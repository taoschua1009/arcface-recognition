# %% [markdown]
# # Face Recognition Accuracy Testing with LFW Dataset

# %% [markdown]
# This notebook evaluates the accuracy of your face recognition system using the Labeled Faces in the Wild (LFW) dataset.
#
# Ensure the following prerequisites are met:
# - The `detector.py` and `model.py` files are functional and accessible.
# - The required dependencies are installed, including `sklearn` and `numpy`.

# %%
# Import các thư viện cần thiết
import os
import cv2
import numpy as np
import torch
from torchvision import transforms
from scrfd.detector import SCRFD
from arcface.model import iresnet_inference
from arcface.utils import compare_encodings, read_features
from face_alignment.alignment import norm_crop
import matplotlib.pyplot as plt
from PIL import Image

# Thiết lập thiết bị (GPU nếu có)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Tải mô hình phát hiện khuôn mặt SCRFD
detector = SCRFD(model_file="scrfd/weights/scrfd_2.5g_bnkps.onnx")
detector.prepare(ctx_id=0 if torch.cuda.is_available() else -1)

# Tải mô hình nhận diện ArcFace
recognizer = iresnet_inference(
    model_name="r100", path="arcface/weights/arcface_r100.pth", device=device
)

# Tải file features.npz
features_path = "./datasets/face_features/feature.npz"
images_names, images_embs = read_features(features_path)

print(f"Loaded {len(images_names)} face embeddings from {features_path}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 27
#      25 # Tải file features.npz
#      26 features_path = "./datasets/face_features/feature.npz"
# ---> 27 images_names, images_embs = read_features(features_path)
#      29 print(f"Loaded {len(images_names)} face embeddings from {features_path}")
#
# TypeError: cannot unpack non-iterable NoneType object

# %%
def read_features(feature_path):
    """
    Đọc các vector đặc trưng và nhãn từ file features.npz.
    """
    if not os.path.exists(feature_path):
        print(f"File {feature_path} không tồn tại.")
        return None

    try:
        data = np.load(feature_path, allow_pickle=True)
        if "images_names" in data and "images_embs" in data:
            return data["images_names"], data["images_embs"]
        else:
            print("File không chứa đủ dữ liệu cần thiết (images_names hoặc images_embs).")
            return None
    except Exception as e:
        print(f"Lỗi khi đọc file features.npz: {e}")
        return None

# %%
import numpy as np
import os

features_path = "./datasets/face_features/feature.npz"

# Kiểm tra file tồn tại
if not os.path.exists(features_path):
    print(f"File {features_path} không tồn tại.")
else:
    print(f"File {features_path} tồn tại.")

    # Thử mở file và kiểm tra nội dung
    try:
        data = np.load(features_path, allow_pickle=True)
        print("Các trường trong file features.npz:", data.files)
        
        if "images_names" in data and "images_embs" in data:
            print("File chứa đầy đủ dữ liệu.")
            images_names = data["images_names"]
            images_embs = data["images_embs"]
            print(f"Đọc được {len(images_names)} nhãn và {images_embs.shape[0]} vector đặc trưng.")
        else:
            print("File không chứa đủ dữ liệu cần thiết (images_names hoặc images_embs).")
    except Exception as e:
        print(f"Lỗi khi đọc file: {e}")
# Out:
# File ./datasets/face_features/feature.npz tồn tại.
# Các trường trong file features.npz: ['images_name', 'images_emb']
# File không chứa đủ dữ liệu cần thiết (images_names hoặc images_embs).

# %%
def read_features(feature_path):
    """
    Đọc các vector đặc trưng và nhãn từ file features.npz.
    """
    if not os.path.exists(feature_path):
        print(f"File {feature_path} không tồn tại.")
        return None

    try:
        data = np.load(feature_path, allow_pickle=True)
        # Sử dụng tên trường thực tế trong file
        if "images_name" in data and "images_emb" in data:
            return data["images_name"], data["images_emb"]
        else:
            print("File không chứa đủ dữ liệu cần thiết (images_name hoặc images_emb).")
            return None
    except Exception as e:
        print(f"Lỗi khi đọc file features.npz: {e}")
        return None

# %%
data = np.load("./datasets/face_features/feature.npz", allow_pickle=True)
print("Các trường trong file features.npz:", data.files)

# Kiểm tra kích thước và dữ liệu của các trường
if "images_name" in data and "images_emb" in data:
    images_names = data["images_name"]
    images_embs = data["images_emb"]
    print(f"Đọc được {len(images_names)} nhãn và {images_embs.shape[0]} vector đặc trưng.")
else:
    print("File không chứa đủ dữ liệu cần thiết.")
# Out:
# Các trường trong file features.npz: ['images_name', 'images_emb']
# Đọc được 707 nhãn và 707 vector đặc trưng.

# %%
import numpy as np
from collections import defaultdict

def group_features_by_name(features_path, output_path):
    """
    Gộp các vector đặc trưng theo nhãn (group by name) và lưu file mới.
    
    Args:
        features_path (str): Đường dẫn tới file features.npz.
        output_path (str): Đường dẫn để lưu file features.npz sau khi gộp.
    """
    # Đọc file features.npz
    data = np.load(features_path, allow_pickle=True)
    images_names = data["images_name"]  # Nhãn của các vector
    images_embs = data["images_emb"]    # Vector đặc trưng

    # Tạo dictionary để nhóm vector theo nhãn
    grouped_embeddings = defaultdict(list)

    # Nhóm vector đặc trưng theo nhãn
    for name, emb in zip(images_names, images_embs):
        grouped_embeddings[name].append(emb)

    # Gộp vector (tính trung bình)
    merged_names = []
    merged_embs = []

    for name, embs in grouped_embeddings.items():
        merged_names.append(name)
        merged_embs.append(np.mean(embs, axis=0))  # Tính trung bình vector đặc trưng

    # Chuyển sang định dạng numpy array
    merged_names = np.array(merged_names)
    merged_embs = np.array(merged_embs)

    # Lưu file mới
    np.savez_compressed(output_path, images_name=merged_names, images_emb=merged_embs)
    print(f"Đã gộp và lưu file mới tại {output_path}")
    print(f"Số lượng nhãn sau khi gộp: {len(merged_names)}")

# %%
features_path = "./datasets/face_features/feature.npz"
output_path = "./datasets/face_features/merged_feature.npz"

group_features_by_name(features_path, output_path)
# Out:
# Đã gộp và lưu file mới tại ./datasets/face_features/merged_feature.npz
# Số lượng nhãn sau khi gộp: 37

# %%
# Đọc file đã gộp
data = np.load(output_path, allow_pickle=True)
merged_names = data["images_name"]
merged_embs = data["images_emb"]

print(f"Các nhãn trong file mới: {merged_names}")
print(f"Số lượng nhãn sau khi gộp: {len(merged_names)}")
# Out:
# Các nhãn trong file mới: ['person_10_tom_holland' 'person_10_tom_holland' 'person_10_tom_holland'
#  'person_10_tom_holland' 'person_10_tom_holland' 'person_10_tom_holland'
#  'person_10_tom_holland' 'person_10_tom_holland' 'person_10_tom_holland'
#  'person_10_tom_holland' 'person_10_tom_holland' 'person_10_tom_holland'
#  'person_10_tom_holland' 'person_10_tom_holland' 'person_10_tom_holland'
#  'person_10_tom_holland' 'person_10_tom_holland' 'person_11_timmothy'
#  'person_11_timmothy' 'person_11_timmothy' 'person_11_timmothy'
#  'person_11_timmothy' 'person_11_timmothy' 'person_11_timmothy'
#  'person_11_timmothy' 'person_11_timmothy' 'person_11_timmothy'
#  'person_11_timmothy' 'person_12_hiddleston' 'person_12_hiddleston'
#  'person_12_hiddleston' 'person_12_hiddleston' 'person_12_hiddleston'
#  'person_12_hiddleston' 'person_12_hiddleston' 'person_12_hiddleston'
#  'person_12_hiddleston' 'person_12_hiddleston' 'person_13_katty_perry'
#  'person_13_katty_perry' 'person_13_katty_perry' 'person_13_katty_perry'
#  'person_13_katty_perry' 'person_13_katty_perry' 'person_13_katty_perry'
#  'person_14_tom_hardy' 'person_14_tom_hardy' 'person_14_tom_hardy'
#  'person_14_tom_hardy' 'person_14_tom_hardy' 'person_14_tom_hardy'
#  'person_14_tom_hardy' 'person_14_tom_hardy' 'person_14_tom_hardy'
#  'person_14_tom_hardy' 'person_14_tom_hardy' 'person_14_tom_hardy'
#  'person_14_tom_hardy' 'person_14_tom_hardy' 'person_14_tom_hardy'
#  'person_14_tom_hardy' 'person_14_tom_hardy' 'person_14_tom_hardy'
#  'person_15_tom_cruise' 'person_15_tom_cruise' 'person_15_tom_cruise'
#  'person_15_tom_cruise' 'person_15_tom_cruise' 'person_15_tom_cruise'
#  'person_15_tom_cruise' 'person_15_tom_cruise' 'person_15_tom_cruise'
#  'person_15_tom_cruise' 'person_15_tom_cruise' 'person_15_tom_cruise'
#  'person_4_Nhu' 'person_4_Nhu' 'person_4_Nhu' 'person_4_Nhu'
#  'person_4_Nhu' 'person_4_Nhu' 'person_4_Nhu' 'person_4_Nhu'
#  'person_5_Giang' 'person_5_Giang' 'person_5_Giang' 'person_5_Giang'
#  'person_5_Giang' 'person_5_Giang' 'person_5_Giang' 'person_5_Giang'
#  'person_7_Phuc' 'person_7_Phuc' 'person_7_Phuc' 'person_7_Phuc'
#  'person_7_Phuc' 'person_7_Phuc' 'person_7_Phuc' 'person_7_Phuc'
#  'person_7_Phuc' 'person_7_Phuc' 'person_7_Phuc' 'person_7_Phuc'
#  'person_7_Phuc' 'person_7_Phuc' 'person_7_Phuc' 'person_7_Phuc'
#  'person_8_tony' 'person_8_tony' 'person_8_tony' 'person_8_tony'
#  'person_8_tony' 'person_8_tony' 'person_8_tony' 'person_8_tony'
#  'person_9_laufey' 'person_9_laufey' 'person_9_laufey' 'person_9_laufey'
#  'person_9_laufey' 'person_9_laufey' 'person_9_laufey' 'person_9_laufey'
#  'person_9_laufey' 'person_9_laufey' 'person_9_laufey' 'person_16_chris'
#  'person_16_chris' 'person_16_chris' 'person_16_chris' 'person_16_chris'
#  'person_16_chris' 'person_16_chris' 'person_16_chris' 'person_16_chris'
#  'person_16_chris' 'person_16_chris' 'person_16_chris' 'person_16_chris'
#  'person_16_chris' 'person_16_chris' 'person_16_chris' 'person_16_chris'
#  'person_17_bruno_mar' 'person_17_bruno_mar' 'person_17_bruno_mar'
#  'person_17_bruno_mar' 'person_17_bruno_mar' 'person_17_bruno_mar'
#  'person_17_bruno_mar' 'person_17_bruno_mar' 'person_17_bruno_mar'
#  'person_17_bruno_mar' 'person_17_bruno_mar' 'person_17_bruno_mar'
#  'person_17_bruno_mar' 'person_17_bruno_mar' 'person_17_bruno_mar'
#  'person_17_bruno_mar' 'person_19_sam_smith' 'person_19_sam_smith'
#  'person_19_sam_smith' 'person_19_sam_smith' 'person_19_sam_smith'
#  'person_19_sam_smith' 'person_19_sam_smith' 'person_19_sam_smith'
#  'person_19_sam_smith' 'person_19_sam_smith' 'person_19_sam_smith'
#  'person_19_sam_smith' 'person_19_sam_smith' 'person_19_sam_smith'
#  'person_19_sam_smith' 'person_19_sam_smith' 'person_19_sam_smith'
#  'person_20_justin_bieber' 'person_20_justin_bieber'
#  'person_20_justin_bieber' 'person_20_justin_bieber'
#  'person_20_justin_bieber' 'person_20_justin_bieber'
#  'person_20_justin_bieber' 'person_20_justin_bieber'
#  'person_20_justin_bieber' 'person_20_justin_bieber'
#  'person_20_justin_bieber' 'person_20_justin_bieber'
#  'person_20_justin_bieber' 'person_20_justin_bieber'
#  'person_20_justin_bieber' 'person_20_justin_bieber'
#  'person_20_justin_bieber' 'person_20_justin_bieber'
#  'person_20_justin_bieber' 'person_20_justin_bieber'
#  'person_20_justin_bieber' 'person_20_justin_bieber' 'person_22_atus'
#  'person_22_atus' 'person_22_atus' 'person_22_atus' 'person_22_atus'
#  'person_22_atus' 'person_22_atus' 'person_22_atus' 'person_22_atus'
#  'person_22_atus' 'person_22_atus' 'person_22_atus' 'person_22_atus'
#  'person_22_atus' 'person_22_atus' 'person_23_h2h' 'person_23_h2h'
#  'person_23_h2h' 'person_23_h2h' 'person_23_h2h' 'person_23_h2h'
#  'person_23_h2h' 'person_23_h2h' 'person_23_h2h' 'person_23_h2h'
#  'person_23_h2h' 'person_23_h2h' 'person_23_h2h' 'person_26_suboi'
#  'person_26_suboi' 'person_26_suboi' 'person_26_suboi' 'person_26_suboi'
#  'person_26_suboi' 'person_26_suboi' 'person_26_suboi' 'person_26_suboi'
#  'person_26_suboi' 'person_26_suboi' 'person_26_suboi' 'person_26_suboi'
#  'person_26_suboi' 'person_26_suboi' 'person_26_suboi' 'person_26_suboi'
#  'person_26_suboi' 'person_26_suboi' 'person_26_suboi' 'person_26_suboi'
#  'person_26_suboi' 'person_26_suboi' 'person_26_suboi' 'person_26_suboi'
#  'person_26_suboi' 'person_27_mck' 'person_27_mck' 'person_27_mck'
#  'person_27_mck' 'person_27_mck' 'person_27_mck' 'person_27_mck'
#  'person_27_mck' 'person_27_mck' 'person_27_mck' 'person_27_mck'
#  'person_27_mck' 'person_27_mck' 'person_27_mck' 'person_27_mck'
#  'person_27_mck' 'person_27_mck' 'person_30_erik' 'person_30_erik'
#  'person_30_erik' 'person_30_erik' 'person_30_erik' 'person_30_erik'
#  'person_30_erik' 'person_30_erik' 'person_30_erik' 'person_30_erik'
#  'person_30_erik' 'person_30_erik' 'person_30_erik' 'person_30_erik'
#  'person_30_erik' 'person_30_erik' 'person_30_erik' 'person_30_erik'
#  'person_30_erik' 'person_30_erik' 'person_30_erik' 'person_30_erik'
#  'person_30_erik' 'person_30_erik' 'person_30_erik' 'person_30_erik'
#  'person_30_erik' 'person_30_erik' 'person_30_erik' 'person_30_erik'
#  'person_31_anh_tu' 'person_31_anh_tu' 'person_31_anh_tu'
#  'person_31_anh_tu' 'person_31_anh_tu' 'person_31_anh_tu'
#  'person_31_anh_tu' 'person_31_anh_tu' 'person_31_anh_tu'
#  'person_31_anh_tu' 'person_31_anh_tu' 'person_31_anh_tu'
#  'person_31_anh_tu' 'person_31_anh_tu' 'person_31_anh_tu'
#  'person_31_anh_tu' 'person_31_anh_tu' 'person_31_anh_tu'
#  'person_31_anh_tu' 'person_31_anh_tu' 'person_31_anh_tu'
#  'person_31_anh_tu' 'person_31_anh_tu' 'person_31_anh_tu'
#  'person_31_anh_tu' 'person_31_anh_tu' 'person_31_anh_tu'
#  'person_31_anh_tu' 'person_32_andrew_garfiled'
#  'person_32_andrew_garfiled' 'person_32_andrew_garfiled'
#  'person_32_andrew_garfiled' 'person_32_andrew_garfiled'
#  'person_32_andrew_garfiled' 'person_32_andrew_garfiled'
#  'person_32_andrew_garfiled' 'person_32_andrew_garfiled'
#  'person_32_andrew_garfiled' 'person_32_andrew_garfiled'
#  'person_32_andrew_garfiled' 'person_32_andrew_garfiled'
#  'person_32_andrew_garfiled' 'person_32_andrew_garfiled'
#  'person_32_andrew_garfiled' 'person_32_andrew_garfiled'
#  'person_32_andrew_garfiled' 'person_32_andrew_garfiled'
#  'person_33_harrington' 'person_33_harrington' 'person_33_harrington'
#  'person_33_harrington' 'person_33_harrington' 'person_33_harrington'
#  'person_33_harrington' 'person_33_harrington' 'person_33_harrington'
#  'person_33_harrington' 'person_33_harrington' 'person_33_harrington'
#  'person_33_harrington' 'person_33_harrington' 'person_33_harrington'
#  'person_33_harrington' 'person_33_harrington' 'person_33_harrington'
#  'person_33_harrington' 'person_33_harrington' 'person_34_harvey'
#  'person_34_harvey' 'person_34_harvey' 'person_34_harvey'
#  'person_34_harvey' 'person_34_harvey' 'person_34_harvey'
#  'person_34_harvey' 'person_34_harvey' 'person_34_harvey'
#  'person_34_harvey' 'person_34_harvey' 'person_34_harvey'
#  'person_34_harvey' 'person_34_harvey' 'person_34_harvey'
#  'person_34_harvey' 'person_35_will__smith' 'person_35_will__smith'
#  'person_35_will__smith' 'person_35_will__smith' 'person_35_will__smith'
#  'person_35_will__smith' 'person_35_will__smith' 'person_35_will__smith'
#  'person_35_will__smith' 'person_35_will__smith' 'person_35_will__smith'
#  'person_35_will__smith' 'person_35_will__smith' 'person_35_will__smith'
#  'person_35_will__smith' 'person_35_will__smith' 'person_35_will__smith'
#  'person_35_will__smith' 'person_35_will__smith' 'person_35_will__smith'
#  'person_36_brad' 'person_36_brad' 'person_36_brad' 'person_36_brad'
#  'person_36_brad' 'person_36_brad' 'person_36_brad' 'person_36_brad'
#  'person_36_brad' 'person_36_brad' 'person_36_brad' 'person_36_brad'
#  'person_36_brad' 'person_36_brad' 'person_36_brad' 'person_36_brad'
#  'person_36_brad' 'person_36_brad' 'person_37_hurrykhng'
#  'person_37_hurrykhng' 'person_37_hurrykhng' 'person_37_hurrykhng'
#  'person_37_hurrykhng' 'person_37_hurrykhng' 'person_37_hurrykhng'
#  'person_37_hurrykhng' 'person_37_hurrykhng' 'person_37_hurrykhng'
#  'person_37_hurrykhng' 'person_37_hurrykhng' 'person_37_hurrykhng'
#  'person_37_hurrykhng' 'person_37_hurrykhng' 'person_37_hurrykhng'
#  'person_37_hurrykhng' 'person_37_hurrykhng' 'person_38_manbo'
#  'person_38_manbo' 'person_38_manbo' 'person_38_manbo' 'person_38_manbo'
#  'person_38_manbo' 'person_38_manbo' 'person_38_manbo' 'person_38_manbo'
#  'person_38_manbo' 'person_38_manbo' 'person_38_manbo' 'person_38_manbo'
#  'person_38_manbo' 'person_38_manbo' 'person_38_manbo' 'person_38_manbo'
#  'person_38_manbo' 'person_38_manbo' 'person_38_manbo'
#  'person_39_crisdevil' 'person_39_crisdevil' 'person_39_crisdevil'
#  'person_39_crisdevil' 'person_39_crisdevil' 'person_39_crisdevil'
#  'person_39_crisdevil' 'person_39_crisdevil' 'person_39_crisdevil'
#  'person_39_crisdevil' 'person_39_crisdevil' 'person_39_crisdevil'
#  'person_39_crisdevil' 'person_39_crisdevil' 'person_39_crisdevil'
#  'person_39_crisdevil' 'person_39_crisdevil' 'person_39_crisdevil'
#  'person_39_crisdevil' 'person_39_crisdevil' 'person_39_crisdevil'
#  'person_39_crisdevil' 'person_40_tranthanh' 'person_40_tranthanh'
#  'person_40_tranthanh' 'person_40_tranthanh' 'person_40_tranthanh'
#  'person_40_tranthanh' 'person_40_tranthanh' 'person_40_tranthanh'
#  'person_40_tranthanh' 'person_40_tranthanh' 'person_40_tranthanh'
#  'person_40_tranthanh' 'person_40_tranthanh' 'person_40_tranthanh'
#  'person_40_tranthanh' 'person_40_tranthanh' 'person_40_tranthanh'
#  'person_40_tranthanh' 'person_40_tranthanh' 'person_40_tranthanh'
#  'person_40_tranthanh' 'person_40_tranthanh' 'person_40_tranthanh'
#  'person_40_tranthanh' 'person_40_tranthanh' 'person_40_tranthanh'
#  'person_40_tranthanh' 'person_40_tranthanh' 'person_40_tranthanh'
#  'person_40_tranthanh' 'person_40_tranthanh' 'person_40_tranthanh'
#  'person_41_quynh' 'person_41_quynh' 'person_41_quynh' 'person_41_quynh'
#  'person_41_quynh' 'person_41_quynh' 'person_41_quynh' 'person_41_quynh'
#  'person_41_quynh' 'person_41_quynh' 'person_41_quynh' 'person_41_quynh'
#  'person_41_quynh' 'person_41_quynh' 'person_41_quynh' 'person_41_quynh'
#  'person_41_quynh' 'person_41_quynh' 'person_41_quynh' 'person_41_quynh'
#  'person_41_quynh' 'person_41_quynh' 'person_41_quynh' 'person_41_quynh'
#  'person_41_quynh' 'person_41_quynh' 'person_41_quynh' 'person_41_quynh'
#  'person_41_quynh' 'person_42_minh' 'person_42_minh' 'person_42_minh'
#  'person_42_minh' 'person_42_minh' 'person_42_minh' 'person_42_minh'
#  'person_42_minh' 'person_42_minh' 'person_42_minh' 'person_42_minh'
#  'person_42_minh' 'person_42_minh' 'person_42_minh' 'person_42_minh'
#  'person_42_minh' 'person_42_minh' 'person_42_minh' 'person_42_minh'
#  'person_42_minh' 'person_42_minh' 'person_42_minh' 'person_42_minh'
#  'person_43_dang' 'person_43_dang' 'person_43_dang' 'person_43_dang'
#  'person_43_dang' 'person_43_dang' 'person_43_dang' 'person_43_dang'
#  'person_43_dang' 'person_43_dang' 'person_43_dang' 'person_43_dang'
#  'person_43_dang' 'person_43_dang' 'person_43_dang' 'person_43_dang'
#  'person_43_dang' 'person_43_dang' 'person_43_dang' 'person_43_dang'
#  'person_43_dang' 'person_43_dang' 'person_43_dang' 'person_43_dang'
#  'person_43_dang' 'person_43_dang' 'person_43_dang' 'person_43_dang'
#  'person_44_yen_nhi' 'person_44_yen_nhi' 'person_44_yen_nhi'
#  'person_44_yen_nhi' 'person_44_yen_nhi' 'person_44_yen_nhi'
#  'person_44_yen_nhi' 'person_44_yen_nhi' 'person_44_yen_nhi'
#  'person_44_yen_nhi' 'person_44_yen_nhi' 'person_44_yen_nhi'
#  'person_44_yen_nhi' 'person_44_yen_nhi' 'person_44_yen_nhi'
#  'person_44_yen_nhi' 'person_44_yen_nhi' 'person_44_yen_nhi'
#  'person_44_yen_nhi' 'person_44_yen_nhi' 'person_44_yen_nhi'
#  'person_44_yen_nhi' 'person_44_yen_nhi' 'person_44_yen_nhi'
#  'person_44_yen_nhi' 'person_44_yen_nhi' 'person_44_yen_nhi'
#  'person_44_yen_nhi' 'person_44_yen_nhi' 'person_44_yen_nhi'
#  'person_44_yen_nhi' 'person_44_yen_nhi' 'person_44_yen_nhi'
#  'person_44_yen_nhi' 'person_44_yen_nhi' 'person_45_tuan_anh'
#  'person_45_tuan_anh' 'person_45_tuan_anh' 'person_45_tuan_anh'
#  'person_45_tuan_anh' 'person_45_tuan_anh' 'person_45_tuan_anh'
#  'person_45_tuan_anh' 'person_45_tuan_anh' 'person_45_tuan_anh'
#  'person_45_tuan_anh' 'person_45_tuan_anh' 'person_45_tuan_anh'
#  'person_45_tuan_anh' 'person_45_tuan_anh' 'person_45_tuan_anh'
#  'person_45_tuan_anh' 'person_45_tuan_anh' 'person_45_tuan_anh'
#  'person_45_tuan_anh' 'person_45_tuan_anh' 'person_45_tuan_anh'
#  'person_46_nam_phuong' 'person_46_nam_phuong' 'person_46_nam_phuong'
#  'person_46_nam_phuong' 'person_46_nam_phuong' 'person_46_nam_phuong'
#  'person_46_nam_phuong' 'person_46_nam_phuong' 'person_46_nam_phuong'
#  'person_46_nam_phuong' 'person_46_nam_phuong' 'person_46_nam_phuong'
#  'person_46_nam_phuong' 'person_46_nam_phuong' 'person_46_nam_phuong'
#  'person_46_nam_phuong' 'person_46_nam_phuong' 'person_46_nam_phuong'
#  'person_46_nam_phuong' 'person_46_nam_phuong' 'person_46_nam_phuong'
#  'person_46_nam_phuong' 'person_46_nam_phuong' 'person_46_nam_phuong'
#  'person_46_nam_phuong' 'person_46_nam_phuong' 'person_46_nam_phuong'
#  'person_46_nam_phuong' 'person_46_nam_phuong' 'person_46_nam_phuong'
#  'person_46_nam_phuong' 'person_46_nam_phuong' 'person_46_nam_phuong'
#  'person_46_nam_phuong' 'person_46_nam_phuong' 'person_46_nam_phuong'
#  'person_46_nam_phuong' 'person_46_nam_phuong' 'person_46_nam_phuong'
#  'person_46_nam_phuong' 'person_46_nam_phuong' 'person_46_nam_phuong'
#  'person_46_nam_phuong' 'person_46_nam_phuong' 'person_50_qanh'
#  'person_50_qanh' 'person_50_qanh' 'person_50_qanh' 'person_50_qanh'
#  'person_50_qanh' 'person_50_qanh' 'person_50_qanh' 'person_50_qanh'
#  'person_50_qanh' 'person_50_qanh' 'person_50_qanh' 'person_50_qanh']
# Số lượng nhãn sau khi gộp: 707

# %%
import numpy as np

def normalize_labels(features_path, output_path):
    """
    Chuẩn hóa nhãn trong file features.npz bằng cách thay khoảng trắng bằng dấu gạch dưới.
    
    Args:
        features_path (str): Đường dẫn tới file features.npz cần chuẩn hóa.
        output_path (str): Đường dẫn để lưu file đã chuẩn hóa.
    """
    # Đọc file features.npz
    data = np.load(features_path, allow_pickle=True)
    images_names = data["images_name"]
    images_embs = data["images_emb"]

    # Chuẩn hóa nhãn
    normalized_names = [name.replace(" ", "_") for name in images_names]

    # Lưu lại file mới với nhãn đã chuẩn hóa
    np.savez_compressed(output_path, images_name=np.array(normalized_names), images_emb=np.array(images_embs))
    print(f"Đã chuẩn hóa nhãn và lưu file mới tại {output_path}")

# %%
features_path = "./datasets/face_features/feature.npz"
output_path = "./datasets/face_features/normalized_feature.npz"

# %%
normalize_labels(features_path, output_path)
# Out:
# Đã chuẩn hóa nhãn và lưu file mới tại ./datasets/face_features/normalized_feature.npz

# %%
import os
import numpy as np
import cv2
import torch
from torchvision import transforms
from arcface.model import iresnet_inference
from arcface.utils import compare_encodings
import matplotlib.pyplot as plt

# Thiết lập thiết bị
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Tải mô hình nhận diện ArcFace
recognizer = iresnet_inference(
    model_name="r100", path="arcface/weights/arcface_r100.pth", device=device
)

# Đường dẫn tới file features.npz đã được chuẩn hóa
features_path = "./datasets/face_features/normalized_feature.npz"

# %%
# Đọc file features.npz
data = np.load(features_path, allow_pickle=True)
images_names = data["images_name"]
images_embs = data["images_emb"]

print(f"Đã tải {len(images_names)} nhãn và vector đặc trưng từ {features_path}.")
# Out:
# Đã tải 707 nhãn và vector đặc trưng từ ./datasets/face_features/normalized_feature.npz.

# %%
features_path = "./datasets/face_features/normalized_feature.npz"
output_path = "./datasets/face_features/merged_feature.npz"

group_features_by_name(features_path, output_path)
# Out:
# Đã gộp và lưu file mới tại ./datasets/face_features/merged_feature.npz
# Số lượng nhãn sau khi gộp: 37

# %%
# Hàm trích xuất vector đặc trưng từ ảnh khuôn mặt
@torch.no_grad()
def get_feature(face_image):
    """
    Trích xuất vector đặc trưng từ ảnh khuôn mặt đã được phát hiện.
    """
    preprocess = transforms.Compose([
        transforms.ToTensor(),
        transforms.Resize((112, 112)),
        transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5]),
    ])
    face_image = cv2.cvtColor(face_image, cv2.COLOR_BGR2RGB)
    face_tensor = preprocess(face_image).unsqueeze(0).to(device)

    emb = recognizer(face_tensor).cpu().numpy()
    return emb / np.linalg.norm(emb)

# %%
def recognition(face_image):
    """
    Nhận diện khuôn mặt từ ảnh khuôn mặt.
    """
    query_emb = get_feature(face_image)
    score, idx = compare_encodings(query_emb, images_embs)
    recognized_name = images_names[idx]
    return score[0], recognized_name

# %%
def show_image_with_results(image_path, true_name):
    """
    Hiển thị kết quả nhận diện từ ảnh đầu vào.
    
    Args:
        image_path (str): Đường dẫn tới ảnh.
        true_name (str): Tên thực tế của người trong ảnh.
    """
    # Đọc ảnh
    face_image = cv2.imread(image_path)
    if face_image is None:
        print(f"Không thể đọc ảnh từ {image_path}")
        return

    # Nhận diện khuôn mặt
    score, recognized_name = recognition(face_image)

    # Hiển thị ảnh và kết quả
    plt.figure(figsize=(10, 10))
    plt.imshow(cv2.cvtColor(face_image, cv2.COLOR_BGR2RGB))
    plt.axis("off")
    plt.title(f"True: {true_name}\nPredicted: {recognized_name} ({score:.2f})")
    plt.show()

    # In kết quả chi tiết
    print(f"Kết quả nhận diện từ {image_path}:")
    print(f"  - Tên nhận diện: {recognized_name}")
    print(f"  - Điểm số: {score:.2f}")
    print(f"  - Tên thực tế: {true_name}")

# %%
# Đánh giá trên một ảnh
def evaluate_single_image(image_path, true_name):
    """
    Đánh giá kết quả nhận diện trên một ảnh.
    
    Args:
        image_path (str): Đường dẫn tới ảnh đã cắt khuôn mặt.
        true_name (str): Tên thực tế của người trong ảnh.

    Returns:
        bool: True nếu nhận diện đúng, False nếu sai.
    """
    face_image = cv2.imread(image_path)
    if face_image is None:
        print(f"Không thể đọc ảnh: {image_path}")
        return False

    score, recognized_name = recognition(face_image)
    print(f"Kết quả từ {image_path}:")
    print(f"  - Dự đoán: {recognized_name} (Score: {score:.2f})")
    print(f"  - Thực tế: {true_name}")

    return recognized_name == true_name

# %%
# Đánh giá toàn bộ dataset
def evaluate_model(dataset_dir):
    """
    Đánh giá mô hình trên toàn bộ tập dữ liệu đã detect.
    
    Args:
        dataset_dir (str): Đường dẫn tới thư mục chứa dataset.

    Returns:
        accuracy (float): Độ chính xác của mô hình.
    """
    total_images = 0
    correct_recognitions = 0
    false_recognitions = 0

    for person_name in os.listdir(dataset_dir):
        person_dir = os.path.join(dataset_dir, person_name)
        if not os.path.isdir(person_dir):
            continue

        for img_name in os.listdir(person_dir):
            img_path = os.path.join(person_dir, img_name)
            total_images += 1
            if evaluate_single_image(img_path, person_name):
                correct_recognitions += 1
            else:
                false_recognitions += 1

    accuracy = correct_recognitions / total_images * 100
    print(f"Độ chính xác của mô hình: {accuracy:.2f}%")
    print(f"Tổng số ảnh: {total_images}")
    print(f"Số nhận diện đúng: {correct_recognitions}")
    print(f"Số nhận diện sai: {false_recognitions}")
    return accuracy

# %%
# Hiển thị kết quả cho một ảnh cụ thể
image_path = "./datasets/data/person_10_tom_holland/1.jpg"
true_name = "person_10_tom_holland"
show_image_with_results(image_path, true_name)

# Đánh giá toàn bộ dataset
dataset_dir = "./datasets/data"
evaluate_model(dataset_dir)
# Out:
# Kết quả từ ./datasets/data\person_10_tom_holland\0.jpg:
#   - Dự đoán: person_10_tom_holland (Score: 1.00)
#   - Thực tế: person_10_tom_holland
# Kết quả từ ./datasets/data\person_10_tom_holland\1.jpg:
#   - Dự đoán: person_10_tom_holland (Score: 1.00)
#   - Thực tế: person_10_tom_holland
# Kết quả từ ./datasets/data\person_10_tom_holland\10.jpg:
#   - Dự đoán: person_10_tom_holland (Score: 1.00)
#   - Thực tế: person_10_tom_holland
# Kết quả từ ./datasets/data\person_10_tom_holland\11.jpg:
#   - Dự đoán: person_10_tom_holland (Score: 1.00)
#   - Thực tế: person_10_tom_holland
# Kết quả từ ./datasets/data\person_10_tom_holland\12.jpg:
#   - Dự đoán: person_10_tom_holland (Score: 1.00)
#   - Thực tế: person_10_tom_holland
# Kết quả từ ./datasets/data\person_10_tom_holland\13.jpg:
#   - Dự đoán: person_10_tom_holland (Score: 1.00)
#   - Thực tế: person_10_tom_holland
# Kết quả từ ./datasets/data\person_10_tom_holland\14.jpg:
#   - Dự đoán: person_10_tom_holland (Score: 1.00)
#   - Thực tế: person_10_tom_holland
# Kết quả từ ./datasets/data\person_10_tom_holland\15.jpg:
#   - Dự đoán: person_10_tom_holland (Score: 1.00)
#   - Thực tế: person_10_tom_holland
# Kết quả từ ./datasets/data\person_10_tom_holland\16.jpg:
#   - Dự đoán: person_10_tom_holland (Score: 1.00)
#   - Thực tế: person_10_tom_holland
# Kết quả từ ./datasets/data\person_10_tom_holland\17.jpg:
#   - Dự đoán: person_10_tom_holland (Score: 1.00)
#   - Thực tế: person_10_tom_holland
# Kết quả từ ./datasets/data\person_10_tom_holland\18.jpg:
#   - Dự đoán: person_10_tom_holland (Score: 1.00)
#   - Thực tế: person_10_tom_holland
# Kết quả từ ./datasets/data\person_10_tom_holland\19.jpg:
#   - Dự đoán: person_10_tom_holland (Score: 1.00)
#   - Thực tế: person_10_tom_holland
# Kết quả từ ./datasets/data\person_10_tom_holland\2.jpg:
#   - Dự đoán: person_10_tom_holland (Score: 1.00)
#   - Thực tế: person_10_tom_holland
# Kết quả từ ./datasets/data\person_10_tom_holland\20.jpg:
#   - Dự đoán: person_10_tom_holland (Score: 1.00)
#   - Thực tế: person_10_tom_holland
# Kết quả từ ./datasets/data\person_10_tom_holland\21.jpg:
#   - Dự đoán: person_10_tom_holland (Score: 1.00)
#   - Thực tế: person_10_tom_holland
# Kết quả từ ./datasets/data\person_10_tom_holland\22.jpg:
#   - Dự đoán: person_10_tom_holland (Score: 1.00)
#   - Thực tế: person_10_tom_holland
# Kết quả từ ./datasets/data\person_10_tom_holland\23.jpg:
#   - Dự đoán: person_10_tom_holland (Score: 1.00)
#   - Thực tế: person_10_tom_holland
# Kết quả từ ./datasets/data\person_10_tom_holland\24.jpg:
#   - Dự đoán: person_10_tom_holland (Score: 1.00)
#   - Thực tế: person_10_tom_holland
# Kết quả từ ./datasets/data\person_10_tom_holland\25.jpg:
#   - Dự đoán: person_10_tom_holland (Score: 1.00)
#   - Thực tế: person_10_tom_holland
# Kết quả từ ./datasets/data\person_10_tom_holland\26.jpg:
#   - Dự đoán: person_10_tom_holland (Score: 1.00)
#   - Thực tế: person_10_tom_holland
# Kết quả từ ./datasets/data\person_10_tom_holland\27.jpg:
#   - Dự đoán: person_10_tom_holland (Score: 1.00)
#   - Thực tế: person_10_tom_holland
# Kết quả từ ./datasets/data\person_10_tom_holland\28.jpg:
#   - Dự đoán: person_10_tom_holland (Score: 1.00)
#   - Thực tế: person_10_tom_holland
# Kết quả từ ./datasets/data\person_10_tom_holland\29.jpg:
#   - Dự đoán: person_10_tom_holland (Score: 1.00)
#   - Thực tế: person_10_tom_holland
# Kết quả từ ./datasets/data\person_10_tom_holland\3.jpg:
#   - Dự đoán: person_10_tom_holland (Score: 1.00)
#   - Thực tế: person_10_tom_holland
# Kết quả từ ./datasets/data\person_10_tom_holland\30.jpg:
#   - Dự đoán: person_10_tom_holland (Score: 1.00)
#   - Thực tế: person_10_tom_holland
# Kết quả từ ./datasets/data\person_10_tom_holland\31.jpg:
#   - Dự đoán: person_10_tom_holland (Score: 1.00)
#   - Thực tế: person_10_tom_holland
# Kết quả từ ./datasets/data\person_10_tom_holland\32.jpg:
#   - Dự đoán: person_10_tom_holland (Score: 1.00)
#   - Thực tế: person_10_tom_holland
# Kết quả từ ./datasets/data\person_10_tom_holland\33.jpg:
#   - Dự đoán: person_10_tom_holland (Score: 1.00)
#   - Thực tế: person_10_tom_holland
# Kết quả từ ./datasets/data\person_10_tom_holland\4.jpg:
#   - Dự đoán: person_10_tom_holland (Score: 1.00)
#   - Thực tế: person_10_tom_holland
# Kết quả từ ./datasets/data\person_10_tom_holland\5.jpg:
#   - Dự đoán: person_10_tom_holland (Score: 1.00)
#   - Thực tế: person_10_tom_holland
# Kết quả từ ./datasets/data\person_10_tom_holland\6.jpg:
#   - Dự đoán: person_10_tom_holland (Score: 1.00)
#   - Thực tế: person_10_tom_holland
# Kết quả từ ./datasets/data\person_10_tom_holland\7.jpg:
#   - Dự đoán: person_10_tom_holland (Score: 1.00)
#   - Thực tế: person_10_tom_holland
# Kết quả từ ./datasets/data\person_10_tom_holland\8.jpg:
#   - Dự đoán: person_10_tom_holland (Score: 1.00)
#   - Thực tế: person_10_tom_holland
# Kết quả từ ./datasets/data\person_10_tom_holland\9.jpg:
#   - Dự đoán: person_10_tom_holland (Score: 1.00)
#   - Thực tế: person_10_tom_holland
# Kết quả từ ./datasets/data\person_11_timmothy\0.jpg:
#   - Dự đoán: person_11_timmothy (Score: 1.00)
#   - Thực tế: person_11_timmothy
# Kết quả từ ./datasets/data\person_11_timmothy\1.jpg:
#   - Dự đoán: person_11_timmothy (Score: 1.00)
#   - Thực tế: person_11_timmothy
# Kết quả từ ./datasets/data\person_11_timmothy\10.jpg:
#   - Dự đoán: person_11_timmothy (Score: 1.00)
#   - Thực tế: person_11_timmothy
# Kết quả từ ./datasets/data\person_11_timmothy\11.jpg:
#   - Dự đoán: person_11_timmothy (Score: 1.00)
#   - Thực tế: person_11_timmothy
# Kết quả từ ./datasets/data\person_11_timmothy\12.jpg:
#   - Dự đoán: person_11_timmothy (Score: 1.00)
#   - Thực tế: person_11_timmothy
# Kết quả từ ./datasets/data\person_11_timmothy\13.jpg:
#   - Dự đoán: person_11_timmothy (Score: 1.00)
#   - Thực tế: person_11_timmothy
# Kết quả từ ./datasets/data\person_11_timmothy\14.jpg:
#   - Dự đoán: person_11_timmothy (Score: 1.00)
#   - Thực tế: person_11_timmothy
# Kết quả từ ./datasets/data\person_11_timmothy\15.jpg:
#   - Dự đoán: person_11_timmothy (Score: 1.00)
#   - Thực tế: person_11_timmothy
# Kết quả từ ./datasets/data\person_11_timmothy\16.jpg:
#   - Dự đoán: person_11_timmothy (Score: 1.00)
#   - Thực tế: person_11_timmothy
# Kết quả từ ./datasets/data\person_11_timmothy\17.jpg:
#   - Dự đoán: person_11_timmothy (Score: 1.00)
#   - Thực tế: person_11_timmothy
# Kết quả từ ./datasets/data\person_11_timmothy\18.jpg:
#   - Dự đoán: person_11_timmothy (Score: 1.00)
#   - Thực tế: person_11_timmothy
# Kết quả từ ./datasets/data\person_11_timmothy\19.jpg:
#   - Dự đoán: person_11_timmothy (Score: 1.00)
#   - Thực tế: person_11_timmothy
# Kết quả từ ./datasets/data\person_11_timmothy\2.jpg:
#   - Dự đoán: person_11_timmothy (Score: 1.00)
#   - Thực tế: person_11_timmothy
# Kết quả từ ./datasets/data\person_11_timmothy\20.jpg:
#   - Dự đoán: person_11_timmothy (Score: 1.00)
#   - Thực tế: person_11_timmothy
# Kết quả từ ./datasets/data\person_11_timmothy\21.jpg:
#   - Dự đoán: person_11_timmothy (Score: 1.00)
#   - Thực tế: person_11_timmothy
# Kết quả từ ./datasets/data\person_11_timmothy\3.jpg:
#   - Dự đoán: person_11_timmothy (Score: 1.00)
#   - Thực tế: person_11_timmothy
# Kết quả từ ./datasets/data\person_11_timmothy\4.jpg:
#   - Dự đoán: person_11_timmothy (Score: 1.00)
#   - Thực tế: person_11_timmothy
# Kết quả từ ./datasets/data\person_11_timmothy\5.jpg:
#   - Dự đoán: person_11_timmothy (Score: 1.00)
#   - Thực tế: person_11_timmothy
# Kết quả từ ./datasets/data\person_11_timmothy\6.jpg:
#   - Dự đoán: person_11_timmothy (Score: 1.00)
#   - Thực tế: person_11_timmothy
# Kết quả từ ./datasets/data\person_11_timmothy\7.jpg:
#   - Dự đoán: person_11_timmothy (Score: 1.00)
#   - Thực tế: person_11_timmothy
# Kết quả từ ./datasets/data\person_11_timmothy\8.jpg:
#   - Dự đoán: person_11_timmothy (Score: 1.00)
#   - Thực tế: person_11_timmothy
# Kết quả từ ./datasets/data\person_11_timmothy\9.jpg:
#   - Dự đoán: person_11_timmothy (Score: 1.00)
#   - Thực tế: person_11_timmothy
# Kết quả từ ./datasets/data\person_12_hiddleston\0.jpg:
#   - Dự đoán: person_12_hiddleston (Score: 1.00)
#   - Thực tế: person_12_hiddleston
# Kết quả từ ./datasets/data\person_12_hiddleston\1.jpg:
#   - Dự đoán: person_12_hiddleston (Score: 1.00)
#   - Thực tế: person_12_hiddleston
# Kết quả từ ./datasets/data\person_12_hiddleston\10.jpg:
#   - Dự đoán: person_12_hiddleston (Score: 1.00)
#   - Thực tế: person_12_hiddleston
# Kết quả từ ./datasets/data\person_12_hiddleston\11.jpg:
#   - Dự đoán: person_12_hiddleston (Score: 1.00)
#   - Thực tế: person_12_hiddleston
# Kết quả từ ./datasets/data\person_12_hiddleston\12.jpg:
#   - Dự đoán: person_12_hiddleston (Score: 1.00)
#   - Thực tế: person_12_hiddleston
# Kết quả từ ./datasets/data\person_12_hiddleston\13.jpg:
#   - Dự đoán: person_12_hiddleston (Score: 1.00)
#   - Thực tế: person_12_hiddleston
# Kết quả từ ./datasets/data\person_12_hiddleston\14.jpg:
#   - Dự đoán: person_12_hiddleston (Score: 1.00)
#   - Thực tế: person_12_hiddleston
# Kết quả từ ./datasets/data\person_12_hiddleston\15.jpg:
#   - Dự đoán: person_12_hiddleston (Score: 1.00)
#   - Thực tế: person_12_hiddleston
# Kết quả từ ./datasets/data\person_12_hiddleston\16.jpg:
#   - Dự đoán: person_12_hiddleston (Score: 1.00)
#   - Thực tế: person_12_hiddleston
# Kết quả từ ./datasets/data\person_12_hiddleston\17.jpg:
#   - Dự đoán: person_12_hiddleston (Score: 1.00)
#   - Thực tế: person_12_hiddleston
# Kết quả từ ./datasets/data\person_12_hiddleston\18.jpg:
#   - Dự đoán: person_12_hiddleston (Score: 1.00)
#   - Thực tế: person_12_hiddleston
# Kết quả từ ./datasets/data\person_12_hiddleston\19.jpg:
#   - Dự đoán: person_12_hiddleston (Score: 1.00)
#   - Thực tế: person_12_hiddleston
# Kết quả từ ./datasets/data\person_12_hiddleston\2.jpg:
#   - Dự đoán: person_12_hiddleston (Score: 1.00)
#   - Thực tế: person_12_hiddleston
# Kết quả từ ./datasets/data\person_12_hiddleston\3.jpg:
#   - Dự đoán: person_12_hiddleston (Score: 1.00)
#   - Thực tế: person_12_hiddleston
# Kết quả từ ./datasets/data\person_12_hiddleston\4.jpg:
#   - Dự đoán: person_12_hiddleston (Score: 1.00)
#   - Thực tế: person_12_hiddleston
# Kết quả từ ./datasets/data\person_12_hiddleston\5.jpg:
#   - Dự đoán: person_12_hiddleston (Score: 1.00)
#   - Thực tế: person_12_hiddleston
# Kết quả từ ./datasets/data\person_12_hiddleston\6.jpg:
#   - Dự đoán: person_12_hiddleston (Score: 1.00)
#   - Thực tế: person_12_hiddleston
# Kết quả từ ./datasets/data\person_12_hiddleston\7.jpg:
#   - Dự đoán: person_12_hiddleston (Score: 1.00)
#   - Thực tế: person_12_hiddleston
# Kết quả từ ./datasets/data\person_12_hiddleston\8.jpg:
#   - Dự đoán: person_12_hiddleston (Score: 1.00)
#   - Thực tế: person_12_hiddleston
# Kết quả từ ./datasets/data\person_12_hiddleston\9.jpg:
#   - Dự đoán: person_12_hiddleston (Score: 1.00)
#   - Thực tế: person_12_hiddleston
# Kết quả từ ./datasets/data\person_13_katty_perry\0.jpg:
#   - Dự đoán: person_13_katty_perry (Score: 1.00)
#   - Thực tế: person_13_katty_perry
# Kết quả từ ./datasets/data\person_13_katty_perry\1.jpg:
#   - Dự đoán: person_13_katty_perry (Score: 1.00)
#   - Thực tế: person_13_katty_perry
# Kết quả từ ./datasets/data\person_13_katty_perry\10.jpg:
#   - Dự đoán: person_13_katty_perry (Score: 1.00)
#   - Thực tế: person_13_katty_perry
# Kết quả từ ./datasets/data\person_13_katty_perry\11.jpg:
#   - Dự đoán: person_13_katty_perry (Score: 1.00)
#   - Thực tế: person_13_katty_perry
# Kết quả từ ./datasets/data\person_13_katty_perry\12.jpg:
#   - Dự đoán: person_13_katty_perry (Score: 1.00)
#   - Thực tế: person_13_katty_perry
# Kết quả từ ./datasets/data\person_13_katty_perry\13.jpg:
#   - Dự đoán: person_13_katty_perry (Score: 1.00)
#   - Thực tế: person_13_katty_perry
# Kết quả từ ./datasets/data\person_13_katty_perry\2.jpg:
#   - Dự đoán: person_13_katty_perry (Score: 1.00)
#   - Thực tế: person_13_katty_perry
# Kết quả từ ./datasets/data\person_13_katty_perry\3.jpg:
#   - Dự đoán: person_13_katty_perry (Score: 1.00)
#   - Thực tế: person_13_katty_perry
# Kết quả từ ./datasets/data\person_13_katty_perry\4.jpg:
#   - Dự đoán: person_13_katty_perry (Score: 1.00)
#   - Thực tế: person_13_katty_perry
# Kết quả từ ./datasets/data\person_13_katty_perry\5.jpg:
#   - Dự đoán: person_13_katty_perry (Score: 1.00)
#   - Thực tế: person_13_katty_perry
# Kết quả từ ./datasets/data\person_13_katty_perry\6.jpg:
#   - Dự đoán: person_13_katty_perry (Score: 1.00)
#   - Thực tế: person_13_katty_perry
# Kết quả từ ./datasets/data\person_13_katty_perry\7.jpg:
#   - Dự đoán: person_13_katty_perry (Score: 1.00)
#   - Thực tế: person_13_katty_perry
# Kết quả từ ./datasets/data\person_13_katty_perry\8.jpg:
#   - Dự đoán: person_13_katty_perry (Score: 1.00)
#   - Thực tế: person_13_katty_perry
# Kết quả từ ./datasets/data\person_13_katty_perry\9.jpg:
#   - Dự đoán: person_13_katty_perry (Score: 1.00)
#   - Thực tế: person_13_katty_perry
# Kết quả từ ./datasets/data\person_14_tom_hardy\0.jpg:
#   - Dự đoán: person_14_tom_hardy (Score: 1.00)
#   - Thực tế: person_14_tom_hardy
# Kết quả từ ./datasets/data\person_14_tom_hardy\1.jpg:
#   - Dự đoán: person_14_tom_hardy (Score: 1.00)
#   - Thực tế: person_14_tom_hardy
# Kết quả từ ./datasets/data\person_14_tom_hardy\10.jpg:
#   - Dự đoán: person_14_tom_hardy (Score: 1.00)
#   - Thực tế: person_14_tom_hardy
# Kết quả từ ./datasets/data\person_14_tom_hardy\11.jpg:
#   - Dự đoán: person_14_tom_hardy (Score: 1.00)
#   - Thực tế: person_14_tom_hardy
# Kết quả từ ./datasets/data\person_14_tom_hardy\12.jpg:
#   - Dự đoán: person_14_tom_hardy (Score: 1.00)
#   - Thực tế: person_14_tom_hardy
# Kết quả từ ./datasets/data\person_14_tom_hardy\13.jpg:
#   - Dự đoán: person_14_tom_hardy (Score: 1.00)
#   - Thực tế: person_14_tom_hardy
# Kết quả từ ./datasets/data\person_14_tom_hardy\14.jpg:
#   - Dự đoán: person_14_tom_hardy (Score: 1.00)
#   - Thực tế: person_14_tom_hardy
# Kết quả từ ./datasets/data\person_14_tom_hardy\15.jpg:
#   - Dự đoán: person_14_tom_hardy (Score: 1.00)
#   - Thực tế: person_14_tom_hardy
# Kết quả từ ./datasets/data\person_14_tom_hardy\16.jpg:
#   - Dự đoán: person_14_tom_hardy (Score: 1.00)
#   - Thực tế: person_14_tom_hardy
# Kết quả từ ./datasets/data\person_14_tom_hardy\17.jpg:
#   - Dự đoán: person_14_tom_hardy (Score: 1.00)
#   - Thực tế: person_14_tom_hardy
# Kết quả từ ./datasets/data\person_14_tom_hardy\18.jpg:
#   - Dự đoán: person_14_tom_hardy (Score: 1.00)
#   - Thực tế: person_14_tom_hardy
# Kết quả từ ./datasets/data\person_14_tom_hardy\19.jpg:
#   - Dự đoán: person_14_tom_hardy (Score: 1.00)
#   - Thực tế: person_14_tom_hardy
# Kết quả từ ./datasets/data\person_14_tom_hardy\2.jpg:
#   - Dự đoán: person_14_tom_hardy (Score: 1.00)
#   - Thực tế: person_14_tom_hardy
# Kết quả từ ./datasets/data\person_14_tom_hardy\20.jpg:
#   - Dự đoán: person_14_tom_hardy (Score: 1.00)
#   - Thực tế: person_14_tom_hardy
# Kết quả từ ./datasets/data\person_14_tom_hardy\21.jpg:
#   - Dự đoán: person_14_tom_hardy (Score: 1.00)
#   - Thực tế: person_14_tom_hardy
# Kết quả từ ./datasets/data\person_14_tom_hardy\22.jpg:
#   - Dự đoán: person_14_tom_hardy (Score: 1.00)
#   - Thực tế: person_14_tom_hardy
# Kết quả từ ./datasets/data\person_14_tom_hardy\23.jpg:
#   - Dự đoán: person_14_tom_hardy (Score: 1.00)
#   - Thực tế: person_14_tom_hardy
# Kết quả từ ./datasets/data\person_14_tom_hardy\24.jpg:
#   - Dự đoán: person_14_tom_hardy (Score: 1.00)
#   - Thực tế: person_14_tom_hardy
# Kết quả từ ./datasets/data\person_14_tom_hardy\25.jpg:
#   - Dự đoán: person_14_tom_hardy (Score: 1.00)
#   - Thực tế: person_14_tom_hardy
# Kết quả từ ./datasets/data\person_14_tom_hardy\26.jpg:
#   - Dự đoán: person_14_tom_hardy (Score: 1.00)
#   - Thực tế: person_14_tom_hardy
# Kết quả từ ./datasets/data\person_14_tom_hardy\27.jpg:
#   - Dự đoán: person_14_tom_hardy (Score: 1.00)
#   - Thực tế: person_14_tom_hardy
# Kết quả từ ./datasets/data\person_14_tom_hardy\28.jpg:
#   - Dự đoán: person_14_tom_hardy (Score: 1.00)
#   - Thực tế: person_14_tom_hardy
# Kết quả từ ./datasets/data\person_14_tom_hardy\29.jpg:
#   - Dự đoán: person_14_tom_hardy (Score: 1.00)
#   - Thực tế: person_14_tom_hardy
# Kết quả từ ./datasets/data\person_14_tom_hardy\3.jpg:
#   - Dự đoán: person_14_tom_hardy (Score: 1.00)
#   - Thực tế: person_14_tom_hardy
# Kết quả từ ./datasets/data\person_14_tom_hardy\30.jpg:
#   - Dự đoán: person_14_tom_hardy (Score: 1.00)
#   - Thực tế: person_14_tom_hardy
# Kết quả từ ./datasets/data\person_14_tom_hardy\31.jpg:
#   - Dự đoán: person_14_tom_hardy (Score: 1.00)
#   - Thực tế: person_14_tom_hardy
# Kết quả từ ./datasets/data\person_14_tom_hardy\32.jpg:
#   - Dự đoán: person_14_tom_hardy (Score: 1.00)
#   - Thực tế: person_14_tom_hardy
# Kết quả từ ./datasets/data\person_14_tom_hardy\33.jpg:
#   - Dự đoán: person_14_tom_hardy (Score: 1.00)
#   - Thực tế: person_14_tom_hardy
# Kết quả từ ./datasets/data\person_14_tom_hardy\34.jpg:
#   - Dự đoán: person_14_tom_hardy (Score: 1.00)
#   - Thực tế: person_14_tom_hardy
# Kết quả từ ./datasets/data\person_14_tom_hardy\35.jpg:
#   - Dự đoán: person_14_tom_hardy (Score: 1.00)
#   - Thực tế: person_14_tom_hardy
# Kết quả từ ./datasets/data\person_14_tom_hardy\4.jpg:
#   - Dự đoán: person_14_tom_hardy (Score: 1.00)
#   - Thực tế: person_14_tom_hardy
# Kết quả từ ./datasets/data\person_14_tom_hardy\5.jpg:
#   - Dự đoán: person_14_tom_hardy (Score: 1.00)
#   - Thực tế: person_14_tom_hardy
# Kết quả từ ./datasets/data\person_14_tom_hardy\6.jpg:
#   - Dự đoán: person_14_tom_hardy (Score: 1.00)
#   - Thực tế: person_14_tom_hardy
# Kết quả từ ./datasets/data\person_14_tom_hardy\7.jpg:
#   - Dự đoán: person_14_tom_hardy (Score: 1.00)
#   - Thực tế: person_14_tom_hardy
# Kết quả từ ./datasets/data\person_14_tom_hardy\8.jpg:
#   - Dự đoán: person_14_tom_hardy (Score: 1.00)
#   - Thực tế: person_14_tom_hardy
# Kết quả từ ./datasets/data\person_14_tom_hardy\9.jpg:
#   - Dự đoán: person_14_tom_hardy (Score: 1.00)
#   - Thực tế: person_14_tom_hardy
# Kết quả từ ./datasets/data\person_15_tom_cruise\0.jpg:
#   - Dự đoán: person_15_tom_cruise (Score: 1.00)
#   - Thực tế: person_15_tom_cruise
# Kết quả từ ./datasets/data\person_15_tom_cruise\1.jpg:
#   - Dự đoán: person_15_tom_cruise (Score: 1.00)
#   - Thực tế: person_15_tom_cruise
# Kết quả từ ./datasets/data\person_15_tom_cruise\10.jpg:
#   - Dự đoán: person_15_tom_cruise (Score: 1.00)
#   - Thực tế: person_15_tom_cruise
# Kết quả từ ./datasets/data\person_15_tom_cruise\11.jpg:
#   - Dự đoán: person_15_tom_cruise (Score: 1.00)
#   - Thực tế: person_15_tom_cruise
# Kết quả từ ./datasets/data\person_15_tom_cruise\12.jpg:
#   - Dự đoán: person_15_tom_cruise (Score: 1.00)
#   - Thực tế: person_15_tom_cruise
# Kết quả từ ./datasets/data\person_15_tom_cruise\13.jpg:
#   - Dự đoán: person_15_tom_cruise (Score: 1.00)
#   - Thực tế: person_15_tom_cruise
# Kết quả từ ./datasets/data\person_15_tom_cruise\14.jpg:
#   - Dự đoán: person_15_tom_cruise (Score: 1.00)
#   - Thực tế: person_15_tom_cruise
# Kết quả từ ./datasets/data\person_15_tom_cruise\15.jpg:
#   - Dự đoán: person_15_tom_cruise (Score: 1.00)
#   - Thực tế: person_15_tom_cruise
# Kết quả từ ./datasets/data\person_15_tom_cruise\16.jpg:
#   - Dự đoán: person_15_tom_cruise (Score: 1.00)
#   - Thực tế: person_15_tom_cruise
# Kết quả từ ./datasets/data\person_15_tom_cruise\17.jpg:
#   - Dự đoán: person_15_tom_cruise (Score: 1.00)
#   - Thực tế: person_15_tom_cruise
# Kết quả từ ./datasets/data\person_15_tom_cruise\18.jpg:
#   - Dự đoán: person_15_tom_cruise (Score: 1.00)
#   - Thực tế: person_15_tom_cruise
# Kết quả từ ./datasets/data\person_15_tom_cruise\19.jpg:
#   - Dự đoán: person_15_tom_cruise (Score: 1.00)
#   - Thực tế: person_15_tom_cruise
# Kết quả từ ./datasets/data\person_15_tom_cruise\2.jpg:
#   - Dự đoán: person_15_tom_cruise (Score: 1.00)
#   - Thực tế: person_15_tom_cruise
# Kết quả từ ./datasets/data\person_15_tom_cruise\20.jpg:
#   - Dự đoán: person_15_tom_cruise (Score: 1.00)
#   - Thực tế: person_15_tom_cruise
# Kết quả từ ./datasets/data\person_15_tom_cruise\21.jpg:
#   - Dự đoán: person_15_tom_cruise (Score: 1.00)
#   - Thực tế: person_15_tom_cruise
# Kết quả từ ./datasets/data\person_15_tom_cruise\22.jpg:
#   - Dự đoán: person_15_tom_cruise (Score: 1.00)
#   - Thực tế: person_15_tom_cruise
# Kết quả từ ./datasets/data\person_15_tom_cruise\23.jpg:
#   - Dự đoán: person_15_tom_cruise (Score: 1.00)
#   - Thực tế: person_15_tom_cruise
# Kết quả từ ./datasets/data\person_15_tom_cruise\3.jpg:
#   - Dự đoán: person_15_tom_cruise (Score: 1.00)
#   - Thực tế: person_15_tom_cruise
# Kết quả từ ./datasets/data\person_15_tom_cruise\4.jpg:
#   - Dự đoán: person_15_tom_cruise (Score: 1.00)
#   - Thực tế: person_15_tom_cruise
# Kết quả từ ./datasets/data\person_15_tom_cruise\5.jpg:
#   - Dự đoán: person_15_tom_cruise (Score: 1.00)
#   - Thực tế: person_15_tom_cruise
# Kết quả từ ./datasets/data\person_15_tom_cruise\6.jpg:
#   - Dự đoán: person_15_tom_cruise (Score: 1.00)
#   - Thực tế: person_15_tom_cruise
# Kết quả từ ./datasets/data\person_15_tom_cruise\7.jpg:
#   - Dự đoán: person_15_tom_cruise (Score: 1.00)
#   - Thực tế: person_15_tom_cruise
# Kết quả từ ./datasets/data\person_15_tom_cruise\8.jpg:
#   - Dự đoán: person_15_tom_cruise (Score: 1.00)
#   - Thực tế: person_15_tom_cruise
# Kết quả từ ./datasets/data\person_15_tom_cruise\9.jpg:
#   - Dự đoán: person_15_tom_cruise (Score: 1.00)
#   - Thực tế: person_15_tom_cruise
# Kết quả từ ./datasets/data\person_16_chris\0.jpg:
#   - Dự đoán: person_16_chris (Score: 1.00)
#   - Thực tế: person_16_chris
# Kết quả từ ./datasets/data\person_16_chris\1.jpg:
#   - Dự đoán: person_16_chris (Score: 1.00)
#   - Thực tế: person_16_chris
# Kết quả từ ./datasets/data\person_16_chris\10.jpg:
#   - Dự đoán: person_16_chris (Score: 1.00)
#   - Thực tế: person_16_chris
# Kết quả từ ./datasets/data\person_16_chris\11.jpg:
#   - Dự đoán: person_16_chris (Score: 1.00)
#   - Thực tế: person_16_chris
# Kết quả từ ./datasets/data\person_16_chris\12.jpg:
#   - Dự đoán: person_16_chris (Score: 1.00)
#   - Thực tế: person_16_chris
# Kết quả từ ./datasets/data\person_16_chris\13.jpg:
#   - Dự đoán: person_16_chris (Score: 1.00)
#   - Thực tế: person_16_chris
# Kết quả từ ./datasets/data\person_16_chris\14.jpg:
#   - Dự đoán: person_16_chris (Score: 1.00)
#   - Thực tế: person_16_chris
# Kết quả từ ./datasets/data\person_16_chris\15.jpg:
#   - Dự đoán: person_16_chris (Score: 1.00)
#   - Thực tế: person_16_chris
# Kết quả từ ./datasets/data\person_16_chris\16.jpg:
#   - Dự đoán: person_16_chris (Score: 1.00)
#   - Thực tế: person_16_chris
# Kết quả từ ./datasets/data\person_16_chris\2.jpg:
#   - Dự đoán: person_16_chris (Score: 1.00)
#   - Thực tế: person_16_chris
# Kết quả từ ./datasets/data\person_16_chris\3.jpg:
#   - Dự đoán: person_16_chris (Score: 1.00)
#   - Thực tế: person_16_chris
# Kết quả từ ./datasets/data\person_16_chris\4.jpg:
#   - Dự đoán: person_16_chris (Score: 1.00)
#   - Thực tế: person_16_chris
# Kết quả từ ./datasets/data\person_16_chris\5.jpg:
#   - Dự đoán: person_16_chris (Score: 1.00)
#   - Thực tế: person_16_chris
# Kết quả từ ./datasets/data\person_16_chris\6.jpg:
#   - Dự đoán: person_16_chris (Score: 1.00)
#   - Thực tế: person_16_chris
# Kết quả từ ./datasets/data\person_16_chris\7.jpg:
#   - Dự đoán: person_16_chris (Score: 1.00)
#   - Thực tế: person_16_chris
# Kết quả từ ./datasets/data\person_16_chris\8.jpg:
#   - Dự đoán: person_16_chris (Score: 1.00)
#   - Thực tế: person_16_chris
# Kết quả từ ./datasets/data\person_16_chris\9.jpg:
#   - Dự đoán: person_16_chris (Score: 1.00)
#   - Thực tế: person_16_chris
# Kết quả từ ./datasets/data\person_17_bruno_mar\0.jpg:
#   - Dự đoán: person_17_bruno_mar (Score: 1.00)
#   - Thực tế: person_17_bruno_mar
# Kết quả từ ./datasets/data\person_17_bruno_mar\1.jpg:
#   - Dự đoán: person_17_bruno_mar (Score: 0.99)
#   - Thực tế: person_17_bruno_mar
# Kết quả từ ./datasets/data\person_17_bruno_mar\10.jpg:
#   - Dự đoán: person_17_bruno_mar (Score: 0.99)
#   - Thực tế: person_17_bruno_mar
# Kết quả từ ./datasets/data\person_17_bruno_mar\11.jpg:
#   - Dự đoán: person_17_bruno_mar (Score: 1.00)
#   - Thực tế: person_17_bruno_mar
# Kết quả từ ./datasets/data\person_17_bruno_mar\12.jpg:
#   - Dự đoán: person_17_bruno_mar (Score: 1.00)
#   - Thực tế: person_17_bruno_mar
# Kết quả từ ./datasets/data\person_17_bruno_mar\13.jpg:
#   - Dự đoán: person_17_bruno_mar (Score: 0.99)
#   - Thực tế: person_17_bruno_mar
# Kết quả từ ./datasets/data\person_17_bruno_mar\14.jpg:
#   - Dự đoán: person_17_bruno_mar (Score: 1.00)
#   - Thực tế: person_17_bruno_mar
# Kết quả từ ./datasets/data\person_17_bruno_mar\15.jpg:
#   - Dự đoán: person_17_bruno_mar (Score: 1.00)
#   - Thực tế: person_17_bruno_mar
# Kết quả từ ./datasets/data\person_17_bruno_mar\2.jpg:
#   - Dự đoán: person_17_bruno_mar (Score: 0.99)
#   - Thực tế: person_17_bruno_mar
# Kết quả từ ./datasets/data\person_17_bruno_mar\3.jpg:
#   - Dự đoán: person_17_bruno_mar (Score: 1.00)
#   - Thực tế: person_17_bruno_mar
# Kết quả từ ./datasets/data\person_17_bruno_mar\4.jpg:
#   - Dự đoán: person_17_bruno_mar (Score: 1.00)
#   - Thực tế: person_17_bruno_mar
# Kết quả từ ./datasets/data\person_17_bruno_mar\5.jpg:
#   - Dự đoán: person_17_bruno_mar (Score: 0.99)
#   - Thực tế: person_17_bruno_mar
# Kết quả từ ./datasets/data\person_17_bruno_mar\6.jpg:
#   - Dự đoán: person_17_bruno_mar (Score: 1.00)
#   - Thực tế: person_17_bruno_mar
# Kết quả từ ./datasets/data\person_17_bruno_mar\7.jpg:
#   - Dự đoán: person_17_bruno_mar (Score: 1.00)
#   - Thực tế: person_17_bruno_mar
# Kết quả từ ./datasets/data\person_17_bruno_mar\8.jpg:
#   - Dự đoán: person_17_bruno_mar (Score: 1.00)
#   - Thực tế: person_17_bruno_mar
# Kết quả từ ./datasets/data\person_17_bruno_mar\9.jpg:
#   - Dự đoán: person_17_bruno_mar (Score: 0.99)
#   - Thực tế: person_17_bruno_mar
# Kết quả từ ./datasets/data\person_19_sam_smith\0.jpg:
#   - Dự đoán: person_19_sam_smith (Score: 1.00)
#   - Thực tế: person_19_sam_smith
# Kết quả từ ./datasets/data\person_19_sam_smith\1.jpg:
#   - Dự đoán: person_19_sam_smith (Score: 1.00)
#   - Thực tế: person_19_sam_smith
# Kết quả từ ./datasets/data\person_19_sam_smith\10.jpg:
#   - Dự đoán: person_19_sam_smith (Score: 1.00)
#   - Thực tế: person_19_sam_smith
# Kết quả từ ./datasets/data\person_19_sam_smith\11.jpg:
#   - Dự đoán: person_19_sam_smith (Score: 1.00)
#   - Thực tế: person_19_sam_smith
# Kết quả từ ./datasets/data\person_19_sam_smith\12.jpg:
#   - Dự đoán: person_19_sam_smith (Score: 1.00)
#   - Thực tế: person_19_sam_smith
# Kết quả từ ./datasets/data\person_19_sam_smith\13.jpg:
#   - Dự đoán: person_19_sam_smith (Score: 1.00)
#   - Thực tế: person_19_sam_smith
# Kết quả từ ./datasets/data\person_19_sam_smith\14.jpg:
#   - Dự đoán: person_19_sam_smith (Score: 1.00)
#   - Thực tế: person_19_sam_smith
# Kết quả từ ./datasets/data\person_19_sam_smith\15.jpg:
#   - Dự đoán: person_19_sam_smith (Score: 1.00)
#   - Thực tế: person_19_sam_smith
# Kết quả từ ./datasets/data\person_19_sam_smith\16.jpg:
#   - Dự đoán: person_19_sam_smith (Score: 1.00)
#   - Thực tế: person_19_sam_smith
# Kết quả từ ./datasets/data\person_19_sam_smith\2.jpg:
#   - Dự đoán: person_19_sam_smith (Score: 1.00)
#   - Thực tế: person_19_sam_smith
# Kết quả từ ./datasets/data\person_19_sam_smith\3.jpg:
#   - Dự đoán: person_19_sam_smith (Score: 1.00)
#   - Thực tế: person_19_sam_smith
# Kết quả từ ./datasets/data\person_19_sam_smith\4.jpg:
#   - Dự đoán: person_19_sam_smith (Score: 1.00)
#   - Thực tế: person_19_sam_smith
# Kết quả từ ./datasets/data\person_19_sam_smith\5.jpg:
#   - Dự đoán: person_19_sam_smith (Score: 1.00)
#   - Thực tế: person_19_sam_smith
# Kết quả từ ./datasets/data\person_19_sam_smith\6.jpg:
#   - Dự đoán: person_19_sam_smith (Score: 1.00)
#   - Thực tế: person_19_sam_smith
# Kết quả từ ./datasets/data\person_19_sam_smith\7.jpg:
#   - Dự đoán: person_19_sam_smith (Score: 1.00)
#   - Thực tế: person_19_sam_smith
# Kết quả từ ./datasets/data\person_19_sam_smith\8.jpg:
#   - Dự đoán: person_19_sam_smith (Score: 1.00)
#   - Thực tế: person_19_sam_smith
# Kết quả từ ./datasets/data\person_19_sam_smith\9.jpg:
#   - Dự đoán: person_19_sam_smith (Score: 1.00)
#   - Thực tế: person_19_sam_smith
# Kết quả từ ./datasets/data\person_20_justin_bieber\0.jpg:
#   - Dự đoán: person_20_justin_bieber (Score: 1.00)
#   - Thực tế: person_20_justin_bieber
# Kết quả từ ./datasets/data\person_20_justin_bieber\1.jpg:
#   - Dự đoán: person_20_justin_bieber (Score: 1.00)
#   - Thực tế: person_20_justin_bieber
# Kết quả từ ./datasets/data\person_20_justin_bieber\10.jpg:
#   - Dự đoán: person_20_justin_bieber (Score: 1.00)
#   - Thực tế: person_20_justin_bieber
# Kết quả từ ./datasets/data\person_20_justin_bieber\11.jpg:
#   - Dự đoán: person_20_justin_bieber (Score: 1.00)
#   - Thực tế: person_20_justin_bieber
# Kết quả từ ./datasets/data\person_20_justin_bieber\12.jpg:
#   - Dự đoán: person_20_justin_bieber (Score: 1.00)
#   - Thực tế: person_20_justin_bieber
# Kết quả từ ./datasets/data\person_20_justin_bieber\13.jpg:
#   - Dự đoán: person_20_justin_bieber (Score: 1.00)
#   - Thực tế: person_20_justin_bieber
# Kết quả từ ./datasets/data\person_20_justin_bieber\14.jpg:
#   - Dự đoán: person_20_justin_bieber (Score: 1.00)
#   - Thực tế: person_20_justin_bieber
# Kết quả từ ./datasets/data\person_20_justin_bieber\15.jpg:
#   - Dự đoán: person_20_justin_bieber (Score: 1.00)
#   - Thực tế: person_20_justin_bieber
# Kết quả từ ./datasets/data\person_20_justin_bieber\16.jpg:
#   - Dự đoán: person_20_justin_bieber (Score: 1.00)
#   - Thực tế: person_20_justin_bieber
# Kết quả từ ./datasets/data\person_20_justin_bieber\17.jpg:
#   - Dự đoán: person_20_justin_bieber (Score: 1.00)
#   - Thực tế: person_20_justin_bieber
# Kết quả từ ./datasets/data\person_20_justin_bieber\18.jpg:
#   - Dự đoán: person_20_justin_bieber (Score: 1.00)
#   - Thực tế: person_20_justin_bieber
# Kết quả từ ./datasets/data\person_20_justin_bieber\19.jpg:
#   - Dự đoán: person_20_justin_bieber (Score: 1.00)
#   - Thực tế: person_20_justin_bieber
# Kết quả từ ./datasets/data\person_20_justin_bieber\2.jpg:
#   - Dự đoán: person_20_justin_bieber (Score: 1.00)
#   - Thực tế: person_20_justin_bieber
# Kết quả từ ./datasets/data\person_20_justin_bieber\20.jpg:
#   - Dự đoán: person_20_justin_bieber (Score: 1.00)
#   - Thực tế: person_20_justin_bieber
# Kết quả từ ./datasets/data\person_20_justin_bieber\21.jpg:
#   - Dự đoán: person_20_justin_bieber (Score: 1.00)
#   - Thực tế: person_20_justin_bieber
# Kết quả từ ./datasets/data\person_20_justin_bieber\3.jpg:
#   - Dự đoán: person_20_justin_bieber (Score: 1.00)
#   - Thực tế: person_20_justin_bieber
# Kết quả từ ./datasets/data\person_20_justin_bieber\4.jpg:
#   - Dự đoán: person_20_justin_bieber (Score: 1.00)
#   - Thực tế: person_20_justin_bieber
# Kết quả từ ./datasets/data\person_20_justin_bieber\5.jpg:
#   - Dự đoán: person_20_justin_bieber (Score: 1.00)
#   - Thực tế: person_20_justin_bieber
# Kết quả từ ./datasets/data\person_20_justin_bieber\6.jpg:
#   - Dự đoán: person_20_justin_bieber (Score: 1.00)
#   - Thực tế: person_20_justin_bieber
# Kết quả từ ./datasets/data\person_20_justin_bieber\7.jpg:
#   - Dự đoán: person_20_justin_bieber (Score: 1.00)
#   - Thực tế: person_20_justin_bieber
# Kết quả từ ./datasets/data\person_20_justin_bieber\8.jpg:
#   - Dự đoán: person_20_justin_bieber (Score: 1.00)
#   - Thực tế: person_20_justin_bieber
# Kết quả từ ./datasets/data\person_20_justin_bieber\9.jpg:
#   - Dự đoán: person_20_justin_bieber (Score: 1.00)
#   - Thực tế: person_20_justin_bieber
# Kết quả từ ./datasets/data\person_22_atus\0.jpg:
#   - Dự đoán: person_22_atus (Score: 1.00)
#   - Thực tế: person_22_atus
# Kết quả từ ./datasets/data\person_22_atus\1.jpg:
#   - Dự đoán: person_22_atus (Score: 1.00)
#   - Thực tế: person_22_atus
# Kết quả từ ./datasets/data\person_22_atus\10.jpg:
#   - Dự đoán: person_22_atus (Score: 1.00)
#   - Thực tế: person_22_atus
# Kết quả từ ./datasets/data\person_22_atus\11.jpg:
#   - Dự đoán: person_22_atus (Score: 1.00)
#   - Thực tế: person_22_atus
# Kết quả từ ./datasets/data\person_22_atus\12.jpg:
#   - Dự đoán: person_22_atus (Score: 1.00)
#   - Thực tế: person_22_atus
# Kết quả từ ./datasets/data\person_22_atus\13.jpg:
#   - Dự đoán: person_22_atus (Score: 1.00)
#   - Thực tế: person_22_atus
# Kết quả từ ./datasets/data\person_22_atus\14.jpg:
#   - Dự đoán: person_22_atus (Score: 1.00)
#   - Thực tế: person_22_atus
# Kết quả từ ./datasets/data\person_22_atus\2.jpg:
#   - Dự đoán: person_22_atus (Score: 1.00)
#   - Thực tế: person_22_atus
# Kết quả từ ./datasets/data\person_22_atus\3.jpg:
#   - Dự đoán: person_22_atus (Score: 1.00)
#   - Thực tế: person_22_atus
# Kết quả từ ./datasets/data\person_22_atus\4.jpg:
#   - Dự đoán: person_22_atus (Score: 1.00)
#   - Thực tế: person_22_atus
# Kết quả từ ./datasets/data\person_22_atus\5.jpg:
#   - Dự đoán: person_22_atus (Score: 1.00)
#   - Thực tế: person_22_atus
# Kết quả từ ./datasets/data\person_22_atus\6.jpg:
#   - Dự đoán: person_22_atus (Score: 1.00)
#   - Thực tế: person_22_atus
# Kết quả từ ./datasets/data\person_22_atus\7.jpg:
#   - Dự đoán: person_22_atus (Score: 1.00)
#   - Thực tế: person_22_atus
# Kết quả từ ./datasets/data\person_22_atus\8.jpg:
#   - Dự đoán: person_22_atus (Score: 1.00)
#   - Thực tế: person_22_atus
# Kết quả từ ./datasets/data\person_22_atus\9.jpg:
#   - Dự đoán: person_22_atus (Score: 1.00)
#   - Thực tế: person_22_atus
# Kết quả từ ./datasets/data\person_23_h2h\0.jpg:
#   - Dự đoán: person_23_h2h (Score: 1.00)
#   - Thực tế: person_23_h2h
# Kết quả từ ./datasets/data\person_23_h2h\1.jpg:
#   - Dự đoán: person_23_h2h (Score: 1.00)
#   - Thực tế: person_23_h2h
# Kết quả từ ./datasets/data\person_23_h2h\10.jpg:
#   - Dự đoán: person_23_h2h (Score: 1.00)
#   - Thực tế: person_23_h2h
# Kết quả từ ./datasets/data\person_23_h2h\11.jpg:
#   - Dự đoán: person_23_h2h (Score: 1.00)
#   - Thực tế: person_23_h2h
# Kết quả từ ./datasets/data\person_23_h2h\12.jpg:
#   - Dự đoán: person_23_h2h (Score: 1.00)
#   - Thực tế: person_23_h2h
# Kết quả từ ./datasets/data\person_23_h2h\2.jpg:
#   - Dự đoán: person_23_h2h (Score: 1.00)
#   - Thực tế: person_23_h2h
# Kết quả từ ./datasets/data\person_23_h2h\3.jpg:
#   - Dự đoán: person_23_h2h (Score: 1.00)
#   - Thực tế: person_23_h2h
# Kết quả từ ./datasets/data\person_23_h2h\4.jpg:
#   - Dự đoán: person_23_h2h (Score: 1.00)
#   - Thực tế: person_23_h2h
# Kết quả từ ./datasets/data\person_23_h2h\5.jpg:
#   - Dự đoán: person_23_h2h (Score: 1.00)
#   - Thực tế: person_23_h2h
# Kết quả từ ./datasets/data\person_23_h2h\6.jpg:
#   - Dự đoán: person_23_h2h (Score: 1.00)
#   - Thực tế: person_23_h2h
# Kết quả từ ./datasets/data\person_23_h2h\7.jpg:
#   - Dự đoán: person_23_h2h (Score: 1.00)
#   - Thực tế: person_23_h2h
# Kết quả từ ./datasets/data\person_23_h2h\8.jpg:
#   - Dự đoán: person_23_h2h (Score: 1.00)
#   - Thực tế: person_23_h2h
# Kết quả từ ./datasets/data\person_23_h2h\9.jpg:
#   - Dự đoán: person_23_h2h (Score: 1.00)
#   - Thực tế: person_23_h2h
# Kết quả từ ./datasets/data\person_26_suboi\0.jpg:
#   - Dự đoán: person_26_suboi (Score: 1.00)
#   - Thực tế: person_26_suboi
# Kết quả từ ./datasets/data\person_26_suboi\1.jpg:
#   - Dự đoán: person_26_suboi (Score: 1.00)
#   - Thực tế: person_26_suboi
# Kết quả từ ./datasets/data\person_26_suboi\10.jpg:
#   - Dự đoán: person_26_suboi (Score: 1.00)
#   - Thực tế: person_26_suboi
# Kết quả từ ./datasets/data\person_26_suboi\11.jpg:
#   - Dự đoán: person_26_suboi (Score: 1.00)
#   - Thực tế: person_26_suboi
# Kết quả từ ./datasets/data\person_26_suboi\12.jpg:
#   - Dự đoán: person_26_suboi (Score: 1.00)
#   - Thực tế: person_26_suboi
# Kết quả từ ./datasets/data\person_26_suboi\13.jpg:
#   - Dự đoán: person_26_suboi (Score: 1.00)
#   - Thực tế: person_26_suboi
# Kết quả từ ./datasets/data\person_26_suboi\14.jpg:
#   - Dự đoán: person_26_suboi (Score: 1.00)
#   - Thực tế: person_26_suboi
# Kết quả từ ./datasets/data\person_26_suboi\15.jpg:
#   - Dự đoán: person_26_suboi (Score: 1.00)
#   - Thực tế: person_26_suboi
# Kết quả từ ./datasets/data\person_26_suboi\16.jpg:
#   - Dự đoán: person_26_suboi (Score: 1.00)
#   - Thực tế: person_26_suboi
# Kết quả từ ./datasets/data\person_26_suboi\17.jpg:
#   - Dự đoán: person_26_suboi (Score: 1.00)
#   - Thực tế: person_26_suboi
# Kết quả từ ./datasets/data\person_26_suboi\18.jpg:
#   - Dự đoán: person_26_suboi (Score: 1.00)
#   - Thực tế: person_26_suboi
# Kết quả từ ./datasets/data\person_26_suboi\19.jpg:
#   - Dự đoán: person_26_suboi (Score: 1.00)
#   - Thực tế: person_26_suboi
# Kết quả từ ./datasets/data\person_26_suboi\2.jpg:
#   - Dự đoán: person_26_suboi (Score: 1.00)
#   - Thực tế: person_26_suboi
# Kết quả từ ./datasets/data\person_26_suboi\20.jpg:
#   - Dự đoán: person_26_suboi (Score: 1.00)
#   - Thực tế: person_26_suboi
# Kết quả từ ./datasets/data\person_26_suboi\21.jpg:
#   - Dự đoán: person_26_suboi (Score: 1.00)
#   - Thực tế: person_26_suboi
# Kết quả từ ./datasets/data\person_26_suboi\22.jpg:
#   - Dự đoán: person_26_suboi (Score: 1.00)
#   - Thực tế: person_26_suboi
# Kết quả từ ./datasets/data\person_26_suboi\23.jpg:
#   - Dự đoán: person_26_suboi (Score: 1.00)
#   - Thực tế: person_26_suboi
# Kết quả từ ./datasets/data\person_26_suboi\24.jpg:
#   - Dự đoán: person_26_suboi (Score: 1.00)
#   - Thực tế: person_26_suboi
# Kết quả từ ./datasets/data\person_26_suboi\25.jpg:
#   - Dự đoán: person_26_suboi (Score: 1.00)
#   - Thực tế: person_26_suboi
# Kết quả từ ./datasets/data\person_26_suboi\3.jpg:
#   - Dự đoán: person_26_suboi (Score: 1.00)
#   - Thực tế: person_26_suboi
# Kết quả từ ./datasets/data\person_26_suboi\4.jpg:
#   - Dự đoán: person_26_suboi (Score: 1.00)
#   - Thực tế: person_26_suboi
# Kết quả từ ./datasets/data\person_26_suboi\5.jpg:
#   - Dự đoán: person_26_suboi (Score: 1.00)
#   - Thực tế: person_26_suboi
# Kết quả từ ./datasets/data\person_26_suboi\6.jpg:
#   - Dự đoán: person_26_suboi (Score: 1.00)
#   - Thực tế: person_26_suboi
# Kết quả từ ./datasets/data\person_26_suboi\7.jpg:
#   - Dự đoán: person_26_suboi (Score: 1.00)
#   - Thực tế: person_26_suboi
# Kết quả từ ./datasets/data\person_26_suboi\8.jpg:
#   - Dự đoán: person_26_suboi (Score: 1.00)
#   - Thực tế: person_26_suboi
# Kết quả từ ./datasets/data\person_26_suboi\9.jpg:
#   - Dự đoán: person_26_suboi (Score: 1.00)
#   - Thực tế: person_26_suboi
# Kết quả từ ./datasets/data\person_27_mck\0.jpg:
#   - Dự đoán: person_27_mck (Score: 1.00)
#   - Thực tế: person_27_mck
# Kết quả từ ./datasets/data\person_27_mck\1.jpg:
#   - Dự đoán: person_27_mck (Score: 1.00)
#   - Thực tế: person_27_mck
# Kết quả từ ./datasets/data\person_27_mck\10.jpg:
#   - Dự đoán: person_27_mck (Score: 1.00)
#   - Thực tế: person_27_mck
# Kết quả từ ./datasets/data\person_27_mck\11.jpg:
#   - Dự đoán: person_27_mck (Score: 1.00)
#   - Thực tế: person_27_mck
# Kết quả từ ./datasets/data\person_27_mck\12.jpg:
#   - Dự đoán: person_27_mck (Score: 1.00)
#   - Thực tế: person_27_mck
# Kết quả từ ./datasets/data\person_27_mck\13.jpg:
#   - Dự đoán: person_27_mck (Score: 1.00)
#   - Thực tế: person_27_mck
# Kết quả từ ./datasets/data\person_27_mck\14.jpg:
#   - Dự đoán: person_27_mck (Score: 1.00)
#   - Thực tế: person_27_mck
# Kết quả từ ./datasets/data\person_27_mck\15.jpg:
#   - Dự đoán: person_27_mck (Score: 1.00)
#   - Thực tế: person_27_mck
# Kết quả từ ./datasets/data\person_27_mck\16.jpg:
#   - Dự đoán: person_27_mck (Score: 1.00)
#   - Thực tế: person_27_mck
# Kết quả từ ./datasets/data\person_27_mck\2.jpg:
#   - Dự đoán: person_27_mck (Score: 1.00)
#   - Thực tế: person_27_mck
# Kết quả từ ./datasets/data\person_27_mck\3.jpg:
#   - Dự đoán: person_27_mck (Score: 1.00)
#   - Thực tế: person_27_mck
# Kết quả từ ./datasets/data\person_27_mck\4.jpg:
#   - Dự đoán: person_27_mck (Score: 1.00)
#   - Thực tế: person_27_mck
# Kết quả từ ./datasets/data\person_27_mck\5.jpg:
#   - Dự đoán: person_27_mck (Score: 1.00)
#   - Thực tế: person_27_mck
# Kết quả từ ./datasets/data\person_27_mck\6.jpg:
#   - Dự đoán: person_27_mck (Score: 1.00)
#   - Thực tế: person_27_mck
# Kết quả từ ./datasets/data\person_27_mck\7.jpg:
#   - Dự đoán: person_27_mck (Score: 1.00)
#   - Thực tế: person_27_mck
# Kết quả từ ./datasets/data\person_27_mck\8.jpg:
#   - Dự đoán: person_27_mck (Score: 1.00)
#   - Thực tế: person_27_mck
# Kết quả từ ./datasets/data\person_27_mck\9.jpg:
#   - Dự đoán: person_27_mck (Score: 1.00)
#   - Thực tế: person_27_mck
# Kết quả từ ./datasets/data\person_30_erik\0.jpg:
#   - Dự đoán: person_30_erik (Score: 1.00)
#   - Thực tế: person_30_erik
# Kết quả từ ./datasets/data\person_30_erik\1.jpg:
#   - Dự đoán: person_30_erik (Score: 1.00)
#   - Thực tế: person_30_erik
# Kết quả từ ./datasets/data\person_30_erik\10.jpg:
#   - Dự đoán: person_30_erik (Score: 1.00)
#   - Thực tế: person_30_erik
# Kết quả từ ./datasets/data\person_30_erik\11.jpg:
#   - Dự đoán: person_30_erik (Score: 1.00)
#   - Thực tế: person_30_erik
# Kết quả từ ./datasets/data\person_30_erik\12.jpg:
#   - Dự đoán: person_30_erik (Score: 1.00)
#   - Thực tế: person_30_erik
# Kết quả từ ./datasets/data\person_30_erik\13.jpg:
#   - Dự đoán: person_30_erik (Score: 1.00)
#   - Thực tế: person_30_erik
# Kết quả từ ./datasets/data\person_30_erik\14.jpg:
#   - Dự đoán: person_30_erik (Score: 1.00)
#   - Thực tế: person_30_erik
# Kết quả từ ./datasets/data\person_30_erik\15.jpg:
#   - Dự đoán: person_30_erik (Score: 1.00)
#   - Thực tế: person_30_erik
# Kết quả từ ./datasets/data\person_30_erik\16.jpg:
#   - Dự đoán: person_30_erik (Score: 1.00)
#   - Thực tế: person_30_erik
# Kết quả từ ./datasets/data\person_30_erik\17.jpg:
#   - Dự đoán: person_30_erik (Score: 1.00)
#   - Thực tế: person_30_erik
# Kết quả từ ./datasets/data\person_30_erik\18.jpg:
#   - Dự đoán: person_30_erik (Score: 1.00)
#   - Thực tế: person_30_erik
# Kết quả từ ./datasets/data\person_30_erik\19.jpg:
#   - Dự đoán: person_30_erik (Score: 1.00)
#   - Thực tế: person_30_erik
# Kết quả từ ./datasets/data\person_30_erik\2.jpg:
#   - Dự đoán: person_30_erik (Score: 1.00)
#   - Thực tế: person_30_erik
# Kết quả từ ./datasets/data\person_30_erik\20.jpg:
#   - Dự đoán: person_30_erik (Score: 1.00)
#   - Thực tế: person_30_erik
# Kết quả từ ./datasets/data\person_30_erik\21.jpg:
#   - Dự đoán: person_30_erik (Score: 1.00)
#   - Thực tế: person_30_erik
# Kết quả từ ./datasets/data\person_30_erik\22.jpg:
#   - Dự đoán: person_30_erik (Score: 1.00)
#   - Thực tế: person_30_erik
# Kết quả từ ./datasets/data\person_30_erik\23.jpg:
#   - Dự đoán: person_30_erik (Score: 1.00)
#   - Thực tế: person_30_erik
# Kết quả từ ./datasets/data\person_30_erik\24.jpg:
#   - Dự đoán: person_30_erik (Score: 1.00)
#   - Thực tế: person_30_erik
# Kết quả từ ./datasets/data\person_30_erik\25.jpg:
#   - Dự đoán: person_30_erik (Score: 1.00)
#   - Thực tế: person_30_erik
# Kết quả từ ./datasets/data\person_30_erik\26.jpg:
#   - Dự đoán: person_30_erik (Score: 1.00)
#   - Thực tế: person_30_erik
# Kết quả từ ./datasets/data\person_30_erik\27.jpg:
#   - Dự đoán: person_30_erik (Score: 1.00)
#   - Thực tế: person_30_erik
# Kết quả từ ./datasets/data\person_30_erik\28.jpg:
#   - Dự đoán: person_30_erik (Score: 1.00)
#   - Thực tế: person_30_erik
# Kết quả từ ./datasets/data\person_30_erik\29.jpg:
#   - Dự đoán: person_30_erik (Score: 1.00)
#   - Thực tế: person_30_erik
# Kết quả từ ./datasets/data\person_30_erik\3.jpg:
#   - Dự đoán: person_30_erik (Score: 1.00)
#   - Thực tế: person_30_erik
# Kết quả từ ./datasets/data\person_30_erik\4.jpg:
#   - Dự đoán: person_30_erik (Score: 1.00)
#   - Thực tế: person_30_erik
# Kết quả từ ./datasets/data\person_30_erik\5.jpg:
#   - Dự đoán: person_30_erik (Score: 1.00)
#   - Thực tế: person_30_erik
# Kết quả từ ./datasets/data\person_30_erik\6.jpg:
#   - Dự đoán: person_30_erik (Score: 1.00)
#   - Thực tế: person_30_erik
# Kết quả từ ./datasets/data\person_30_erik\7.jpg:
#   - Dự đoán: person_30_erik (Score: 1.00)
#   - Thực tế: person_30_erik
# Kết quả từ ./datasets/data\person_30_erik\8.jpg:
#   - Dự đoán: person_30_erik (Score: 1.00)
#   - Thực tế: person_30_erik
# Kết quả từ ./datasets/data\person_30_erik\9.jpg:
#   - Dự đoán: person_30_erik (Score: 1.00)
#   - Thực tế: person_30_erik
# Kết quả từ ./datasets/data\person_31_anh_tu\0.jpg:
#   - Dự đoán: person_31_anh_tu (Score: 1.00)
#   - Thực tế: person_31_anh_tu
# Kết quả từ ./datasets/data\person_31_anh_tu\1.jpg:
#   - Dự đoán: person_31_anh_tu (Score: 1.00)
#   - Thực tế: person_31_anh_tu
# Kết quả từ ./datasets/data\person_31_anh_tu\10.jpg:
#   - Dự đoán: person_31_anh_tu (Score: 1.00)
#   - Thực tế: person_31_anh_tu
# Kết quả từ ./datasets/data\person_31_anh_tu\11.jpg:
#   - Dự đoán: person_31_anh_tu (Score: 1.00)
#   - Thực tế: person_31_anh_tu
# Kết quả từ ./datasets/data\person_31_anh_tu\12.jpg:
#   - Dự đoán: person_31_anh_tu (Score: 1.00)
#   - Thực tế: person_31_anh_tu
# Kết quả từ ./datasets/data\person_31_anh_tu\13.jpg:
#   - Dự đoán: person_31_anh_tu (Score: 1.00)
#   - Thực tế: person_31_anh_tu
# Kết quả từ ./datasets/data\person_31_anh_tu\14.jpg:
#   - Dự đoán: person_31_anh_tu (Score: 1.00)
#   - Thực tế: person_31_anh_tu
# Kết quả từ ./datasets/data\person_31_anh_tu\15.jpg:
#   - Dự đoán: person_31_anh_tu (Score: 1.00)
#   - Thực tế: person_31_anh_tu
# Kết quả từ ./datasets/data\person_31_anh_tu\16.jpg:
#   - Dự đoán: person_31_anh_tu (Score: 1.00)
#   - Thực tế: person_31_anh_tu
# Kết quả từ ./datasets/data\person_31_anh_tu\17.jpg:
#   - Dự đoán: person_31_anh_tu (Score: 1.00)
#   - Thực tế: person_31_anh_tu
# Kết quả từ ./datasets/data\person_31_anh_tu\18.jpg:
#   - Dự đoán: person_31_anh_tu (Score: 1.00)
#   - Thực tế: person_31_anh_tu
# Kết quả từ ./datasets/data\person_31_anh_tu\19.jpg:
#   - Dự đoán: person_31_anh_tu (Score: 1.00)
#   - Thực tế: person_31_anh_tu
# Kết quả từ ./datasets/data\person_31_anh_tu\2.jpg:
#   - Dự đoán: person_31_anh_tu (Score: 1.00)
#   - Thực tế: person_31_anh_tu
# Kết quả từ ./datasets/data\person_31_anh_tu\20.jpg:
#   - Dự đoán: person_31_anh_tu (Score: 1.00)
#   - Thực tế: person_31_anh_tu
# Kết quả từ ./datasets/data\person_31_anh_tu\21.jpg:
#   - Dự đoán: person_31_anh_tu (Score: 1.00)
#   - Thực tế: person_31_anh_tu
# Kết quả từ ./datasets/data\person_31_anh_tu\22.jpg:
#   - Dự đoán: person_31_anh_tu (Score: 1.00)
#   - Thực tế: person_31_anh_tu
# Kết quả từ ./datasets/data\person_31_anh_tu\23.jpg:
#   - Dự đoán: person_31_anh_tu (Score: 1.00)
#   - Thực tế: person_31_anh_tu
# Kết quả từ ./datasets/data\person_31_anh_tu\24.jpg:
#   - Dự đoán: person_31_anh_tu (Score: 1.00)
#   - Thực tế: person_31_anh_tu
# Kết quả từ ./datasets/data\person_31_anh_tu\25.jpg:
#   - Dự đoán: person_31_anh_tu (Score: 1.00)
#   - Thực tế: person_31_anh_tu
# Kết quả từ ./datasets/data\person_31_anh_tu\26.jpg:
#   - Dự đoán: person_31_anh_tu (Score: 1.00)
#   - Thực tế: person_31_anh_tu
# Kết quả từ ./datasets/data\person_31_anh_tu\27.jpg:
#   - Dự đoán: person_31_anh_tu (Score: 1.00)
#   - Thực tế: person_31_anh_tu
# Kết quả từ ./datasets/data\person_31_anh_tu\3.jpg:
#   - Dự đoán: person_31_anh_tu (Score: 1.00)
#   - Thực tế: person_31_anh_tu
# Kết quả từ ./datasets/data\person_31_anh_tu\4.jpg:
#   - Dự đoán: person_31_anh_tu (Score: 1.00)
#   - Thực tế: person_31_anh_tu
# Kết quả từ ./datasets/data\person_31_anh_tu\5.jpg:
#   - Dự đoán: person_31_anh_tu (Score: 1.00)
#   - Thực tế: person_31_anh_tu
# Kết quả từ ./datasets/data\person_31_anh_tu\6.jpg:
#   - Dự đoán: person_31_anh_tu (Score: 1.00)
#   - Thực tế: person_31_anh_tu
# Kết quả từ ./datasets/data\person_31_anh_tu\7.jpg:
#   - Dự đoán: person_31_anh_tu (Score: 1.00)
#   - Thực tế: person_31_anh_tu
# Kết quả từ ./datasets/data\person_31_anh_tu\8.jpg:
#   - Dự đoán: person_31_anh_tu (Score: 1.00)
#   - Thực tế: person_31_anh_tu
# Kết quả từ ./datasets/data\person_31_anh_tu\9.jpg:
#   - Dự đoán: person_31_anh_tu (Score: 1.00)
#   - Thực tế: person_31_anh_tu
# Kết quả từ ./datasets/data\person_32_andrew_garfiled\0.jpg:
#   - Dự đoán: person_32_andrew_garfiled (Score: 1.00)
#   - Thực tế: person_32_andrew_garfiled
# Kết quả từ ./datasets/data\person_32_andrew_garfiled\1.jpg:
#   - Dự đoán: person_32_andrew_garfiled (Score: 1.00)
#   - Thực tế: person_32_andrew_garfiled
# Kết quả từ ./datasets/data\person_32_andrew_garfiled\10.jpg:
#   - Dự đoán: person_32_andrew_garfiled (Score: 1.00)
#   - Thực tế: person_32_andrew_garfiled
# Kết quả từ ./datasets/data\person_32_andrew_garfiled\11.jpg:
#   - Dự đoán: person_32_andrew_garfiled (Score: 1.00)
#   - Thực tế: person_32_andrew_garfiled
# Kết quả từ ./datasets/data\person_32_andrew_garfiled\12.jpg:
#   - Dự đoán: person_32_andrew_garfiled (Score: 1.00)
#   - Thực tế: person_32_andrew_garfiled
# Kết quả từ ./datasets/data\person_32_andrew_garfiled\13.jpg:
#   - Dự đoán: person_32_andrew_garfiled (Score: 1.00)
#   - Thực tế: person_32_andrew_garfiled
# Kết quả từ ./datasets/data\person_32_andrew_garfiled\14.jpg:
#   - Dự đoán: person_32_andrew_garfiled (Score: 1.00)
#   - Thực tế: person_32_andrew_garfiled
# Kết quả từ ./datasets/data\person_32_andrew_garfiled\15.jpg:
#   - Dự đoán: person_32_andrew_garfiled (Score: 1.00)
#   - Thực tế: person_32_andrew_garfiled
# Kết quả từ ./datasets/data\person_32_andrew_garfiled\16.jpg:
#   - Dự đoán: person_32_andrew_garfiled (Score: 1.00)
#   - Thực tế: person_32_andrew_garfiled
# Kết quả từ ./datasets/data\person_32_andrew_garfiled\17.jpg:
#   - Dự đoán: person_32_andrew_garfiled (Score: 1.00)
#   - Thực tế: person_32_andrew_garfiled
# Kết quả từ ./datasets/data\person_32_andrew_garfiled\18.jpg:
#   - Dự đoán: person_32_andrew_garfiled (Score: 1.00)
#   - Thực tế: person_32_andrew_garfiled
# Kết quả từ ./datasets/data\person_32_andrew_garfiled\2.jpg:
#   - Dự đoán: person_32_andrew_garfiled (Score: 1.00)
#   - Thực tế: person_32_andrew_garfiled
# Kết quả từ ./datasets/data\person_32_andrew_garfiled\3.jpg:
#   - Dự đoán: person_32_andrew_garfiled (Score: 1.00)
#   - Thực tế: person_32_andrew_garfiled
# Kết quả từ ./datasets/data\person_32_andrew_garfiled\4.jpg:
#   - Dự đoán: person_32_andrew_garfiled (Score: 1.00)
#   - Thực tế: person_32_andrew_garfiled
# ...
#   - Dự đoán: person_46_nam_phuong (Score: 1.00)
#   - Thực tế: person_46_nam_phuong
# Kết quả từ ./datasets/data\person_46_nam_phuong\34.jpg:
#   - Dự đoán: person_46_nam_phuong (Score: 1.00)
#   - Thực tế: person_46_nam_phuong
# Kết quả từ ./datasets/data\person_46_nam_phuong\35.jpg:
#   - Dự đoán: person_46_nam_phuong (Score: 1.00)
#   - Thực tế: person_46_nam_phuong
# Kết quả từ ./datasets/data\person_46_nam_phuong\36.jpg:
#   - Dự đoán: person_46_nam_phuong (Score: 1.00)
#   - Thực tế: person_46_nam_phuong
# Kết quả từ ./datasets/data\person_46_nam_phuong\37.jpg:
#   - Dự đoán: person_46_nam_phuong (Score: 1.00)
#   - Thực tế: person_46_nam_phuong
# Kết quả từ ./datasets/data\person_46_nam_phuong\38.jpg:
#   - Dự đoán: person_46_nam_phuong (Score: 1.00)
#   - Thực tế: person_46_nam_phuong
# Kết quả từ ./datasets/data\person_46_nam_phuong\39.jpg:
#   - Dự đoán: person_46_nam_phuong (Score: 1.00)
#   - Thực tế: person_46_nam_phuong
# Kết quả từ ./datasets/data\person_46_nam_phuong\4.jpg:
#   - Dự đoán: person_46_nam_phuong (Score: 1.00)
#   - Thực tế: person_46_nam_phuong
# Kết quả từ ./datasets/data\person_46_nam_phuong\40.jpg:
#   - Dự đoán: person_46_nam_phuong (Score: 1.00)
#   - Thực tế: person_46_nam_phuong
# Kết quả từ ./datasets/data\person_46_nam_phuong\41.jpg:
#   - Dự đoán: person_46_nam_phuong (Score: 1.00)
#   - Thực tế: person_46_nam_phuong
# Kết quả từ ./datasets/data\person_46_nam_phuong\42.jpg:
#   - Dự đoán: person_46_nam_phuong (Score: 1.00)
#   - Thực tế: person_46_nam_phuong
# Kết quả từ ./datasets/data\person_46_nam_phuong\43.jpg:
#   - Dự đoán: person_46_nam_phuong (Score: 1.00)
#   - Thực tế: person_46_nam_phuong
# Kết quả từ ./datasets/data\person_46_nam_phuong\5.jpg:
#   - Dự đoán: person_46_nam_phuong (Score: 1.00)
#   - Thực tế: person_46_nam_phuong
# Kết quả từ ./datasets/data\person_46_nam_phuong\6.jpg:
#   - Dự đoán: person_46_nam_phuong (Score: 1.00)
#   - Thực tế: person_46_nam_phuong
# Kết quả từ ./datasets/data\person_46_nam_phuong\7.jpg:
#   - Dự đoán: person_46_nam_phuong (Score: 0.99)
#   - Thực tế: person_46_nam_phuong
# Kết quả từ ./datasets/data\person_46_nam_phuong\8.jpg:
#   - Dự đoán: person_46_nam_phuong (Score: 0.99)
#   - Thực tế: person_46_nam_phuong
# Kết quả từ ./datasets/data\person_46_nam_phuong\9.jpg:
#   - Dự đoán: person_46_nam_phuong (Score: 1.00)
#   - Thực tế: person_46_nam_phuong
# Kết quả từ ./datasets/data\person_4_nhu\0.jpg:
#   - Dự đoán: person_4_Nhu (Score: 1.00)
#   - Thực tế: person_4_nhu
# Kết quả từ ./datasets/data\person_4_nhu\1.jpg:
#   - Dự đoán: person_4_Nhu (Score: 1.00)
#   - Thực tế: person_4_nhu
# Kết quả từ ./datasets/data\person_4_nhu\10.jpg:
#   - Dự đoán: person_4_Nhu (Score: 1.00)
#   - Thực tế: person_4_nhu
# Kết quả từ ./datasets/data\person_4_nhu\11.jpg:
#   - Dự đoán: person_4_Nhu (Score: 1.00)
#   - Thực tế: person_4_nhu
# Kết quả từ ./datasets/data\person_4_nhu\12.jpg:
#   - Dự đoán: person_4_Nhu (Score: 1.00)
#   - Thực tế: person_4_nhu
# Kết quả từ ./datasets/data\person_4_nhu\13.jpg:
#   - Dự đoán: person_4_Nhu (Score: 1.00)
#   - Thực tế: person_4_nhu
# Kết quả từ ./datasets/data\person_4_nhu\14.jpg:
#   - Dự đoán: person_4_Nhu (Score: 1.00)
#   - Thực tế: person_4_nhu
# Kết quả từ ./datasets/data\person_4_nhu\15.jpg:
#   - Dự đoán: person_4_Nhu (Score: 1.00)
#   - Thực tế: person_4_nhu
# Kết quả từ ./datasets/data\person_4_nhu\2.jpg:
#   - Dự đoán: person_4_Nhu (Score: 1.00)
#   - Thực tế: person_4_nhu
# Kết quả từ ./datasets/data\person_4_nhu\3.jpg:
#   - Dự đoán: person_4_Nhu (Score: 1.00)
#   - Thực tế: person_4_nhu
# Kết quả từ ./datasets/data\person_4_nhu\4.jpg:
#   - Dự đoán: person_4_Nhu (Score: 1.00)
#   - Thực tế: person_4_nhu
# Kết quả từ ./datasets/data\person_4_nhu\5.jpg:
#   - Dự đoán: person_4_Nhu (Score: 1.00)
#   - Thực tế: person_4_nhu
# Kết quả từ ./datasets/data\person_4_nhu\6.jpg:
#   - Dự đoán: person_4_Nhu (Score: 1.00)
#   - Thực tế: person_4_nhu
# Kết quả từ ./datasets/data\person_4_nhu\7.jpg:
#   - Dự đoán: person_4_Nhu (Score: 1.00)
#   - Thực tế: person_4_nhu
# Kết quả từ ./datasets/data\person_4_nhu\8.jpg:
#   - Dự đoán: person_4_Nhu (Score: 1.00)
#   - Thực tế: person_4_nhu
# Kết quả từ ./datasets/data\person_4_nhu\9.jpg:
#   - Dự đoán: person_4_Nhu (Score: 1.00)
#   - Thực tế: person_4_nhu
# Kết quả từ ./datasets/data\person_50_qanh\0.jpg:
#   - Dự đoán: person_50_qanh (Score: 1.00)
#   - Thực tế: person_50_qanh
# Kết quả từ ./datasets/data\person_50_qanh\1.jpg:
#   - Dự đoán: person_50_qanh (Score: 1.00)
#   - Thực tế: person_50_qanh
# Kết quả từ ./datasets/data\person_50_qanh\10.jpg:
#   - Dự đoán: person_50_qanh (Score: 1.00)
#   - Thực tế: person_50_qanh
# Kết quả từ ./datasets/data\person_50_qanh\11.jpg:
#   - Dự đoán: person_50_qanh (Score: 1.00)
#   - Thực tế: person_50_qanh
# Kết quả từ ./datasets/data\person_50_qanh\12.jpg:
#   - Dự đoán: person_50_qanh (Score: 1.00)
#   - Thực tế: person_50_qanh
# Kết quả từ ./datasets/data\person_50_qanh\2.jpg:
#   - Dự đoán: person_50_qanh (Score: 1.00)
#   - Thực tế: person_50_qanh
# Kết quả từ ./datasets/data\person_50_qanh\3.jpg:
#   - Dự đoán: person_50_qanh (Score: 1.00)
#   - Thực tế: person_50_qanh
# Kết quả từ ./datasets/data\person_50_qanh\4.jpg:
#   - Dự đoán: person_50_qanh (Score: 1.00)
#   - Thực tế: person_50_qanh
# Kết quả từ ./datasets/data\person_50_qanh\5.jpg:
#   - Dự đoán: person_50_qanh (Score: 1.00)
#   - Thực tế: person_50_qanh
# Kết quả từ ./datasets/data\person_50_qanh\6.jpg:
#   - Dự đoán: person_50_qanh (Score: 1.00)
#   - Thực tế: person_50_qanh
# Kết quả từ ./datasets/data\person_50_qanh\7.jpg:
#   - Dự đoán: person_50_qanh (Score: 1.00)
#   - Thực tế: person_50_qanh
# Kết quả từ ./datasets/data\person_50_qanh\8.jpg:
#   - Dự đoán: person_50_qanh (Score: 1.00)
#   - Thực tế: person_50_qanh
# Kết quả từ ./datasets/data\person_50_qanh\9.jpg:
#   - Dự đoán: person_50_qanh (Score: 1.00)
#   - Thực tế: person_50_qanh
# Kết quả từ ./datasets/data\person_5_giang\0.jpg:
#   - Dự đoán: person_5_Giang (Score: 1.00)
#   - Thực tế: person_5_giang
# Kết quả từ ./datasets/data\person_5_giang\1.jpg:
#   - Dự đoán: person_5_Giang (Score: 1.00)
#   - Thực tế: person_5_giang
# Kết quả từ ./datasets/data\person_5_giang\10.jpg:
#   - Dự đoán: person_5_Giang (Score: 1.00)
#   - Thực tế: person_5_giang
# Kết quả từ ./datasets/data\person_5_giang\11.jpg:
#   - Dự đoán: person_5_Giang (Score: 1.00)
#   - Thực tế: person_5_giang
# Kết quả từ ./datasets/data\person_5_giang\12.jpg:
#   - Dự đoán: person_5_Giang (Score: 1.00)
#   - Thực tế: person_5_giang
# Kết quả từ ./datasets/data\person_5_giang\13.jpg:
#   - Dự đoán: person_5_Giang (Score: 1.00)
#   - Thực tế: person_5_giang
# Kết quả từ ./datasets/data\person_5_giang\14.jpg:
#   - Dự đoán: person_5_Giang (Score: 1.00)
#   - Thực tế: person_5_giang
# Kết quả từ ./datasets/data\person_5_giang\15.jpg:
#   - Dự đoán: person_5_Giang (Score: 1.00)
#   - Thực tế: person_5_giang
# Kết quả từ ./datasets/data\person_5_giang\2.jpg:
#   - Dự đoán: person_5_Giang (Score: 1.00)
#   - Thực tế: person_5_giang
# Kết quả từ ./datasets/data\person_5_giang\3.jpg:
#   - Dự đoán: person_5_Giang (Score: 1.00)
#   - Thực tế: person_5_giang
# Kết quả từ ./datasets/data\person_5_giang\4.jpg:
#   - Dự đoán: person_5_Giang (Score: 1.00)
#   - Thực tế: person_5_giang
# Kết quả từ ./datasets/data\person_5_giang\5.jpg:
#   - Dự đoán: person_5_Giang (Score: 1.00)
#   - Thực tế: person_5_giang
# Kết quả từ ./datasets/data\person_5_giang\6.jpg:
#   - Dự đoán: person_5_Giang (Score: 1.00)
#   - Thực tế: person_5_giang
# Kết quả từ ./datasets/data\person_5_giang\7.jpg:
#   - Dự đoán: person_5_Giang (Score: 1.00)
#   - Thực tế: person_5_giang
# Kết quả từ ./datasets/data\person_5_giang\8.jpg:
#   - Dự đoán: person_5_Giang (Score: 1.00)
#   - Thực tế: person_5_giang
# Kết quả từ ./datasets/data\person_5_giang\9.jpg:
#   - Dự đoán: person_5_Giang (Score: 1.00)
#   - Thực tế: person_5_giang
# Kết quả từ ./datasets/data\person_7_phuc\0.jpg:
#   - Dự đoán: person_7_Phuc (Score: 1.00)
#   - Thực tế: person_7_phuc
# Kết quả từ ./datasets/data\person_7_phuc\1.jpg:
#   - Dự đoán: person_7_Phuc (Score: 1.00)
#   - Thực tế: person_7_phuc
# Kết quả từ ./datasets/data\person_7_phuc\10.jpg:
#   - Dự đoán: person_7_Phuc (Score: 1.00)
#   - Thực tế: person_7_phuc
# Kết quả từ ./datasets/data\person_7_phuc\11.jpg:
#   - Dự đoán: person_7_Phuc (Score: 1.00)
#   - Thực tế: person_7_phuc
# Kết quả từ ./datasets/data\person_7_phuc\12.jpg:
#   - Dự đoán: person_7_Phuc (Score: 1.00)
#   - Thực tế: person_7_phuc
# Kết quả từ ./datasets/data\person_7_phuc\13.jpg:
#   - Dự đoán: person_7_Phuc (Score: 1.00)
#   - Thực tế: person_7_phuc
# Kết quả từ ./datasets/data\person_7_phuc\14.jpg:
#   - Dự đoán: person_7_Phuc (Score: 1.00)
#   - Thực tế: person_7_phuc
# Kết quả từ ./datasets/data\person_7_phuc\15.jpg:
#   - Dự đoán: person_7_Phuc (Score: 1.00)
#   - Thực tế: person_7_phuc
# Kết quả từ ./datasets/data\person_7_phuc\16.jpg:
#   - Dự đoán: person_7_Phuc (Score: 1.00)
#   - Thực tế: person_7_phuc
# Kết quả từ ./datasets/data\person_7_phuc\17.jpg:
#   - Dự đoán: person_7_Phuc (Score: 1.00)
#   - Thực tế: person_7_phuc
# Kết quả từ ./datasets/data\person_7_phuc\18.jpg:
#   - Dự đoán: person_7_Phuc (Score: 1.00)
#   - Thực tế: person_7_phuc
# Kết quả từ ./datasets/data\person_7_phuc\19.jpg:
#   - Dự đoán: person_7_Phuc (Score: 1.00)
#   - Thực tế: person_7_phuc
# Kết quả từ ./datasets/data\person_7_phuc\2.jpg:
#   - Dự đoán: person_7_Phuc (Score: 1.00)
#   - Thực tế: person_7_phuc
# Kết quả từ ./datasets/data\person_7_phuc\20.jpg:
#   - Dự đoán: person_7_Phuc (Score: 1.00)
#   - Thực tế: person_7_phuc
# Kết quả từ ./datasets/data\person_7_phuc\21.jpg:
#   - Dự đoán: person_7_Phuc (Score: 1.00)
#   - Thực tế: person_7_phuc
# Kết quả từ ./datasets/data\person_7_phuc\22.jpg:
#   - Dự đoán: person_7_Phuc (Score: 1.00)
#   - Thực tế: person_7_phuc
# Kết quả từ ./datasets/data\person_7_phuc\23.jpg:
#   - Dự đoán: person_7_Phuc (Score: 1.00)
#   - Thực tế: person_7_phuc
# Kết quả từ ./datasets/data\person_7_phuc\24.jpg:
#   - Dự đoán: person_7_Phuc (Score: 1.00)
#   - Thực tế: person_7_phuc
# Kết quả từ ./datasets/data\person_7_phuc\25.jpg:
#   - Dự đoán: person_7_Phuc (Score: 1.00)
#   - Thực tế: person_7_phuc
# Kết quả từ ./datasets/data\person_7_phuc\26.jpg:
#   - Dự đoán: person_7_Phuc (Score: 1.00)
#   - Thực tế: person_7_phuc
# Kết quả từ ./datasets/data\person_7_phuc\27.jpg:
#   - Dự đoán: person_7_Phuc (Score: 1.00)
#   - Thực tế: person_7_phuc
# Kết quả từ ./datasets/data\person_7_phuc\28.jpg:
#   - Dự đoán: person_7_Phuc (Score: 1.00)
#   - Thực tế: person_7_phuc
# Kết quả từ ./datasets/data\person_7_phuc\29.jpg:
#   - Dự đoán: person_7_Phuc (Score: 1.00)
#   - Thực tế: person_7_phuc
# Kết quả từ ./datasets/data\person_7_phuc\3.jpg:
#   - Dự đoán: person_7_Phuc (Score: 1.00)
#   - Thực tế: person_7_phuc
# Kết quả từ ./datasets/data\person_7_phuc\30.jpg:
#   - Dự đoán: person_7_Phuc (Score: 1.00)
#   - Thực tế: person_7_phuc
# Kết quả từ ./datasets/data\person_7_phuc\31.jpg:
#   - Dự đoán: person_7_Phuc (Score: 1.00)
#   - Thực tế: person_7_phuc
# Kết quả từ ./datasets/data\person_7_phuc\4.jpg:
#   - Dự đoán: person_7_Phuc (Score: 1.00)
#   - Thực tế: person_7_phuc
# Kết quả từ ./datasets/data\person_7_phuc\5.jpg:
#   - Dự đoán: person_7_Phuc (Score: 1.00)
#   - Thực tế: person_7_phuc
# Kết quả từ ./datasets/data\person_7_phuc\6.jpg:
#   - Dự đoán: person_7_Phuc (Score: 1.00)
#   - Thực tế: person_7_phuc
# Kết quả từ ./datasets/data\person_7_phuc\7.jpg:
#   - Dự đoán: person_7_Phuc (Score: 1.00)
#   - Thực tế: person_7_phuc
# Kết quả từ ./datasets/data\person_7_phuc\8.jpg:
#   - Dự đoán: person_7_Phuc (Score: 1.00)
#   - Thực tế: person_7_phuc
# Kết quả từ ./datasets/data\person_7_phuc\9.jpg:
#   - Dự đoán: person_7_Phuc (Score: 1.00)
#   - Thực tế: person_7_phuc
# Kết quả từ ./datasets/data\person_8_tony\0.jpg:
#   - Dự đoán: person_8_tony (Score: 1.00)
#   - Thực tế: person_8_tony
# Kết quả từ ./datasets/data\person_8_tony\1.jpg:
#   - Dự đoán: person_8_tony (Score: 1.00)
#   - Thực tế: person_8_tony
# Kết quả từ ./datasets/data\person_8_tony\10.jpg:
#   - Dự đoán: person_8_tony (Score: 1.00)
#   - Thực tế: person_8_tony
# Kết quả từ ./datasets/data\person_8_tony\11.jpg:
#   - Dự đoán: person_8_tony (Score: 1.00)
#   - Thực tế: person_8_tony
# Kết quả từ ./datasets/data\person_8_tony\12.jpg:
#   - Dự đoán: person_8_tony (Score: 1.00)
#   - Thực tế: person_8_tony
# Kết quả từ ./datasets/data\person_8_tony\13.jpg:
#   - Dự đoán: person_8_tony (Score: 1.00)
#   - Thực tế: person_8_tony
# Kết quả từ ./datasets/data\person_8_tony\14.jpg:
#   - Dự đoán: person_8_tony (Score: 1.00)
#   - Thực tế: person_8_tony
# Kết quả từ ./datasets/data\person_8_tony\15.jpg:
#   - Dự đoán: person_8_tony (Score: 1.00)
#   - Thực tế: person_8_tony
# Kết quả từ ./datasets/data\person_8_tony\2.jpg:
#   - Dự đoán: person_8_tony (Score: 1.00)
#   - Thực tế: person_8_tony
# Kết quả từ ./datasets/data\person_8_tony\3.jpg:
#   - Dự đoán: person_8_tony (Score: 1.00)
#   - Thực tế: person_8_tony
# Kết quả từ ./datasets/data\person_8_tony\4.jpg:
#   - Dự đoán: person_8_tony (Score: 1.00)
#   - Thực tế: person_8_tony
# Kết quả từ ./datasets/data\person_8_tony\5.jpg:
#   - Dự đoán: person_8_tony (Score: 1.00)
#   - Thực tế: person_8_tony
# Kết quả từ ./datasets/data\person_8_tony\6.jpg:
#   - Dự đoán: person_8_tony (Score: 1.00)
#   - Thực tế: person_8_tony
# Kết quả từ ./datasets/data\person_8_tony\7.jpg:
#   - Dự đoán: person_8_tony (Score: 1.00)
#   - Thực tế: person_8_tony
# Kết quả từ ./datasets/data\person_8_tony\8.jpg:
#   - Dự đoán: person_8_tony (Score: 1.00)
#   - Thực tế: person_8_tony
# Kết quả từ ./datasets/data\person_8_tony\9.jpg:
#   - Dự đoán: person_8_tony (Score: 1.00)
#   - Thực tế: person_8_tony
# Kết quả từ ./datasets/data\person_9_laufey\0.jpg:
#   - Dự đoán: person_9_laufey (Score: 1.00)
#   - Thực tế: person_9_laufey
# Kết quả từ ./datasets/data\person_9_laufey\1.jpg:
#   - Dự đoán: person_9_laufey (Score: 1.00)
#   - Thực tế: person_9_laufey
# Kết quả từ ./datasets/data\person_9_laufey\10.jpg:
#   - Dự đoán: person_9_laufey (Score: 1.00)
#   - Thực tế: person_9_laufey
# Kết quả từ ./datasets/data\person_9_laufey\11.jpg:
#   - Dự đoán: person_9_laufey (Score: 1.00)
#   - Thực tế: person_9_laufey
# Kết quả từ ./datasets/data\person_9_laufey\12.jpg:
#   - Dự đoán: person_9_laufey (Score: 1.00)
#   - Thực tế: person_9_laufey
# Kết quả từ ./datasets/data\person_9_laufey\13.jpg:
#   - Dự đoán: person_9_laufey (Score: 1.00)
#   - Thực tế: person_9_laufey
# Kết quả từ ./datasets/data\person_9_laufey\14.jpg:
#   - Dự đoán: person_9_laufey (Score: 1.00)
#   - Thực tế: person_9_laufey
# Kết quả từ ./datasets/data\person_9_laufey\15.jpg:
#   - Dự đoán: person_9_laufey (Score: 1.00)
#   - Thực tế: person_9_laufey
# Kết quả từ ./datasets/data\person_9_laufey\16.jpg:
#   - Dự đoán: person_9_laufey (Score: 1.00)
#   - Thực tế: person_9_laufey
# Kết quả từ ./datasets/data\person_9_laufey\17.jpg:
#   - Dự đoán: person_9_laufey (Score: 1.00)
#   - Thực tế: person_9_laufey
# Kết quả từ ./datasets/data\person_9_laufey\18.jpg:
#   - Dự đoán: person_9_laufey (Score: 1.00)
#   - Thực tế: person_9_laufey
# Kết quả từ ./datasets/data\person_9_laufey\19.jpg:
#   - Dự đoán: person_9_laufey (Score: 1.00)
#   - Thực tế: person_9_laufey
# Kết quả từ ./datasets/data\person_9_laufey\2.jpg:
#   - Dự đoán: person_9_laufey (Score: 1.00)
#   - Thực tế: person_9_laufey
# Kết quả từ ./datasets/data\person_9_laufey\20.jpg:
#   - Dự đoán: person_9_laufey (Score: 1.00)
#   - Thực tế: person_9_laufey
# Kết quả từ ./datasets/data\person_9_laufey\21.jpg:
#   - Dự đoán: person_9_laufey (Score: 1.00)
#   - Thực tế: person_9_laufey
# Kết quả từ ./datasets/data\person_9_laufey\3.jpg:
#   - Dự đoán: person_9_laufey (Score: 1.00)
#   - Thực tế: person_9_laufey
# Kết quả từ ./datasets/data\person_9_laufey\4.jpg:
#   - Dự đoán: person_9_laufey (Score: 1.00)
#   - Thực tế: person_9_laufey
# Kết quả từ ./datasets/data\person_9_laufey\5.jpg:
#   - Dự đoán: person_9_laufey (Score: 1.00)
#   - Thực tế: person_9_laufey
# Kết quả từ ./datasets/data\person_9_laufey\6.jpg:
#   - Dự đoán: person_9_laufey (Score: 1.00)
#   - Thực tế: person_9_laufey
# Kết quả từ ./datasets/data\person_9_laufey\7.jpg:
#   - Dự đoán: person_9_laufey (Score: 1.00)
#   - Thực tế: person_9_laufey
# Kết quả từ ./datasets/data\person_9_laufey\8.jpg:
#   - Dự đoán: person_9_laufey (Score: 1.00)
#   - Thực tế: person_9_laufey
# Kết quả từ ./datasets/data\person_9_laufey\9.jpg:
#   - Dự đoán: person_9_laufey (Score: 1.00)
#   - Thực tế: person_9_laufey
# Độ chính xác của mô hình: 92.32%
# Tổng số ảnh: 833
# Số nhận diện đúng: 769
# Số nhận diện sai: 64
# 92.31692677070828

# %%
#shuffle dữ liệu 
import random

def evaluate_model(dataset_dir, shuffle=True):
    """
    Đánh giá mô hình trên toàn bộ tập dữ liệu đã detect và xáo trộn dữ liệu nếu cần.
    
    Args:
        dataset_dir (str): Đường dẫn tới thư mục chứa dataset.
        shuffle (bool): Có xáo trộn dữ liệu trước khi dự đoán không.

    Returns:
        accuracy (float): Độ chính xác của mô hình.
    """
    total_images = 0
    correct_recognitions = 0
    false_recognitions = 0

    # Tạo danh sách tất cả ảnh và nhãn
    all_images = []
    for person_name in os.listdir(dataset_dir):
        person_dir = os.path.join(dataset_dir, person_name)
        if not os.path.isdir(person_dir):
            continue

        for img_name in os.listdir(person_dir):
            img_path = os.path.join(person_dir, img_name)
            all_images.append((img_path, person_name))

    # Shuffle dữ liệu
    if shuffle:
        random.shuffle(all_images)

    # Dự đoán trên từng ảnh
    for img_path, true_name in all_images:
        total_images += 1
        if evaluate_single_image(img_path, true_name):
            correct_recognitions += 1
        else:
            false_recognitions += 1

    accuracy = correct_recognitions / total_images * 100
    print(f"Độ chính xác của mô hình: {accuracy:.2f}%")
    print(f"Tổng số ảnh: {total_images}")
    print(f"Số nhận diện đúng: {correct_recognitions}")
    print(f"Số nhận diện sai: {false_recognitions}")
    return accuracy

# %%
def evaluate_single_image(image_path, true_name):
    """
    Đánh giá kết quả nhận diện trên một ảnh.
    
    Args:
        image_path (str): Đường dẫn tới ảnh đã cắt khuôn mặt.
        true_name (str): Tên thực tế của người trong ảnh.

    Returns:
        bool: True nếu nhận diện đúng, False nếu sai.
    """
    face_image = cv2.imread(image_path)
    if face_image is None:
        print(f"Không thể đọc ảnh: {image_path}")
        return False

    score, recognized_name = recognition(face_image)
    print(f"Kết quả từ {image_path}:")
    print(f"  - Dự đoán: {recognized_name} (Score: {score:.2f})")
    print(f"  - Thực tế: {true_name}")

    return recognized_name == true_name

# %%
dataset_dir = "./datasets/data"
evaluate_model(dataset_dir, shuffle=True)
# Out:
# Kết quả từ ./datasets/data\person_43_dang\19.jpg:
#   - Dự đoán: person_43_dang (Score: 1.00)
#   - Thực tế: person_43_dang
# Kết quả từ ./datasets/data\person_11_timmothy\20.jpg:
#   - Dự đoán: person_11_timmothy (Score: 1.00)
#   - Thực tế: person_11_timmothy
# Kết quả từ ./datasets/data\person_11_timmothy\2.jpg:
#   - Dự đoán: person_11_timmothy (Score: 1.00)
#   - Thực tế: person_11_timmothy
# Kết quả từ ./datasets/data\person_39_crisdevil\13.jpg:
#   - Dự đoán: person_39_crisdevil (Score: 1.00)
#   - Thực tế: person_39_crisdevil
# Kết quả từ ./datasets/data\person_36_brad\14.jpg:
#   - Dự đoán: person_36_brad (Score: 1.00)
#   - Thực tế: person_36_brad
# Kết quả từ ./datasets/data\person_11_timmothy\12.jpg:
#   - Dự đoán: person_11_timmothy (Score: 1.00)
#   - Thực tế: person_11_timmothy
# Kết quả từ ./datasets/data\person_37_hurrykhng\10.jpg:
#   - Dự đoán: person_37_hurrykhng (Score: 1.00)
#   - Thực tế: person_37_hurrykhng
# Kết quả từ ./datasets/data\person_27_mck\3.jpg:
#   - Dự đoán: person_27_mck (Score: 1.00)
#   - Thực tế: person_27_mck
# Kết quả từ ./datasets/data\person_15_tom_cruise\13.jpg:
#   - Dự đoán: person_15_tom_cruise (Score: 1.00)
#   - Thực tế: person_15_tom_cruise
# Kết quả từ ./datasets/data\person_14_tom_hardy\14.jpg:
#   - Dự đoán: person_14_tom_hardy (Score: 1.00)
#   - Thực tế: person_14_tom_hardy
# Kết quả từ ./datasets/data\person_36_brad\1.jpg:
#   - Dự đoán: person_36_brad (Score: 1.00)
#   - Thực tế: person_36_brad
# Kết quả từ ./datasets/data\person_10_tom_holland\8.jpg:
#   - Dự đoán: person_10_tom_holland (Score: 1.00)
#   - Thực tế: person_10_tom_holland
# Kết quả từ ./datasets/data\person_10_tom_holland\24.jpg:
#   - Dự đoán: person_10_tom_holland (Score: 1.00)
#   - Thực tế: person_10_tom_holland
# Kết quả từ ./datasets/data\person_44_yen_nhi\29.jpg:
#   - Dự đoán: person_44_yen_nhi (Score: 1.00)
#   - Thực tế: person_44_yen_nhi
# Kết quả từ ./datasets/data\person_10_tom_holland\26.jpg:
#   - Dự đoán: person_10_tom_holland (Score: 1.00)
#   - Thực tế: person_10_tom_holland
# Kết quả từ ./datasets/data\person_44_yen_nhi\7.jpg:
#   - Dự đoán: person_44_yen_nhi (Score: 1.00)
#   - Thực tế: person_44_yen_nhi
# Kết quả từ ./datasets/data\person_27_mck\16.jpg:
#   - Dự đoán: person_27_mck (Score: 1.00)
#   - Thực tế: person_27_mck
# Kết quả từ ./datasets/data\person_33_harrington\17.jpg:
#   - Dự đoán: person_33_harrington (Score: 1.00)
#   - Thực tế: person_33_harrington
# Kết quả từ ./datasets/data\person_26_suboi\7.jpg:
#   - Dự đoán: person_26_suboi (Score: 1.00)
#   - Thực tế: person_26_suboi
# Kết quả từ ./datasets/data\person_22_atus\12.jpg:
#   - Dự đoán: person_22_atus (Score: 1.00)
#   - Thực tế: person_22_atus
# Kết quả từ ./datasets/data\person_32_andrew_garfiled\8.jpg:
#   - Dự đoán: person_32_andrew_garfiled (Score: 1.00)
#   - Thực tế: person_32_andrew_garfiled
# Kết quả từ ./datasets/data\person_37_hurrykhng\14.jpg:
#   - Dự đoán: person_37_hurrykhng (Score: 1.00)
#   - Thực tế: person_37_hurrykhng
# Kết quả từ ./datasets/data\person_31_anh_tu\13.jpg:
#   - Dự đoán: person_31_anh_tu (Score: 1.00)
#   - Thực tế: person_31_anh_tu
# Kết quả từ ./datasets/data\person_17_bruno_mar\13.jpg:
#   - Dự đoán: person_17_bruno_mar (Score: 0.99)
#   - Thực tế: person_17_bruno_mar
# Kết quả từ ./datasets/data\person_8_tony\1.jpg:
#   - Dự đoán: person_8_tony (Score: 1.00)
#   - Thực tế: person_8_tony
# Kết quả từ ./datasets/data\person_36_brad\4.jpg:
#   - Dự đoán: person_36_brad (Score: 1.00)
#   - Thực tế: person_36_brad
# Kết quả từ ./datasets/data\person_20_justin_bieber\13.jpg:
#   - Dự đoán: person_20_justin_bieber (Score: 1.00)
#   - Thực tế: person_20_justin_bieber
# Kết quả từ ./datasets/data\person_26_suboi\11.jpg:
#   - Dự đoán: person_26_suboi (Score: 1.00)
#   - Thực tế: person_26_suboi
# Kết quả từ ./datasets/data\person_40_tranthanh\13.jpg:
#   - Dự đoán: person_40_tranthanh (Score: 1.00)
#   - Thực tế: person_40_tranthanh
# Kết quả từ ./datasets/data\person_20_justin_bieber\11.jpg:
#   - Dự đoán: person_20_justin_bieber (Score: 1.00)
#   - Thực tế: person_20_justin_bieber
# Kết quả từ ./datasets/data\person_36_brad\7.jpg:
#   - Dự đoán: person_36_brad (Score: 1.00)
#   - Thực tế: person_36_brad
# Kết quả từ ./datasets/data\person_23_h2h\5.jpg:
#   - Dự đoán: person_23_h2h (Score: 1.00)
#   - Thực tế: person_23_h2h
# Kết quả từ ./datasets/data\person_13_katty_perry\3.jpg:
#   - Dự đoán: person_13_katty_perry (Score: 1.00)
#   - Thực tế: person_13_katty_perry
# Kết quả từ ./datasets/data\person_8_tony\8.jpg:
#   - Dự đoán: person_8_tony (Score: 1.00)
#   - Thực tế: person_8_tony
# Kết quả từ ./datasets/data\person_40_tranthanh\4.jpg:
#   - Dự đoán: person_40_tranthanh (Score: 1.00)
#   - Thực tế: person_40_tranthanh
# Kết quả từ ./datasets/data\person_43_dang\21.jpg:
#   - Dự đoán: person_43_dang (Score: 1.00)
#   - Thực tế: person_43_dang
# Kết quả từ ./datasets/data\person_41_quynh\0.jpg:
#   - Dự đoán: person_41_quynh (Score: 1.00)
#   - Thực tế: person_41_quynh
# Kết quả từ ./datasets/data\person_7_phuc\3.jpg:
#   - Dự đoán: person_7_Phuc (Score: 1.00)
#   - Thực tế: person_7_phuc
# Kết quả từ ./datasets/data\person_44_yen_nhi\22.jpg:
#   - Dự đoán: person_44_yen_nhi (Score: 1.00)
#   - Thực tế: person_44_yen_nhi
# Kết quả từ ./datasets/data\person_5_giang\7.jpg:
#   - Dự đoán: person_5_Giang (Score: 1.00)
#   - Thực tế: person_5_giang
# Kết quả từ ./datasets/data\person_26_suboi\13.jpg:
#   - Dự đoán: person_26_suboi (Score: 1.00)
#   - Thực tế: person_26_suboi
# Kết quả từ ./datasets/data\person_33_harrington\1.jpg:
#   - Dự đoán: person_33_harrington (Score: 1.00)
#   - Thực tế: person_33_harrington
# Kết quả từ ./datasets/data\person_32_andrew_garfiled\17.jpg:
#   - Dự đoán: person_32_andrew_garfiled (Score: 1.00)
#   - Thực tế: person_32_andrew_garfiled
# Kết quả từ ./datasets/data\person_34_harvey\13.jpg:
#   - Dự đoán: person_34_harvey (Score: 1.00)
#   - Thực tế: person_34_harvey
# Kết quả từ ./datasets/data\person_43_dang\23.jpg:
#   - Dự đoán: person_43_dang (Score: 1.00)
#   - Thực tế: person_43_dang
# Kết quả từ ./datasets/data\person_46_nam_phuong\40.jpg:
#   - Dự đoán: person_46_nam_phuong (Score: 1.00)
#   - Thực tế: person_46_nam_phuong
# Kết quả từ ./datasets/data\person_13_katty_perry\11.jpg:
#   - Dự đoán: person_13_katty_perry (Score: 1.00)
#   - Thực tế: person_13_katty_perry
# Kết quả từ ./datasets/data\person_9_laufey\3.jpg:
#   - Dự đoán: person_9_laufey (Score: 1.00)
#   - Thực tế: person_9_laufey
# Kết quả từ ./datasets/data\person_5_giang\2.jpg:
#   - Dự đoán: person_5_Giang (Score: 1.00)
#   - Thực tế: person_5_giang
# Kết quả từ ./datasets/data\person_12_hiddleston\8.jpg:
#   - Dự đoán: person_12_hiddleston (Score: 1.00)
#   - Thực tế: person_12_hiddleston
# Kết quả từ ./datasets/data\person_11_timmothy\10.jpg:
#   - Dự đoán: person_11_timmothy (Score: 1.00)
#   - Thực tế: person_11_timmothy
# Kết quả từ ./datasets/data\person_16_chris\1.jpg:
#   - Dự đoán: person_16_chris (Score: 1.00)
#   - Thực tế: person_16_chris
# Kết quả từ ./datasets/data\person_42_minh\11.jpg:
#   - Dự đoán: person_42_minh (Score: 1.00)
#   - Thực tế: person_42_minh
# Kết quả từ ./datasets/data\person_7_phuc\1.jpg:
#   - Dự đoán: person_7_Phuc (Score: 1.00)
#   - Thực tế: person_7_phuc
# Kết quả từ ./datasets/data\person_31_anh_tu\11.jpg:
#   - Dự đoán: person_31_anh_tu (Score: 1.00)
#   - Thực tế: person_31_anh_tu
# Kết quả từ ./datasets/data\person_14_tom_hardy\19.jpg:
#   - Dự đoán: person_14_tom_hardy (Score: 1.00)
#   - Thực tế: person_14_tom_hardy
# Kết quả từ ./datasets/data\person_41_quynh\19.jpg:
#   - Dự đoán: person_41_quynh (Score: 1.00)
#   - Thực tế: person_41_quynh
# Kết quả từ ./datasets/data\person_20_justin_bieber\3.jpg:
#   - Dự đoán: person_20_justin_bieber (Score: 1.00)
#   - Thực tế: person_20_justin_bieber
# Kết quả từ ./datasets/data\person_38_manbo\13.jpg:
#   - Dự đoán: person_38_manbo (Score: 1.00)
#   - Thực tế: person_38_manbo
# Kết quả từ ./datasets/data\person_50_qanh\2.jpg:
#   - Dự đoán: person_50_qanh (Score: 1.00)
#   - Thực tế: person_50_qanh
# Kết quả từ ./datasets/data\person_7_phuc\27.jpg:
#   - Dự đoán: person_7_Phuc (Score: 1.00)
#   - Thực tế: person_7_phuc
# Kết quả từ ./datasets/data\person_45_tuan_anh\21.jpg:
#   - Dự đoán: person_45_tuan_anh (Score: 1.00)
#   - Thực tế: person_45_tuan_anh
# Kết quả từ ./datasets/data\person_22_atus\4.jpg:
#   - Dự đoán: person_22_atus (Score: 1.00)
#   - Thực tế: person_22_atus
# Kết quả từ ./datasets/data\person_40_tranthanh\20.jpg:
#   - Dự đoán: person_40_tranthanh (Score: 1.00)
#   - Thực tế: person_40_tranthanh
# Kết quả từ ./datasets/data\person_46_nam_phuong\6.jpg:
#   - Dự đoán: person_46_nam_phuong (Score: 1.00)
#   - Thực tế: person_46_nam_phuong
# Kết quả từ ./datasets/data\person_15_tom_cruise\23.jpg:
#   - Dự đoán: person_15_tom_cruise (Score: 1.00)
#   - Thực tế: person_15_tom_cruise
# Kết quả từ ./datasets/data\person_35_will__smith\18.jpg:
#   - Dự đoán: person_35_will__smith (Score: 1.00)
#   - Thực tế: person_35_will__smith
# Kết quả từ ./datasets/data\person_8_tony\11.jpg:
#   - Dự đoán: person_8_tony (Score: 1.00)
#   - Thực tế: person_8_tony
# Kết quả từ ./datasets/data\person_7_phuc\31.jpg:
#   - Dự đoán: person_7_Phuc (Score: 1.00)
#   - Thực tế: person_7_phuc
# Kết quả từ ./datasets/data\person_46_nam_phuong\2.jpg:
#   - Dự đoán: person_46_nam_phuong (Score: 1.00)
#   - Thực tế: person_46_nam_phuong
# Kết quả từ ./datasets/data\person_5_giang\8.jpg:
#   - Dự đoán: person_5_Giang (Score: 1.00)
#   - Thực tế: person_5_giang
# Kết quả từ ./datasets/data\person_50_qanh\4.jpg:
#   - Dự đoán: person_50_qanh (Score: 1.00)
#   - Thực tế: person_50_qanh
# Kết quả từ ./datasets/data\person_10_tom_holland\29.jpg:
#   - Dự đoán: person_10_tom_holland (Score: 1.00)
#   - Thực tế: person_10_tom_holland
# Kết quả từ ./datasets/data\person_7_phuc\9.jpg:
#   - Dự đoán: person_7_Phuc (Score: 1.00)
#   - Thực tế: person_7_phuc
# Kết quả từ ./datasets/data\person_36_brad\15.jpg:
#   - Dự đoán: person_36_brad (Score: 1.00)
#   - Thực tế: person_36_brad
# Kết quả từ ./datasets/data\person_17_bruno_mar\11.jpg:
#   - Dự đoán: person_17_bruno_mar (Score: 1.00)
#   - Thực tế: person_17_bruno_mar
# Kết quả từ ./datasets/data\person_46_nam_phuong\41.jpg:
#   - Dự đoán: person_46_nam_phuong (Score: 1.00)
#   - Thực tế: person_46_nam_phuong
# Kết quả từ ./datasets/data\person_14_tom_hardy\26.jpg:
#   - Dự đoán: person_14_tom_hardy (Score: 1.00)
#   - Thực tế: person_14_tom_hardy
# Kết quả từ ./datasets/data\person_46_nam_phuong\19.jpg:
#   - Dự đoán: person_46_nam_phuong (Score: 1.00)
#   - Thực tế: person_46_nam_phuong
# Kết quả từ ./datasets/data\person_30_erik\11.jpg:
#   - Dự đoán: person_30_erik (Score: 1.00)
#   - Thực tế: person_30_erik
# Kết quả từ ./datasets/data\person_12_hiddleston\0.jpg:
#   - Dự đoán: person_12_hiddleston (Score: 1.00)
#   - Thực tế: person_12_hiddleston
# Kết quả từ ./datasets/data\person_43_dang\13.jpg:
#   - Dự đoán: person_43_dang (Score: 1.00)
#   - Thực tế: person_43_dang
# Kết quả từ ./datasets/data\person_50_qanh\9.jpg:
#   - Dự đoán: person_50_qanh (Score: 1.00)
#   - Thực tế: person_50_qanh
# Kết quả từ ./datasets/data\person_44_yen_nhi\25.jpg:
#   - Dự đoán: person_44_yen_nhi (Score: 1.00)
#   - Thực tế: person_44_yen_nhi
# Kết quả từ ./datasets/data\person_27_mck\5.jpg:
#   - Dự đoán: person_27_mck (Score: 1.00)
#   - Thực tế: person_27_mck
# Kết quả từ ./datasets/data\person_37_hurrykhng\12.jpg:
#   - Dự đoán: person_37_hurrykhng (Score: 1.00)
#   - Thực tế: person_37_hurrykhng
# Kết quả từ ./datasets/data\person_40_tranthanh\27.jpg:
#   - Dự đoán: person_40_tranthanh (Score: 1.00)
#   - Thực tế: person_40_tranthanh
# Kết quả từ ./datasets/data\person_43_dang\7.jpg:
#   - Dự đoán: person_43_dang (Score: 1.00)
#   - Thực tế: person_43_dang
# Kết quả từ ./datasets/data\person_9_laufey\2.jpg:
#   - Dự đoán: person_9_laufey (Score: 1.00)
#   - Thực tế: person_9_laufey
# Kết quả từ ./datasets/data\person_12_hiddleston\10.jpg:
#   - Dự đoán: person_12_hiddleston (Score: 1.00)
#   - Thực tế: person_12_hiddleston
# Kết quả từ ./datasets/data\person_35_will__smith\10.jpg:
#   - Dự đoán: person_35_will__smith (Score: 1.00)
#   - Thực tế: person_35_will__smith
# Kết quả từ ./datasets/data\person_39_crisdevil\7.jpg:
#   - Dự đoán: person_39_crisdevil (Score: 1.00)
#   - Thực tế: person_39_crisdevil
# Kết quả từ ./datasets/data\person_39_crisdevil\9.jpg:
#   - Dự đoán: person_39_crisdevil (Score: 1.00)
#   - Thực tế: person_39_crisdevil
# Kết quả từ ./datasets/data\person_43_dang\4.jpg:
#   - Dự đoán: person_43_dang (Score: 1.00)
#   - Thực tế: person_43_dang
# Kết quả từ ./datasets/data\person_27_mck\9.jpg:
#   - Dự đoán: person_27_mck (Score: 1.00)
#   - Thực tế: person_27_mck
# Kết quả từ ./datasets/data\person_23_h2h\2.jpg:
#   - Dự đoán: person_23_h2h (Score: 1.00)
#   - Thực tế: person_23_h2h
# Kết quả từ ./datasets/data\person_15_tom_cruise\17.jpg:
#   - Dự đoán: person_15_tom_cruise (Score: 1.00)
#   - Thực tế: person_15_tom_cruise
# Kết quả từ ./datasets/data\person_16_chris\16.jpg:
#   - Dự đoán: person_16_chris (Score: 1.00)
#   - Thực tế: person_16_chris
# Kết quả từ ./datasets/data\person_43_dang\3.jpg:
#   - Dự đoán: person_43_dang (Score: 1.00)
#   - Thực tế: person_43_dang
# Kết quả từ ./datasets/data\person_41_quynh\9.jpg:
#   - Dự đoán: person_41_quynh (Score: 1.00)
#   - Thực tế: person_41_quynh
# Kết quả từ ./datasets/data\person_10_tom_holland\0.jpg:
#   - Dự đoán: person_10_tom_holland (Score: 1.00)
#   - Thực tế: person_10_tom_holland
# Kết quả từ ./datasets/data\person_26_suboi\0.jpg:
#   - Dự đoán: person_26_suboi (Score: 1.00)
#   - Thực tế: person_26_suboi
# Kết quả từ ./datasets/data\person_15_tom_cruise\8.jpg:
#   - Dự đoán: person_15_tom_cruise (Score: 1.00)
#   - Thực tế: person_15_tom_cruise
# Kết quả từ ./datasets/data\person_17_bruno_mar\4.jpg:
#   - Dự đoán: person_17_bruno_mar (Score: 1.00)
#   - Thực tế: person_17_bruno_mar
# Kết quả từ ./datasets/data\person_40_tranthanh\7.jpg:
#   - Dự đoán: person_40_tranthanh (Score: 1.00)
#   - Thực tế: person_40_tranthanh
# Kết quả từ ./datasets/data\person_15_tom_cruise\10.jpg:
#   - Dự đoán: person_15_tom_cruise (Score: 1.00)
#   - Thực tế: person_15_tom_cruise
# Kết quả từ ./datasets/data\person_19_sam_smith\10.jpg:
#   - Dự đoán: person_19_sam_smith (Score: 1.00)
#   - Thực tế: person_19_sam_smith
# Kết quả từ ./datasets/data\person_40_tranthanh\29.jpg:
#   - Dự đoán: person_40_tranthanh (Score: 1.00)
#   - Thực tế: person_40_tranthanh
# Kết quả từ ./datasets/data\person_34_harvey\2.jpg:
#   - Dự đoán: person_34_harvey (Score: 1.00)
#   - Thực tế: person_34_harvey
# Kết quả từ ./datasets/data\person_22_atus\8.jpg:
#   - Dự đoán: person_22_atus (Score: 1.00)
#   - Thực tế: person_22_atus
# Kết quả từ ./datasets/data\person_42_minh\15.jpg:
#   - Dự đoán: person_42_minh (Score: 1.00)
#   - Thực tế: person_42_minh
# Kết quả từ ./datasets/data\person_20_justin_bieber\19.jpg:
#   - Dự đoán: person_20_justin_bieber (Score: 1.00)
#   - Thực tế: person_20_justin_bieber
# Kết quả từ ./datasets/data\person_14_tom_hardy\6.jpg:
#   - Dự đoán: person_14_tom_hardy (Score: 1.00)
#   - Thực tế: person_14_tom_hardy
# Kết quả từ ./datasets/data\person_32_andrew_garfiled\14.jpg:
#   - Dự đoán: person_32_andrew_garfiled (Score: 1.00)
#   - Thực tế: person_32_andrew_garfiled
# Kết quả từ ./datasets/data\person_14_tom_hardy\3.jpg:
#   - Dự đoán: person_14_tom_hardy (Score: 1.00)
#   - Thực tế: person_14_tom_hardy
# Kết quả từ ./datasets/data\person_5_giang\11.jpg:
#   - Dự đoán: person_5_Giang (Score: 1.00)
#   - Thực tế: person_5_giang
# Kết quả từ ./datasets/data\person_31_anh_tu\22.jpg:
#   - Dự đoán: person_31_anh_tu (Score: 1.00)
#   - Thực tế: person_31_anh_tu
# Kết quả từ ./datasets/data\person_37_hurrykhng\8.jpg:
#   - Dự đoán: person_37_hurrykhng (Score: 1.00)
#   - Thực tế: person_37_hurrykhng
# Kết quả từ ./datasets/data\person_40_tranthanh\12.jpg:
#   - Dự đoán: person_40_tranthanh (Score: 1.00)
#   - Thực tế: person_40_tranthanh
# Kết quả từ ./datasets/data\person_20_justin_bieber\12.jpg:
#   - Dự đoán: person_20_justin_bieber (Score: 1.00)
#   - Thực tế: person_20_justin_bieber
# Kết quả từ ./datasets/data\person_33_harrington\3.jpg:
#   - Dự đoán: person_33_harrington (Score: 1.00)
#   - Thực tế: person_33_harrington
# Kết quả từ ./datasets/data\person_9_laufey\4.jpg:
#   - Dự đoán: person_9_laufey (Score: 1.00)
#   - Thực tế: person_9_laufey
# Kết quả từ ./datasets/data\person_42_minh\22.jpg:
#   - Dự đoán: person_42_minh (Score: 1.00)
#   - Thực tế: person_42_minh
# Kết quả từ ./datasets/data\person_8_tony\9.jpg:
#   - Dự đoán: person_8_tony (Score: 1.00)
#   - Thực tế: person_8_tony
# Kết quả từ ./datasets/data\person_44_yen_nhi\17.jpg:
#   - Dự đoán: person_44_yen_nhi (Score: 1.00)
#   - Thực tế: person_44_yen_nhi
# Kết quả từ ./datasets/data\person_17_bruno_mar\8.jpg:
#   - Dự đoán: person_17_bruno_mar (Score: 1.00)
#   - Thực tế: person_17_bruno_mar
# Kết quả từ ./datasets/data\person_7_phuc\8.jpg:
#   - Dự đoán: person_7_Phuc (Score: 1.00)
#   - Thực tế: person_7_phuc
# Kết quả từ ./datasets/data\person_9_laufey\17.jpg:
#   - Dự đoán: person_9_laufey (Score: 1.00)
#   - Thực tế: person_9_laufey
# Kết quả từ ./datasets/data\person_19_sam_smith\7.jpg:
#   - Dự đoán: person_19_sam_smith (Score: 1.00)
#   - Thực tế: person_19_sam_smith
# Kết quả từ ./datasets/data\person_42_minh\1.jpg:
#   - Dự đoán: person_42_minh (Score: 1.00)
#   - Thực tế: person_42_minh
# Kết quả từ ./datasets/data\person_16_chris\3.jpg:
#   - Dự đoán: person_16_chris (Score: 1.00)
#   - Thực tế: person_16_chris
# Kết quả từ ./datasets/data\person_39_crisdevil\3.jpg:
#   - Dự đoán: person_39_crisdevil (Score: 1.00)
#   - Thực tế: person_39_crisdevil
# Kết quả từ ./datasets/data\person_20_justin_bieber\15.jpg:
#   - Dự đoán: person_20_justin_bieber (Score: 1.00)
#   - Thực tế: person_20_justin_bieber
# Kết quả từ ./datasets/data\person_31_anh_tu\23.jpg:
#   - Dự đoán: person_31_anh_tu (Score: 1.00)
#   - Thực tế: person_31_anh_tu
# Kết quả từ ./datasets/data\person_38_manbo\14.jpg:
#   - Dự đoán: person_38_manbo (Score: 1.00)
#   - Thực tế: person_38_manbo
# Kết quả từ ./datasets/data\person_10_tom_holland\31.jpg:
#   - Dự đoán: person_10_tom_holland (Score: 1.00)
#   - Thực tế: person_10_tom_holland
# Kết quả từ ./datasets/data\person_27_mck\2.jpg:
#   - Dự đoán: person_27_mck (Score: 1.00)
#   - Thực tế: person_27_mck
# Kết quả từ ./datasets/data\person_30_erik\1.jpg:
#   - Dự đoán: person_30_erik (Score: 1.00)
#   - Thực tế: person_30_erik
# Kết quả từ ./datasets/data\person_13_katty_perry\8.jpg:
#   - Dự đoán: person_13_katty_perry (Score: 1.00)
#   - Thực tế: person_13_katty_perry
# Kết quả từ ./datasets/data\person_7_phuc\13.jpg:
#   - Dự đoán: person_7_Phuc (Score: 1.00)
#   - Thực tế: person_7_phuc
# Kết quả từ ./datasets/data\person_9_laufey\7.jpg:
#   - Dự đoán: person_9_laufey (Score: 1.00)
#   - Thực tế: person_9_laufey
# Kết quả từ ./datasets/data\person_30_erik\21.jpg:
#   - Dự đoán: person_30_erik (Score: 1.00)
#   - Thực tế: person_30_erik
# Kết quả từ ./datasets/data\person_35_will__smith\12.jpg:
#   - Dự đoán: person_35_will__smith (Score: 1.00)
#   - Thực tế: person_35_will__smith
# Kết quả từ ./datasets/data\person_10_tom_holland\7.jpg:
#   - Dự đoán: person_10_tom_holland (Score: 1.00)
#   - Thực tế: person_10_tom_holland
# Kết quả từ ./datasets/data\person_12_hiddleston\2.jpg:
#   - Dự đoán: person_12_hiddleston (Score: 1.00)
#   - Thực tế: person_12_hiddleston
# Kết quả từ ./datasets/data\person_19_sam_smith\6.jpg:
#   - Dự đoán: person_19_sam_smith (Score: 1.00)
#   - Thực tế: person_19_sam_smith
# Kết quả từ ./datasets/data\person_14_tom_hardy\13.jpg:
#   - Dự đoán: person_14_tom_hardy (Score: 1.00)
#   - Thực tế: person_14_tom_hardy
# Kết quả từ ./datasets/data\person_5_giang\10.jpg:
#   - Dự đoán: person_5_Giang (Score: 1.00)
#   - Thực tế: person_5_giang
# Kết quả từ ./datasets/data\person_23_h2h\12.jpg:
#   - Dự đoán: person_23_h2h (Score: 1.00)
#   - Thực tế: person_23_h2h
# Kết quả từ ./datasets/data\person_7_phuc\16.jpg:
#   - Dự đoán: person_7_Phuc (Score: 1.00)
#   - Thực tế: person_7_phuc
# Kết quả từ ./datasets/data\person_26_suboi\19.jpg:
#   - Dự đoán: person_26_suboi (Score: 1.00)
#   - Thực tế: person_26_suboi
# Kết quả từ ./datasets/data\person_11_timmothy\13.jpg:
#   - Dự đoán: person_11_timmothy (Score: 1.00)
#   - Thực tế: person_11_timmothy
# Kết quả từ ./datasets/data\person_31_anh_tu\5.jpg:
#   - Dự đoán: person_31_anh_tu (Score: 1.00)
#   - Thực tế: person_31_anh_tu
# Kết quả từ ./datasets/data\person_7_phuc\17.jpg:
#   - Dự đoán: person_7_Phuc (Score: 1.00)
#   - Thực tế: person_7_phuc
# Kết quả từ ./datasets/data\person_16_chris\4.jpg:
#   - Dự đoán: person_16_chris (Score: 1.00)
#   - Thực tế: person_16_chris
# Kết quả từ ./datasets/data\person_22_atus\14.jpg:
#   - Dự đoán: person_22_atus (Score: 1.00)
#   - Thực tế: person_22_atus
# Kết quả từ ./datasets/data\person_15_tom_cruise\1.jpg:
#   - Dự đoán: person_15_tom_cruise (Score: 1.00)
#   - Thực tế: person_15_tom_cruise
# Kết quả từ ./datasets/data\person_33_harrington\8.jpg:
#   - Dự đoán: person_33_harrington (Score: 1.00)
#   - Thực tế: person_33_harrington
# Kết quả từ ./datasets/data\person_14_tom_hardy\9.jpg:
#   - Dự đoán: person_14_tom_hardy (Score: 1.00)
#   - Thực tế: person_14_tom_hardy
# Kết quả từ ./datasets/data\person_13_katty_perry\12.jpg:
#   - Dự đoán: person_13_katty_perry (Score: 1.00)
#   - Thực tế: person_13_katty_perry
# Kết quả từ ./datasets/data\person_36_brad\8.jpg:
#   - Dự đoán: person_36_brad (Score: 1.00)
#   - Thực tế: person_36_brad
# Kết quả từ ./datasets/data\person_5_giang\4.jpg:
#   - Dự đoán: person_5_Giang (Score: 1.00)
#   - Thực tế: person_5_giang
# Kết quả từ ./datasets/data\person_20_justin_bieber\4.jpg:
#   - Dự đoán: person_20_justin_bieber (Score: 1.00)
#   - Thực tế: person_20_justin_bieber
# Kết quả từ ./datasets/data\person_4_nhu\3.jpg:
#   - Dự đoán: person_4_Nhu (Score: 1.00)
#   - Thực tế: person_4_nhu
# Kết quả từ ./datasets/data\person_11_timmothy\21.jpg:
#   - Dự đoán: person_11_timmothy (Score: 1.00)
#   - Thực tế: person_11_timmothy
# Kết quả từ ./datasets/data\person_31_anh_tu\10.jpg:
#   - Dự đoán: person_31_anh_tu (Score: 1.00)
#   - Thực tế: person_31_anh_tu
# Kết quả từ ./datasets/data\person_46_nam_phuong\37.jpg:
#   - Dự đoán: person_46_nam_phuong (Score: 1.00)
#   - Thực tế: person_46_nam_phuong
# Kết quả từ ./datasets/data\person_34_harvey\10.jpg:
#   - Dự đoán: person_34_harvey (Score: 1.00)
#   - Thực tế: person_34_harvey
# Kết quả từ ./datasets/data\person_46_nam_phuong\39.jpg:
#   - Dự đoán: person_46_nam_phuong (Score: 1.00)
#   - Thực tế: person_46_nam_phuong
# Kết quả từ ./datasets/data\person_17_bruno_mar\10.jpg:
#   - Dự đoán: person_17_bruno_mar (Score: 0.99)
#   - Thực tế: person_17_bruno_mar
# Kết quả từ ./datasets/data\person_16_chris\0.jpg:
#   - Dự đoán: person_16_chris (Score: 1.00)
#   - Thực tế: person_16_chris
# Kết quả từ ./datasets/data\person_30_erik\3.jpg:
#   - Dự đoán: person_30_erik (Score: 1.00)
#   - Thực tế: person_30_erik
# Kết quả từ ./datasets/data\person_45_tuan_anh\10.jpg:
#   - Dự đoán: person_45_tuan_anh (Score: 1.00)
#   - Thực tế: person_45_tuan_anh
# Kết quả từ ./datasets/data\person_31_anh_tu\20.jpg:
#   - Dự đoán: person_31_anh_tu (Score: 1.00)
#   - Thực tế: person_31_anh_tu
# Kết quả từ ./datasets/data\person_12_hiddleston\5.jpg:
#   - Dự đoán: person_12_hiddleston (Score: 1.00)
#   - Thực tế: person_12_hiddleston
# Kết quả từ ./datasets/data\person_11_timmothy\17.jpg:
#   - Dự đoán: person_11_timmothy (Score: 1.00)
#   - Thực tế: person_11_timmothy
# Kết quả từ ./datasets/data\person_26_suboi\8.jpg:
#   - Dự đoán: person_26_suboi (Score: 1.00)
#   - Thực tế: person_26_suboi
# Kết quả từ ./datasets/data\person_5_giang\12.jpg:
#   - Dự đoán: person_5_Giang (Score: 1.00)
#   - Thực tế: person_5_giang
# Kết quả từ ./datasets/data\person_17_bruno_mar\1.jpg:
#   - Dự đoán: person_17_bruno_mar (Score: 0.99)
#   - Thực tế: person_17_bruno_mar
# Kết quả từ ./datasets/data\person_12_hiddleston\18.jpg:
#   - Dự đoán: person_12_hiddleston (Score: 1.00)
#   - Thực tế: person_12_hiddleston
# Kết quả từ ./datasets/data\person_37_hurrykhng\7.jpg:
#   - Dự đoán: person_37_hurrykhng (Score: 1.00)
#   - Thực tế: person_37_hurrykhng
# Kết quả từ ./datasets/data\person_37_hurrykhng\4.jpg:
#   - Dự đoán: person_37_hurrykhng (Score: 1.00)
#   - Thực tế: person_37_hurrykhng
# Kết quả từ ./datasets/data\person_19_sam_smith\0.jpg:
#   - Dự đoán: person_19_sam_smith (Score: 1.00)
#   - Thực tế: person_19_sam_smith
# Kết quả từ ./datasets/data\person_37_hurrykhng\2.jpg:
#   - Dự đoán: person_37_hurrykhng (Score: 1.00)
#   - Thực tế: person_37_hurrykhng
# Kết quả từ ./datasets/data\person_34_harvey\15.jpg:
#   - Dự đoán: person_34_harvey (Score: 1.00)
#   - Thực tế: person_34_harvey
# Kết quả từ ./datasets/data\person_7_phuc\2.jpg:
#   - Dự đoán: person_7_Phuc (Score: 1.00)
#   - Thực tế: person_7_phuc
# Kết quả từ ./datasets/data\person_19_sam_smith\8.jpg:
#   - Dự đoán: person_19_sam_smith (Score: 1.00)
#   - Thực tế: person_19_sam_smith
# Kết quả từ ./datasets/data\person_45_tuan_anh\16.jpg:
#   - Dự đoán: person_45_tuan_anh (Score: 1.00)
#   - Thực tế: person_45_tuan_anh
# Kết quả từ ./datasets/data\person_44_yen_nhi\13.jpg:
#   - Dự đoán: person_44_yen_nhi (Score: 1.00)
#   - Thực tế: person_44_yen_nhi
# Kết quả từ ./datasets/data\person_12_hiddleston\14.jpg:
#   - Dự đoán: person_12_hiddleston (Score: 1.00)
#   - Thực tế: person_12_hiddleston
# Kết quả từ ./datasets/data\person_20_justin_bieber\14.jpg:
#   - Dự đoán: person_20_justin_bieber (Score: 1.00)
#   - Thực tế: person_20_justin_bieber
# Kết quả từ ./datasets/data\person_36_brad\0.jpg:
#   - Dự đoán: person_36_brad (Score: 1.00)
#   - Thực tế: person_36_brad
# Kết quả từ ./datasets/data\person_19_sam_smith\11.jpg:
#   - Dự đoán: person_19_sam_smith (Score: 1.00)
#   - Thực tế: person_19_sam_smith
# Kết quả từ ./datasets/data\person_46_nam_phuong\36.jpg:
#   - Dự đoán: person_46_nam_phuong (Score: 1.00)
#   - Thực tế: person_46_nam_phuong
# Kết quả từ ./datasets/data\person_42_minh\4.jpg:
#   - Dự đoán: person_42_minh (Score: 1.00)
#   - Thực tế: person_42_minh
# Kết quả từ ./datasets/data\person_36_brad\13.jpg:
#   - Dự đoán: person_36_brad (Score: 1.00)
#   - Thực tế: person_36_brad
# Kết quả từ ./datasets/data\person_43_dang\18.jpg:
#   - Dự đoán: person_43_dang (Score: 1.00)
#   - Thực tế: person_43_dang
# Kết quả từ ./datasets/data\person_44_yen_nhi\11.jpg:
#   - Dự đoán: person_44_yen_nhi (Score: 1.00)
#   - Thực tế: person_44_yen_nhi
# Kết quả từ ./datasets/data\person_45_tuan_anh\19.jpg:
#   - Dự đoán: person_45_tuan_anh (Score: 1.00)
#   - Thực tế: person_45_tuan_anh
# Kết quả từ ./datasets/data\person_40_tranthanh\9.jpg:
#   - Dự đoán: person_40_tranthanh (Score: 1.00)
#   - Thực tế: person_40_tranthanh
# Kết quả từ ./datasets/data\person_15_tom_cruise\20.jpg:
#   - Dự đoán: person_15_tom_cruise (Score: 1.00)
#   - Thực tế: person_15_tom_cruise
# Kết quả từ ./datasets/data\person_14_tom_hardy\28.jpg:
#   - Dự đoán: person_14_tom_hardy (Score: 1.00)
#   - Thực tế: person_14_tom_hardy
# Kết quả từ ./datasets/data\person_39_crisdevil\6.jpg:
#   - Dự đoán: person_39_crisdevil (Score: 1.00)
#   - Thực tế: person_39_crisdevil
# Kết quả từ ./datasets/data\person_10_tom_holland\22.jpg:
#   - Dự đoán: person_10_tom_holland (Score: 1.00)
#   - Thực tế: person_10_tom_holland
# Kết quả từ ./datasets/data\person_8_tony\7.jpg:
#   - Dự đoán: person_8_tony (Score: 1.00)
#   - Thực tế: person_8_tony
# Kết quả từ ./datasets/data\person_38_manbo\19.jpg:
#   - Dự đoán: person_38_manbo (Score: 1.00)
#   - Thực tế: person_38_manbo
# Kết quả từ ./datasets/data\person_45_tuan_anh\1.jpg:
#   - Dự đoán: person_45_tuan_anh (Score: 1.00)
#   - Thực tế: person_45_tuan_anh
# Kết quả từ ./datasets/data\person_10_tom_holland\15.jpg:
#   - Dự đoán: person_10_tom_holland (Score: 1.00)
#   - Thực tế: person_10_tom_holland
# Kết quả từ ./datasets/data\person_36_brad\5.jpg:
#   - Dự đoán: person_36_brad (Score: 1.00)
#   - Thực tế: person_36_brad
# Kết quả từ ./datasets/data\person_42_minh\10.jpg:
#   - Dự đoán: person_42_minh (Score: 1.00)
#   - Thực tế: person_42_minh
# Kết quả từ ./datasets/data\person_43_dang\15.jpg:
#   - Dự đoán: person_43_dang (Score: 1.00)
#   - Thực tế: person_43_dang
# Kết quả từ ./datasets/data\person_44_yen_nhi\18.jpg:
#   - Dự đoán: person_44_yen_nhi (Score: 1.00)
#   - Thực tế: person_44_yen_nhi
# Kết quả từ ./datasets/data\person_46_nam_phuong\34.jpg:
#   - Dự đoán: person_46_nam_phuong (Score: 1.00)
#   - Thực tế: person_46_nam_phuong
# Kết quả từ ./datasets/data\person_9_laufey\20.jpg:
#   - Dự đoán: person_9_laufey (Score: 1.00)
#   - Thực tế: person_9_laufey
# Kết quả từ ./datasets/data\person_35_will__smith\4.jpg:
#   - Dự đoán: person_35_will__smith (Score: 1.00)
#   - Thực tế: person_35_will__smith
# Kết quả từ ./datasets/data\person_16_chris\12.jpg:
#   - Dự đoán: person_16_chris (Score: 1.00)
#   - Thực tế: person_16_chris
# Kết quả từ ./datasets/data\person_44_yen_nhi\10.jpg:
#   - Dự đoán: person_44_yen_nhi (Score: 1.00)
#   - Thực tế: person_44_yen_nhi
# Kết quả từ ./datasets/data\person_40_tranthanh\26.jpg:
#   - Dự đoán: person_40_tranthanh (Score: 1.00)
#   - Thực tế: person_40_tranthanh
# Kết quả từ ./datasets/data\person_41_quynh\1.jpg:
#   - Dự đoán: person_41_quynh (Score: 1.00)
#   - Thực tế: person_41_quynh
# Kết quả từ ./datasets/data\person_43_dang\9.jpg:
#   - Dự đoán: person_43_dang (Score: 1.00)
#   - Thực tế: person_43_dang
# Kết quả từ ./datasets/data\person_41_quynh\2.jpg:
#   - Dự đoán: person_41_quynh (Score: 1.00)
#   - Thực tế: person_41_quynh
# Kết quả từ ./datasets/data\person_13_katty_perry\1.jpg:
#   - Dự đoán: person_13_katty_perry (Score: 1.00)
#   - Thực tế: person_13_katty_perry
# Kết quả từ ./datasets/data\person_27_mck\13.jpg:
#   - Dự đoán: person_27_mck (Score: 1.00)
#   - Thực tế: person_27_mck
# Kết quả từ ./datasets/data\person_9_laufey\21.jpg:
#   - Dự đoán: person_9_laufey (Score: 1.00)
#   - Thực tế: person_9_laufey
# Kết quả từ ./datasets/data\person_46_nam_phuong\10.jpg:
#   - Dự đoán: person_46_nam_phuong (Score: 0.99)
#   - Thực tế: person_46_nam_phuong
# Kết quả từ ./datasets/data\person_50_qanh\1.jpg:
#   - Dự đoán: person_50_qanh (Score: 1.00)
#   - Thực tế: person_50_qanh
# Kết quả từ ./datasets/data\person_42_minh\12.jpg:
#   - Dự đoán: person_42_minh (Score: 1.00)
#   - Thực tế: person_42_minh
# Kết quả từ ./datasets/data\person_41_quynh\21.jpg:
#   - Dự đoán: person_41_quynh (Score: 1.00)
#   - Thực tế: person_41_quynh
# Kết quả từ ./datasets/data\person_40_tranthanh\8.jpg:
#   - Dự đoán: person_40_tranthanh (Score: 1.00)
#   - Thực tế: person_40_tranthanh
# Kết quả từ ./datasets/data\person_22_atus\0.jpg:
#   - Dự đoán: person_22_atus (Score: 1.00)
#   - Thực tế: person_22_atus
# Kết quả từ ./datasets/data\person_45_tuan_anh\14.jpg:
#   - Dự đoán: person_45_tuan_anh (Score: 1.00)
#   - Thực tế: person_45_tuan_anh
# Kết quả từ ./datasets/data\person_10_tom_holland\4.jpg:
#   - Dự đoán: person_10_tom_holland (Score: 1.00)
#   - Thực tế: person_10_tom_holland
# Kết quả từ ./datasets/data\person_32_andrew_garfiled\5.jpg:
#   - Dự đoán: person_32_andrew_garfiled (Score: 1.00)
#   - Thực tế: person_32_andrew_garfiled
# Kết quả từ ./datasets/data\person_4_nhu\15.jpg:
#   - Dự đoán: person_4_Nhu (Score: 1.00)
#   - Thực tế: person_4_nhu
# Kết quả từ ./datasets/data\person_42_minh\20.jpg:
#   - Dự đoán: person_42_minh (Score: 1.00)
#   - Thực tế: person_42_minh
# Kết quả từ ./datasets/data\person_43_dang\6.jpg:
#   - Dự đoán: person_43_dang (Score: 1.00)
#   - Thực tế: person_43_dang
# Kết quả từ ./datasets/data\person_42_minh\5.jpg:
#   - Dự đoán: person_42_minh (Score: 1.00)
#   - Thực tế: person_42_minh
# Kết quả từ ./datasets/data\person_37_hurrykhng\11.jpg:
#   - Dự đoán: person_37_hurrykhng (Score: 1.00)
#   - Thực tế: person_37_hurrykhng
# Kết quả từ ./datasets/data\person_45_tuan_anh\20.jpg:
#   - Dự đoán: person_45_tuan_anh (Score: 1.00)
#   - Thực tế: person_45_tuan_anh
# Kết quả từ ./datasets/data\person_43_dang\0.jpg:
#   - Dự đoán: person_43_dang (Score: 1.00)
#   - Thực tế: person_43_dang
# Kết quả từ ./datasets/data\person_10_tom_holland\23.jpg:
#   - Dự đoán: person_10_tom_holland (Score: 1.00)
#   - Thực tế: person_10_tom_holland
# Kết quả từ ./datasets/data\person_9_laufey\6.jpg:
#   - Dự đoán: person_9_laufey (Score: 1.00)
#   - Thực tế: person_9_laufey
# Kết quả từ ./datasets/data\person_43_dang\26.jpg:
#   - Dự đoán: person_43_dang (Score: 1.00)
#   - Thực tế: person_43_dang
# Kết quả từ ./datasets/data\person_50_qanh\11.jpg:
#   - Dự đoán: person_50_qanh (Score: 1.00)
#   - Thực tế: person_50_qanh
# Kết quả từ ./datasets/data\person_45_tuan_anh\5.jpg:
#   - Dự đoán: person_45_tuan_anh (Score: 1.00)
#   - Thực tế: person_45_tuan_anh
# Kết quả từ ./datasets/data\person_23_h2h\3.jpg:
#   - Dự đoán: person_23_h2h (Score: 1.00)
#   - Thực tế: person_23_h2h
# Kết quả từ ./datasets/data\person_13_katty_perry\7.jpg:
#   - Dự đoán: person_13_katty_perry (Score: 1.00)
#   - Thực tế: person_13_katty_perry
# Kết quả từ ./datasets/data\person_22_atus\11.jpg:
#   - Dự đoán: person_22_atus (Score: 1.00)
#   - Thực tế: person_22_atus
# Kết quả từ ./datasets/data\person_16_chris\7.jpg:
#   - Dự đoán: person_16_chris (Score: 1.00)
#   - Thực tế: person_16_chris
# Kết quả từ ./datasets/data\person_30_erik\15.jpg:
#   - Dự đoán: person_30_erik (Score: 1.00)
#   - Thực tế: person_30_erik
# Kết quả từ ./datasets/data\person_26_suboi\25.jpg:
#   - Dự đoán: person_26_suboi (Score: 1.00)
#   - Thực tế: person_26_suboi
# Kết quả từ ./datasets/data\person_45_tuan_anh\12.jpg:
#   - Dự đoán: person_45_tuan_anh (Score: 1.00)
#   - Thực tế: person_45_tuan_anh
# Kết quả từ ./datasets/data\person_5_giang\5.jpg:
#   - Dự đoán: person_5_Giang (Score: 1.00)
#   - Thực tế: person_5_giang
# Kết quả từ ./datasets/data\person_46_nam_phuong\4.jpg:
#   - Dự đoán: person_46_nam_phuong (Score: 1.00)
#   - Thực tế: person_46_nam_phuong
# Kết quả từ ./datasets/data\person_17_bruno_mar\15.jpg:
#   - Dự đoán: person_17_bruno_mar (Score: 1.00)
#   - Thực tế: person_17_bruno_mar
# Kết quả từ ./datasets/data\person_19_sam_smith\4.jpg:
#   - Dự đoán: person_19_sam_smith (Score: 1.00)
#   - Thực tế: person_19_sam_smith
# Kết quả từ ./datasets/data\person_38_manbo\12.jpg:
#   - Dự đoán: person_38_manbo (Score: 1.00)
#   - Thực tế: person_38_manbo
# Kết quả từ ./datasets/data\person_42_minh\13.jpg:
#   - Dự đoán: person_42_minh (Score: 1.00)
#   - Thực tế: person_42_minh
# Kết quả từ ./datasets/data\person_11_timmothy\0.jpg:
#   - Dự đoán: person_11_timmothy (Score: 1.00)
#   - Thực tế: person_11_timmothy
# Kết quả từ ./datasets/data\person_17_bruno_mar\7.jpg:
#   - Dự đoán: person_17_bruno_mar (Score: 1.00)
#   - Thực tế: person_17_bruno_mar
# Kết quả từ ./datasets/data\person_7_phuc\28.jpg:
#   - Dự đoán: person_7_Phuc (Score: 1.00)
#   - Thực tế: person_7_phuc
# Kết quả từ ./datasets/data\person_39_crisdevil\10.jpg:
#   - Dự đoán: person_39_crisdevil (Score: 1.00)
#   - Thực tế: person_39_crisdevil
# Kết quả từ ./datasets/data\person_10_tom_holland\28.jpg:
#   - Dự đoán: person_10_tom_holland (Score: 1.00)
#   - Thực tế: person_10_tom_holland
# Kết quả từ ./datasets/data\person_35_will__smith\19.jpg:
#   - Dự đoán: person_35_will__smith (Score: 1.00)
#   - Thực tế: person_35_will__smith
# Kết quả từ ./datasets/data\person_12_hiddleston\13.jpg:
#   - Dự đoán: person_12_hiddleston (Score: 1.00)
#   - Thực tế: person_12_hiddleston
# Kết quả từ ./datasets/data\person_46_nam_phuong\0.jpg:
#   - Dự đoán: person_46_nam_phuong (Score: 0.99)
#   - Thực tế: person_46_nam_phuong
# Kết quả từ ./datasets/data\person_7_phuc\11.jpg:
#   - Dự đoán: person_7_Phuc (Score: 1.00)
#   - Thực tế: person_7_phuc
# Kết quả từ ./datasets/data\person_16_chris\14.jpg:
#   - Dự đoán: person_16_chris (Score: 1.00)
#   - Thực tế: person_16_chris
# Kết quả từ ./datasets/data\person_33_harrington\14.jpg:
#   - Dự đoán: person_33_harrington (Score: 1.00)
#   - Thực tế: person_33_harrington
# Kết quả từ ./datasets/data\person_7_phuc\25.jpg:
#   - Dự đoán: person_7_Phuc (Score: 1.00)
#   - Thực tế: person_7_phuc
# Kết quả từ ./datasets/data\person_45_tuan_anh\3.jpg:
#   - Dự đoán: person_45_tuan_anh (Score: 1.00)
#   - Thực tế: person_45_tuan_anh
# Kết quả từ ./datasets/data\person_40_tranthanh\21.jpg:
#   - Dự đoán: person_40_tranthanh (Score: 1.00)
#   - Thực tế: person_40_tranthanh
# Kết quả từ ./datasets/data\person_31_anh_tu\27.jpg:
#   - Dự đoán: person_31_anh_tu (Score: 1.00)
#   - Thực tế: person_31_anh_tu
# Kết quả từ ./datasets/data\person_7_phuc\20.jpg:
#   - Dự đoán: person_7_Phuc (Score: 1.00)
#   - Thực tế: person_7_phuc
# Kết quả từ ./datasets/data\person_41_quynh\18.jpg:
#   - Dự đoán: person_41_quynh (Score: 1.00)
#   - Thực tế: person_41_quynh
# Kết quả từ ./datasets/data\person_30_erik\28.jpg:
#   - Dự đoán: person_30_erik (Score: 1.00)
#   - Thực tế: person_30_erik
# Kết quả từ ./datasets/data\person_45_tuan_anh\7.jpg:
#   - Dự đoán: person_45_tuan_anh (Score: 1.00)
#   - Thực tế: person_45_tuan_anh
# Kết quả từ ./datasets/data\person_41_quynh\4.jpg:
#   - Dự đoán: person_41_quynh (Score: 1.00)
#   - Thực tế: person_41_quynh
# Kết quả từ ./datasets/data\person_46_nam_phuong\26.jpg:
#   - Dự đoán: person_46_nam_phuong (Score: 1.00)
#   - Thực tế: person_46_nam_phuong
# Kết quả từ ./datasets/data\person_36_brad\16.jpg:
#   - Dự đoán: person_36_brad (Score: 1.00)
#   - Thực tế: person_36_brad
# Kết quả từ ./datasets/data\person_22_atus\9.jpg:
#   - Dự đoán: person_22_atus (Score: 1.00)
#   - Thực tế: person_22_atus
# Kết quả từ ./datasets/data\person_10_tom_holland\33.jpg:
#   - Dự đoán: person_10_tom_holland (Score: 1.00)
#   - Thực tế: person_10_tom_holland
# Kết quả từ ./datasets/data\person_38_manbo\5.jpg:
#   - Dự đoán: person_38_manbo (Score: 1.00)
#   - Thực tế: person_38_manbo
# Kết quả từ ./datasets/data\person_43_dang\11.jpg:
#   - Dự đoán: person_43_dang (Score: 1.00)
#   - Thực tế: person_43_dang
# Kết quả từ ./datasets/data\person_33_harrington\6.jpg:
#   - Dự đoán: person_33_harrington (Score: 1.00)
#   - Thực tế: person_33_harrington
# Kết quả từ ./datasets/data\person_34_harvey\5.jpg:
#   - Dự đoán: person_34_harvey (Score: 1.00)
#   - Thực tế: person_34_harvey
# Kết quả từ ./datasets/data\person_17_bruno_mar\3.jpg:
#   - Dự đoán: person_17_bruno_mar (Score: 1.00)
#   - Thực tế: person_17_bruno_mar
# Kết quả từ ./datasets/data\person_30_erik\0.jpg:
#   - Dự đoán: person_30_erik (Score: 1.00)
#   - Thực tế: person_30_erik
# Kết quả từ ./datasets/data\person_39_crisdevil\17.jpg:
#   - Dự đoán: person_39_crisdevil (Score: 1.00)
#   - Thực tế: person_39_crisdevil
# Kết quả từ ./datasets/data\person_5_giang\13.jpg:
#   - Dự đoán: person_5_Giang (Score: 1.00)
#   - Thực tế: person_5_giang
# Kết quả từ ./datasets/data\person_40_tranthanh\30.jpg:
#   - Dự đoán: person_40_tranthanh (Score: 1.00)
#   - Thực tế: person_40_tranthanh
# Kết quả từ ./datasets/data\person_45_tuan_anh\11.jpg:
#   - Dự đoán: person_45_tuan_anh (Score: 1.00)
#   - Thực tế: person_45_tuan_anh
# Kết quả từ ./datasets/data\person_14_tom_hardy\35.jpg:
#   - Dự đoán: person_14_tom_hardy (Score: 1.00)
#   - Thực tế: person_14_tom_hardy
# Kết quả từ ./datasets/data\person_44_yen_nhi\3.jpg:
#   - Dự đoán: person_44_yen_nhi (Score: 1.00)
#   - Thực tế: person_44_yen_nhi
# Kết quả từ ./datasets/data\person_36_brad\9.jpg:
#   - Dự đoán: person_36_brad (Score: 1.00)
#   - Thực tế: person_36_brad
# Kết quả từ ./datasets/data\person_27_mck\14.jpg:
#   - Dự đoán: person_27_mck (Score: 1.00)
#   - Thực tế: person_27_mck
# Kết quả từ ./datasets/data\person_4_nhu\9.jpg:
#   - Dự đoán: person_4_Nhu (Score: 1.00)
#   - Thực tế: person_4_nhu
# Kết quả từ ./datasets/data\person_44_yen_nhi\31.jpg:
#   - Dự đoán: person_44_yen_nhi (Score: 1.00)
#   - Thực tế: person_44_yen_nhi
# Kết quả từ ./datasets/data\person_15_tom_cruise\9.jpg:
#   - Dự đoán: person_15_tom_cruise (Score: 1.00)
#   - Thực tế: person_15_tom_cruise
# Kết quả từ ./datasets/data\person_15_tom_cruise\14.jpg:
#   - Dự đoán: person_15_tom_cruise (Score: 1.00)
#   - Thực tế: person_15_tom_cruise
# Kết quả từ ./datasets/data\person_7_phuc\6.jpg:
#   - Dự đoán: person_7_Phuc (Score: 1.00)
#   - Thực tế: person_7_phuc
# Kết quả từ ./datasets/data\person_50_qanh\8.jpg:
#   - Dự đoán: person_50_qanh (Score: 1.00)
#   - Thực tế: person_50_qanh
# Kết quả từ ./datasets/data\person_38_manbo\2.jpg:
#   - Dự đoán: person_38_manbo (Score: 1.00)
#   - Thực tế: person_38_manbo
# Kết quả từ ./datasets/data\person_50_qanh\5.jpg:
#   - Dự đoán: person_50_qanh (Score: 1.00)
#   - Thực tế: person_50_qanh
# Kết quả từ ./datasets/data\person_39_crisdevil\0.jpg:
#   - Dự đoán: person_39_crisdevil (Score: 1.00)
#   - Thực tế: person_39_crisdevil
# Kết quả từ ./datasets/data\person_39_crisdevil\14.jpg:
#   - Dự đoán: person_39_crisdevil (Score: 1.00)
#   - Thực tế: person_39_crisdevil
# Kết quả từ ./datasets/data\person_44_yen_nhi\20.jpg:
#   - Dự đoán: person_44_yen_nhi (Score: 1.00)
#   - Thực tế: person_44_yen_nhi
# Kết quả từ ./datasets/data\person_31_anh_tu\16.jpg:
#   - Dự đoán: person_31_anh_tu (Score: 1.00)
#   - Thực tế: person_31_anh_tu
# Kết quả từ ./datasets/data\person_26_suboi\23.jpg:
#   - Dự đoán: person_26_suboi (Score: 1.00)
#   - Thực tế: person_26_suboi
# Kết quả từ ./datasets/data\person_26_suboi\20.jpg:
#   - Dự đoán: person_26_suboi (Score: 1.00)
#   - Thực tế: person_26_suboi
# Kết quả từ ./datasets/data\person_31_anh_tu\3.jpg:
#   - Dự đoán: person_31_anh_tu (Score: 1.00)
#   - Thực tế: person_31_anh_tu
# Kết quả từ ./datasets/data\person_32_andrew_garfiled\0.jpg:
#   - Dự đoán: person_32_andrew_garfiled (Score: 1.00)
#   - Thực tế: person_32_andrew_garfiled
# Kết quả từ ./datasets/data\person_9_laufey\15.jpg:
#   - Dự đoán: person_9_laufey (Score: 1.00)
#   - Thực tế: person_9_laufey
# Kết quả từ ./datasets/data\person_38_manbo\1.jpg:
#   - Dự đoán: person_38_manbo (Score: 1.00)
#   - Thực tế: person_38_manbo
# Kết quả từ ./datasets/data\person_12_hiddleston\1.jpg:
#   - Dự đoán: person_12_hiddleston (Score: 1.00)
#   - Thực tế: person_12_hiddleston
# Kết quả từ ./datasets/data\person_43_dang\8.jpg:
#   - Dự đoán: person_43_dang (Score: 1.00)
#   - Thực tế: person_43_dang
# Kết quả từ ./datasets/data\person_34_harvey\11.jpg:
#   - Dự đoán: person_34_harvey (Score: 1.00)
#   - Thực tế: person_34_harvey
# Kết quả từ ./datasets/data\person_15_tom_cruise\22.jpg:
#   - Dự đoán: person_15_tom_cruise (Score: 1.00)
#   - Thực tế: person_15_tom_cruise
# Kết quả từ ./datasets/data\person_34_harvey\14.jpg:
#   - Dự đoán: person_34_harvey (Score: 1.00)
#   - Thực tế: person_34_harvey
# Kết quả từ ./datasets/data\person_10_tom_holland\12.jpg:
#   - Dự đoán: person_10_tom_holland (Score: 1.00)
#   - Thực tế: person_10_tom_holland
# Kết quả từ ./datasets/data\person_32_andrew_garfiled\18.jpg:
#   - Dự đoán: person_32_andrew_garfiled (Score: 1.00)
#   - Thực tế: person_32_andrew_garfiled
# Kết quả từ ./datasets/data\person_12_hiddleston\17.jpg:
#   - Dự đoán: person_12_hiddleston (Score: 1.00)
#   - Thực tế: person_12_hiddleston
# Kết quả từ ./datasets/data\person_45_tuan_anh\2.jpg:
#   - Dự đoán: person_45_tuan_anh (Score: 1.00)
#   - Thực tế: person_45_tuan_anh
# Kết quả từ ./datasets/data\person_34_harvey\6.jpg:
#   - Dự đoán: person_34_harvey (Score: 1.00)
#   - Thực tế: person_34_harvey
# Kết quả từ ./datasets/data\person_8_tony\2.jpg:
#   - Dự đoán: person_8_tony (Score: 1.00)
#   - Thực tế: person_8_tony
# Kết quả từ ./datasets/data\person_36_brad\3.jpg:
#   - Dự đoán: person_36_brad (Score: 1.00)
#   - Thực tế: person_36_brad
# Kết quả từ ./datasets/data\person_44_yen_nhi\23.jpg:
#   - Dự đoán: person_44_yen_nhi (Score: 1.00)
#   - Thực tế: person_44_yen_nhi
# Kết quả từ ./datasets/data\person_12_hiddleston\19.jpg:
#   - Dự đoán: person_12_hiddleston (Score: 1.00)
#   - Thực tế: person_12_hiddleston
# Kết quả từ ./datasets/data\person_15_tom_cruise\6.jpg:
#   - Dự đoán: person_15_tom_cruise (Score: 1.00)
#   - Thực tế: person_15_tom_cruise
# Kết quả từ ./datasets/data\person_34_harvey\0.jpg:
#   - Dự đoán: person_34_harvey (Score: 1.00)
#   - Thực tế: person_34_harvey
# Kết quả từ ./datasets/data\person_44_yen_nhi\15.jpg:
#   - Dự đoán: person_44_yen_nhi (Score: 1.00)
#   - Thực tế: person_44_yen_nhi
# Kết quả từ ./datasets/data\person_35_will__smith\8.jpg:
#   - Dự đoán: person_35_will__smith (Score: 1.00)
#   - Thực tế: person_35_will__smith
# Kết quả từ ./datasets/data\person_33_harrington\13.jpg:
#   - Dự đoán: person_33_harrington (Score: 1.00)
#   - Thực tế: person_33_harrington
# Kết quả từ ./datasets/data\person_8_tony\12.jpg:
#   - Dự đoán: person_8_tony (Score: 1.00)
#   - Thực tế: person_8_tony
# Kết quả từ ./datasets/data\person_5_giang\14.jpg:
#   - Dự đoán: person_5_Giang (Score: 1.00)
#   - Thực tế: person_5_giang
# Kết quả từ ./datasets/data\person_22_atus\10.jpg:
#   - Dự đoán: person_22_atus (Score: 1.00)
#   - Thực tế: person_22_atus
# Kết quả từ ./datasets/data\person_19_sam_smith\9.jpg:
#   - Dự đoán: person_19_sam_smith (Score: 1.00)
#   - Thực tế: person_19_sam_smith
# Kết quả từ ./datasets/data\person_31_anh_tu\1.jpg:
#   - Dự đoán: person_31_anh_tu (Score: 1.00)
#   - Thực tế: person_31_anh_tu
# Kết quả từ ./datasets/data\person_41_quynh\23.jpg:
#   - Dự đoán: person_41_quynh (Score: 1.00)
#   - Thực tế: person_41_quynh
# Kết quả từ ./datasets/data\person_39_crisdevil\2.jpg:
#   - Dự đoán: person_39_crisdevil (Score: 1.00)
#   - Thực tế: person_39_crisdevil
# Kết quả từ ./datasets/data\person_40_tranthanh\18.jpg:
#   - Dự đoán: person_40_tranthanh (Score: 1.00)
#   - Thực tế: person_40_tranthanh
# Kết quả từ ./datasets/data\person_11_timmothy\4.jpg:
#   - Dự đoán: person_11_timmothy (Score: 1.00)
#   - Thực tế: person_11_timmothy
# Kết quả từ ./datasets/data\person_45_tuan_anh\13.jpg:
#   - Dự đoán: person_45_tuan_anh (Score: 1.00)
#   - Thực tế: person_45_tuan_anh
# Kết quả từ ./datasets/data\person_46_nam_phuong\20.jpg:
#   - Dự đoán: person_46_nam_phuong (Score: 1.00)
#   - Thực tế: person_46_nam_phuong
# Kết quả từ ./datasets/data\person_12_hiddleston\4.jpg:
#   - Dự đoán: person_12_hiddleston (Score: 1.00)
#   - Thực tế: person_12_hiddleston
# Kết quả từ ./datasets/data\person_14_tom_hardy\0.jpg:
#   - Dự đoán: person_14_tom_hardy (Score: 1.00)
#   - Thực tế: person_14_tom_hardy
# Kết quả từ ./datasets/data\person_41_quynh\3.jpg:
#   - Dự đoán: person_41_quynh (Score: 1.00)
#   - Thực tế: person_41_quynh
# Kết quả từ ./datasets/data\person_13_katty_perry\13.jpg:
#   - Dự đoán: person_13_katty_perry (Score: 1.00)
#   - Thực tế: person_13_katty_perry
# Kết quả từ ./datasets/data\person_44_yen_nhi\27.jpg:
#   - Dự đoán: person_44_yen_nhi (Score: 1.00)
#   - Thực tế: person_44_yen_nhi
# Kết quả từ ./datasets/data\person_46_nam_phuong\27.jpg:
#   - Dự đoán: person_46_nam_phuong (Score: 1.00)
#   - Thực tế: person_46_nam_phuong
# Kết quả từ ./datasets/data\person_15_tom_cruise\4.jpg:
#   - Dự đoán: person_15_tom_cruise (Score: 1.00)
#   - Thực tế: person_15_tom_cruise
# Kết quả từ ./datasets/data\person_40_tranthanh\28.jpg:
#   - Dự đoán: person_40_tranthanh (Score: 1.00)
#   - Thực tế: person_40_tranthanh
# Kết quả từ ./datasets/data\person_46_nam_phuong\33.jpg:
#   - Dự đoán: person_46_nam_phuong (Score: 1.00)
#   - Thực tế: person_46_nam_phuong
# Kết quả từ ./datasets/data\person_33_harrington\4.jpg:
#   - Dự đoán: person_33_harrington (Score: 1.00)
#   - Thực tế: person_33_harrington
# Kết quả từ ./datasets/data\person_31_anh_tu\9.jpg:
#   - Dự đoán: person_31_anh_tu (Score: 1.00)
#   - Thực tế: person_31_anh_tu
# Kết quả từ ./datasets/data\person_10_tom_holland\14.jpg:
#   - Dự đoán: person_10_tom_holland (Score: 1.00)
#   - Thực tế: person_10_tom_holland
# Kết quả từ ./datasets/data\person_11_timmothy\6.jpg:
#   - Dự đoán: person_11_timmothy (Score: 1.00)
#   - Thực tế: person_11_timmothy
# Kết quả từ ./datasets/data\person_26_suboi\24.jpg:
#   - Dự đoán: person_26_suboi (Score: 1.00)
#   - Thực tế: person_26_suboi
# Kết quả từ ./datasets/data\person_17_bruno_mar\9.jpg:
#   - Dự đoán: person_17_bruno_mar (Score: 0.99)
#   - Thực tế: person_17_bruno_mar
# Kết quả từ ./datasets/data\person_32_andrew_garfiled\11.jpg:
#   - Dự đoán: person_32_andrew_garfiled (Score: 1.00)
#   - Thực tế: person_32_andrew_garfiled
# Kết quả từ ./datasets/data\person_50_qanh\0.jpg:
#   - Dự đoán: person_50_qanh (Score: 1.00)
#   - Thực tế: person_50_qanh
# Kết quả từ ./datasets/data\person_14_tom_hardy\8.jpg:
#   - Dự đoán: person_14_tom_hardy (Score: 1.00)
#   - Thực tế: person_14_tom_hardy
# Kết quả từ ./datasets/data\person_5_giang\15.jpg:
#   - Dự đoán: person_5_Giang (Score: 1.00)
#   - Thực tế: person_5_giang
# Kết quả từ ./datasets/data\person_10_tom_holland\2.jpg:
#   - Dự đoán: person_10_tom_holland (Score: 1.00)
#   - Thực tế: person_10_tom_holland
# Kết quả từ ./datasets/data\person_35_will__smith\13.jpg:
#   - Dự đoán: person_35_will__smith (Score: 1.00)
#   - Thực tế: person_35_will__smith
# Kết quả từ ./datasets/data\person_11_timmothy\5.jpg:
#   - Dự đoán: person_11_timmothy (Score: 1.00)
#   - Thực tế: person_11_timmothy
# Kết quả từ ./datasets/data\person_14_tom_hardy\23.jpg:
#   - Dự đoán: person_14_tom_hardy (Score: 1.00)
#   - Thực tế: person_14_tom_hardy
# Kết quả từ ./datasets/data\person_30_erik\18.jpg:
#   - Dự đoán: person_30_erik (Score: 1.00)
#   - Thực tế: person_30_erik
# Kết quả từ ./datasets/data\person_8_tony\6.jpg:
#   - Dự đoán: person_8_tony (Score: 1.00)
#   - Thực tế: person_8_tony
# Kết quả từ ./datasets/data\person_44_yen_nhi\0.jpg:
#   - Dự đoán: person_44_yen_nhi (Score: 1.00)
#   - Thực tế: person_44_yen_nhi
# Kết quả từ ./datasets/data\person_41_quynh\11.jpg:
#   - Dự đoán: person_41_quynh (Score: 1.00)
#   - Thực tế: person_41_quynh
# Kết quả từ ./datasets/data\person_8_tony\14.jpg:
#   - Dự đoán: person_8_tony (Score: 1.00)
#   - Thực tế: person_8_tony
# Kết quả từ ./datasets/data\person_26_suboi\3.jpg:
# ...
# Kết quả từ ./datasets/data\person_5_giang\1.jpg:
#   - Dự đoán: person_5_Giang (Score: 1.00)
#   - Thực tế: person_5_giang
# Kết quả từ ./datasets/data\person_43_dang\14.jpg:
#   - Dự đoán: person_43_dang (Score: 1.00)
#   - Thực tế: person_43_dang
# Kết quả từ ./datasets/data\person_30_erik\5.jpg:
#   - Dự đoán: person_30_erik (Score: 1.00)
#   - Thực tế: person_30_erik
# Kết quả từ ./datasets/data\person_20_justin_bieber\9.jpg:
#   - Dự đoán: person_20_justin_bieber (Score: 1.00)
#   - Thực tế: person_20_justin_bieber
# Kết quả từ ./datasets/data\person_11_timmothy\1.jpg:
#   - Dự đoán: person_11_timmothy (Score: 1.00)
#   - Thực tế: person_11_timmothy
# Kết quả từ ./datasets/data\person_37_hurrykhng\6.jpg:
#   - Dự đoán: person_37_hurrykhng (Score: 1.00)
#   - Thực tế: person_37_hurrykhng
# Kết quả từ ./datasets/data\person_23_h2h\11.jpg:
#   - Dự đoán: person_23_h2h (Score: 1.00)
#   - Thực tế: person_23_h2h
# Kết quả từ ./datasets/data\person_11_timmothy\18.jpg:
#   - Dự đoán: person_11_timmothy (Score: 1.00)
#   - Thực tế: person_11_timmothy
# Kết quả từ ./datasets/data\person_42_minh\0.jpg:
#   - Dự đoán: person_42_minh (Score: 1.00)
#   - Thực tế: person_42_minh
# Kết quả từ ./datasets/data\person_41_quynh\5.jpg:
#   - Dự đoán: person_41_quynh (Score: 1.00)
#   - Thực tế: person_41_quynh
# Kết quả từ ./datasets/data\person_38_manbo\17.jpg:
#   - Dự đoán: person_38_manbo (Score: 1.00)
#   - Thực tế: person_38_manbo
# Kết quả từ ./datasets/data\person_31_anh_tu\26.jpg:
#   - Dự đoán: person_31_anh_tu (Score: 1.00)
#   - Thực tế: person_31_anh_tu
# Kết quả từ ./datasets/data\person_34_harvey\9.jpg:
#   - Dự đoán: person_34_harvey (Score: 1.00)
#   - Thực tế: person_34_harvey
# Kết quả từ ./datasets/data\person_15_tom_cruise\16.jpg:
#   - Dự đoán: person_15_tom_cruise (Score: 1.00)
#   - Thực tế: person_15_tom_cruise
# Kết quả từ ./datasets/data\person_26_suboi\6.jpg:
#   - Dự đoán: person_26_suboi (Score: 1.00)
#   - Thực tế: person_26_suboi
# Kết quả từ ./datasets/data\person_14_tom_hardy\10.jpg:
#   - Dự đoán: person_14_tom_hardy (Score: 1.00)
#   - Thực tế: person_14_tom_hardy
# Kết quả từ ./datasets/data\person_20_justin_bieber\16.jpg:
#   - Dự đoán: person_20_justin_bieber (Score: 1.00)
#   - Thực tế: person_20_justin_bieber
# Kết quả từ ./datasets/data\person_37_hurrykhng\1.jpg:
#   - Dự đoán: person_37_hurrykhng (Score: 1.00)
#   - Thực tế: person_37_hurrykhng
# Kết quả từ ./datasets/data\person_43_dang\1.jpg:
#   - Dự đoán: person_43_dang (Score: 1.00)
#   - Thực tế: person_43_dang
# Kết quả từ ./datasets/data\person_40_tranthanh\23.jpg:
#   - Dự đoán: person_40_tranthanh (Score: 1.00)
#   - Thực tế: person_40_tranthanh
# Kết quả từ ./datasets/data\person_9_laufey\5.jpg:
#   - Dự đoán: person_9_laufey (Score: 1.00)
#   - Thực tế: person_9_laufey
# Kết quả từ ./datasets/data\person_10_tom_holland\19.jpg:
#   - Dự đoán: person_10_tom_holland (Score: 1.00)
#   - Thực tế: person_10_tom_holland
# Kết quả từ ./datasets/data\person_44_yen_nhi\9.jpg:
#   - Dự đoán: person_44_yen_nhi (Score: 1.00)
#   - Thực tế: person_44_yen_nhi
# Kết quả từ ./datasets/data\person_43_dang\12.jpg:
#   - Dự đoán: person_43_dang (Score: 1.00)
#   - Thực tế: person_43_dang
# Kết quả từ ./datasets/data\person_38_manbo\3.jpg:
#   - Dự đoán: person_38_manbo (Score: 1.00)
#   - Thực tế: person_38_manbo
# Kết quả từ ./datasets/data\person_12_hiddleston\15.jpg:
#   - Dự đoán: person_12_hiddleston (Score: 1.00)
#   - Thực tế: person_12_hiddleston
# Kết quả từ ./datasets/data\person_43_dang\10.jpg:
#   - Dự đoán: person_43_dang (Score: 1.00)
#   - Thực tế: person_43_dang
# Kết quả từ ./datasets/data\person_33_harrington\11.jpg:
#   - Dự đoán: person_33_harrington (Score: 1.00)
#   - Thực tế: person_33_harrington
# Kết quả từ ./datasets/data\person_39_crisdevil\15.jpg:
#   - Dự đoán: person_39_crisdevil (Score: 1.00)
#   - Thực tế: person_39_crisdevil
# Kết quả từ ./datasets/data\person_41_quynh\15.jpg:
#   - Dự đoán: person_41_quynh (Score: 1.00)
#   - Thực tế: person_41_quynh
# Kết quả từ ./datasets/data\person_39_crisdevil\4.jpg:
#   - Dự đoán: person_39_crisdevil (Score: 1.00)
#   - Thực tế: person_39_crisdevil
# Kết quả từ ./datasets/data\person_17_bruno_mar\5.jpg:
#   - Dự đoán: person_17_bruno_mar (Score: 0.99)
#   - Thực tế: person_17_bruno_mar
# Kết quả từ ./datasets/data\person_10_tom_holland\17.jpg:
#   - Dự đoán: person_10_tom_holland (Score: 1.00)
#   - Thực tế: person_10_tom_holland
# Kết quả từ ./datasets/data\person_44_yen_nhi\26.jpg:
#   - Dự đoán: person_44_yen_nhi (Score: 1.00)
#   - Thực tế: person_44_yen_nhi
# Kết quả từ ./datasets/data\person_22_atus\1.jpg:
#   - Dự đoán: person_22_atus (Score: 1.00)
#   - Thực tế: person_22_atus
# Kết quả từ ./datasets/data\person_45_tuan_anh\15.jpg:
#   - Dự đoán: person_45_tuan_anh (Score: 1.00)
#   - Thực tế: person_45_tuan_anh
# Kết quả từ ./datasets/data\person_41_quynh\12.jpg:
#   - Dự đoán: person_41_quynh (Score: 1.00)
#   - Thực tế: person_41_quynh
# Kết quả từ ./datasets/data\person_31_anh_tu\24.jpg:
#   - Dự đoán: person_31_anh_tu (Score: 1.00)
#   - Thực tế: person_31_anh_tu
# Kết quả từ ./datasets/data\person_12_hiddleston\12.jpg:
#   - Dự đoán: person_12_hiddleston (Score: 1.00)
#   - Thực tế: person_12_hiddleston
# Kết quả từ ./datasets/data\person_14_tom_hardy\5.jpg:
#   - Dự đoán: person_14_tom_hardy (Score: 1.00)
#   - Thực tế: person_14_tom_hardy
# Kết quả từ ./datasets/data\person_23_h2h\0.jpg:
#   - Dự đoán: person_23_h2h (Score: 1.00)
#   - Thực tế: person_23_h2h
# Kết quả từ ./datasets/data\person_14_tom_hardy\15.jpg:
#   - Dự đoán: person_14_tom_hardy (Score: 1.00)
#   - Thực tế: person_14_tom_hardy
# Kết quả từ ./datasets/data\person_20_justin_bieber\7.jpg:
#   - Dự đoán: person_20_justin_bieber (Score: 1.00)
#   - Thực tế: person_20_justin_bieber
# Kết quả từ ./datasets/data\person_14_tom_hardy\4.jpg:
#   - Dự đoán: person_14_tom_hardy (Score: 1.00)
#   - Thực tế: person_14_tom_hardy
# Kết quả từ ./datasets/data\person_39_crisdevil\8.jpg:
#   - Dự đoán: person_39_crisdevil (Score: 1.00)
#   - Thực tế: person_39_crisdevil
# Kết quả từ ./datasets/data\person_30_erik\14.jpg:
#   - Dự đoán: person_30_erik (Score: 1.00)
#   - Thực tế: person_30_erik
# Kết quả từ ./datasets/data\person_30_erik\16.jpg:
#   - Dự đoán: person_30_erik (Score: 1.00)
#   - Thực tế: person_30_erik
# Kết quả từ ./datasets/data\person_50_qanh\6.jpg:
#   - Dự đoán: person_50_qanh (Score: 1.00)
#   - Thực tế: person_50_qanh
# Kết quả từ ./datasets/data\person_50_qanh\10.jpg:
#   - Dự đoán: person_50_qanh (Score: 1.00)
#   - Thực tế: person_50_qanh
# Kết quả từ ./datasets/data\person_15_tom_cruise\5.jpg:
#   - Dự đoán: person_15_tom_cruise (Score: 1.00)
#   - Thực tế: person_15_tom_cruise
# Kết quả từ ./datasets/data\person_42_minh\17.jpg:
#   - Dự đoán: person_42_minh (Score: 1.00)
#   - Thực tế: person_42_minh
# Kết quả từ ./datasets/data\person_43_dang\25.jpg:
#   - Dự đoán: person_43_dang (Score: 1.00)
#   - Thực tế: person_43_dang
# Kết quả từ ./datasets/data\person_38_manbo\9.jpg:
#   - Dự đoán: person_38_manbo (Score: 1.00)
#   - Thực tế: person_38_manbo
# Kết quả từ ./datasets/data\person_50_qanh\3.jpg:
#   - Dự đoán: person_50_qanh (Score: 1.00)
#   - Thực tế: person_50_qanh
# Kết quả từ ./datasets/data\person_43_dang\16.jpg:
#   - Dự đoán: person_43_dang (Score: 1.00)
#   - Thực tế: person_43_dang
# Kết quả từ ./datasets/data\person_44_yen_nhi\14.jpg:
#   - Dự đoán: person_44_yen_nhi (Score: 1.00)
#   - Thực tế: person_44_yen_nhi
# Kết quả từ ./datasets/data\person_35_will__smith\15.jpg:
#   - Dự đoán: person_35_will__smith (Score: 1.00)
#   - Thực tế: person_35_will__smith
# Kết quả từ ./datasets/data\person_35_will__smith\9.jpg:
#   - Dự đoán: person_35_will__smith (Score: 1.00)
#   - Thực tế: person_35_will__smith
# Kết quả từ ./datasets/data\person_30_erik\24.jpg:
#   - Dự đoán: person_30_erik (Score: 1.00)
#   - Thực tế: person_30_erik
# Kết quả từ ./datasets/data\person_34_harvey\12.jpg:
#   - Dự đoán: person_34_harvey (Score: 1.00)
#   - Thực tế: person_34_harvey
# Kết quả từ ./datasets/data\person_7_phuc\15.jpg:
#   - Dự đoán: person_7_Phuc (Score: 1.00)
#   - Thực tế: person_7_phuc
# Kết quả từ ./datasets/data\person_7_phuc\4.jpg:
#   - Dự đoán: person_7_Phuc (Score: 1.00)
#   - Thực tế: person_7_phuc
# Kết quả từ ./datasets/data\person_9_laufey\19.jpg:
#   - Dự đoán: person_9_laufey (Score: 1.00)
#   - Thực tế: person_9_laufey
# Kết quả từ ./datasets/data\person_33_harrington\15.jpg:
#   - Dự đoán: person_33_harrington (Score: 1.00)
#   - Thực tế: person_33_harrington
# Kết quả từ ./datasets/data\person_30_erik\23.jpg:
#   - Dự đoán: person_30_erik (Score: 1.00)
#   - Thực tế: person_30_erik
# Kết quả từ ./datasets/data\person_46_nam_phuong\24.jpg:
#   - Dự đoán: person_46_nam_phuong (Score: 1.00)
#   - Thực tế: person_46_nam_phuong
# Kết quả từ ./datasets/data\person_16_chris\8.jpg:
#   - Dự đoán: person_16_chris (Score: 1.00)
#   - Thực tế: person_16_chris
# Kết quả từ ./datasets/data\person_9_laufey\13.jpg:
#   - Dự đoán: person_9_laufey (Score: 1.00)
#   - Thực tế: person_9_laufey
# Kết quả từ ./datasets/data\person_4_nhu\7.jpg:
#   - Dự đoán: person_4_Nhu (Score: 1.00)
#   - Thực tế: person_4_nhu
# Kết quả từ ./datasets/data\person_22_atus\13.jpg:
#   - Dự đoán: person_22_atus (Score: 1.00)
#   - Thực tế: person_22_atus
# Kết quả từ ./datasets/data\person_11_timmothy\9.jpg:
#   - Dự đoán: person_11_timmothy (Score: 1.00)
#   - Thực tế: person_11_timmothy
# Kết quả từ ./datasets/data\person_39_crisdevil\18.jpg:
#   - Dự đoán: person_39_crisdevil (Score: 1.00)
#   - Thực tế: person_39_crisdevil
# Kết quả từ ./datasets/data\person_33_harrington\10.jpg:
#   - Dự đoán: person_33_harrington (Score: 1.00)
#   - Thực tế: person_33_harrington
# Kết quả từ ./datasets/data\person_38_manbo\6.jpg:
#   - Dự đoán: person_38_manbo (Score: 1.00)
#   - Thực tế: person_38_manbo
# Kết quả từ ./datasets/data\person_33_harrington\12.jpg:
#   - Dự đoán: person_33_harrington (Score: 1.00)
#   - Thực tế: person_33_harrington
# Kết quả từ ./datasets/data\person_23_h2h\6.jpg:
#   - Dự đoán: person_23_h2h (Score: 1.00)
#   - Thực tế: person_23_h2h
# Kết quả từ ./datasets/data\person_15_tom_cruise\15.jpg:
#   - Dự đoán: person_15_tom_cruise (Score: 1.00)
#   - Thực tế: person_15_tom_cruise
# Kết quả từ ./datasets/data\person_16_chris\13.jpg:
#   - Dự đoán: person_16_chris (Score: 1.00)
#   - Thực tế: person_16_chris
# Kết quả từ ./datasets/data\person_17_bruno_mar\6.jpg:
#   - Dự đoán: person_17_bruno_mar (Score: 1.00)
#   - Thực tế: person_17_bruno_mar
# Kết quả từ ./datasets/data\person_20_justin_bieber\2.jpg:
#   - Dự đoán: person_20_justin_bieber (Score: 1.00)
#   - Thực tế: person_20_justin_bieber
# Kết quả từ ./datasets/data\person_41_quynh\20.jpg:
#   - Dự đoán: person_41_quynh (Score: 1.00)
#   - Thực tế: person_41_quynh
# Kết quả từ ./datasets/data\person_16_chris\11.jpg:
#   - Dự đoán: person_16_chris (Score: 1.00)
#   - Thực tế: person_16_chris
# Kết quả từ ./datasets/data\person_32_andrew_garfiled\9.jpg:
#   - Dự đoán: person_32_andrew_garfiled (Score: 1.00)
#   - Thực tế: person_32_andrew_garfiled
# Kết quả từ ./datasets/data\person_30_erik\6.jpg:
#   - Dự đoán: person_30_erik (Score: 1.00)
#   - Thực tế: person_30_erik
# Kết quả từ ./datasets/data\person_14_tom_hardy\17.jpg:
#   - Dự đoán: person_14_tom_hardy (Score: 1.00)
#   - Thực tế: person_14_tom_hardy
# Kết quả từ ./datasets/data\person_27_mck\0.jpg:
#   - Dự đoán: person_27_mck (Score: 1.00)
#   - Thực tế: person_27_mck
# Kết quả từ ./datasets/data\person_26_suboi\21.jpg:
#   - Dự đoán: person_26_suboi (Score: 1.00)
#   - Thực tế: person_26_suboi
# Kết quả từ ./datasets/data\person_35_will__smith\11.jpg:
#   - Dự đoán: person_35_will__smith (Score: 1.00)
#   - Thực tế: person_35_will__smith
# Kết quả từ ./datasets/data\person_44_yen_nhi\2.jpg:
#   - Dự đoán: person_44_yen_nhi (Score: 1.00)
#   - Thực tế: person_44_yen_nhi
# Kết quả từ ./datasets/data\person_7_phuc\18.jpg:
#   - Dự đoán: person_7_Phuc (Score: 1.00)
#   - Thực tế: person_7_phuc
# Kết quả từ ./datasets/data\person_4_nhu\4.jpg:
#   - Dự đoán: person_4_Nhu (Score: 1.00)
#   - Thực tế: person_4_nhu
# Kết quả từ ./datasets/data\person_20_justin_bieber\10.jpg:
#   - Dự đoán: person_20_justin_bieber (Score: 1.00)
#   - Thực tế: person_20_justin_bieber
# Kết quả từ ./datasets/data\person_33_harrington\18.jpg:
#   - Dự đoán: person_33_harrington (Score: 1.00)
#   - Thực tế: person_33_harrington
# Kết quả từ ./datasets/data\person_42_minh\9.jpg:
#   - Dự đoán: person_42_minh (Score: 1.00)
#   - Thực tế: person_42_minh
# Kết quả từ ./datasets/data\person_16_chris\6.jpg:
#   - Dự đoán: person_16_chris (Score: 1.00)
#   - Thực tế: person_16_chris
# Kết quả từ ./datasets/data\person_35_will__smith\14.jpg:
#   - Dự đoán: person_35_will__smith (Score: 1.00)
#   - Thực tế: person_35_will__smith
# Kết quả từ ./datasets/data\person_5_giang\3.jpg:
#   - Dự đoán: person_5_Giang (Score: 1.00)
#   - Thực tế: person_5_giang
# Kết quả từ ./datasets/data\person_31_anh_tu\8.jpg:
#   - Dự đoán: person_31_anh_tu (Score: 1.00)
#   - Thực tế: person_31_anh_tu
# Kết quả từ ./datasets/data\person_36_brad\10.jpg:
#   - Dự đoán: person_36_brad (Score: 1.00)
#   - Thực tế: person_36_brad
# Kết quả từ ./datasets/data\person_9_laufey\1.jpg:
#   - Dự đoán: person_9_laufey (Score: 1.00)
#   - Thực tế: person_9_laufey
# Kết quả từ ./datasets/data\person_20_justin_bieber\5.jpg:
#   - Dự đoán: person_20_justin_bieber (Score: 1.00)
#   - Thực tế: person_20_justin_bieber
# Kết quả từ ./datasets/data\person_30_erik\20.jpg:
#   - Dự đoán: person_30_erik (Score: 1.00)
#   - Thực tế: person_30_erik
# Kết quả từ ./datasets/data\person_10_tom_holland\9.jpg:
#   - Dự đoán: person_10_tom_holland (Score: 1.00)
#   - Thực tế: person_10_tom_holland
# Kết quả từ ./datasets/data\person_32_andrew_garfiled\3.jpg:
#   - Dự đoán: person_32_andrew_garfiled (Score: 1.00)
#   - Thực tế: person_32_andrew_garfiled
# Kết quả từ ./datasets/data\person_37_hurrykhng\5.jpg:
#   - Dự đoán: person_37_hurrykhng (Score: 1.00)
#   - Thực tế: person_37_hurrykhng
# Kết quả từ ./datasets/data\person_39_crisdevil\12.jpg:
#   - Dự đoán: person_39_crisdevil (Score: 1.00)
#   - Thực tế: person_39_crisdevil
# Kết quả từ ./datasets/data\person_41_quynh\7.jpg:
#   - Dự đoán: person_41_quynh (Score: 1.00)
#   - Thực tế: person_41_quynh
# Kết quả từ ./datasets/data\person_33_harrington\16.jpg:
#   - Dự đoán: person_33_harrington (Score: 1.00)
#   - Thực tế: person_33_harrington
# Kết quả từ ./datasets/data\person_31_anh_tu\15.jpg:
#   - Dự đoán: person_31_anh_tu (Score: 1.00)
#   - Thực tế: person_31_anh_tu
# Kết quả từ ./datasets/data\person_17_bruno_mar\14.jpg:
#   - Dự đoán: person_17_bruno_mar (Score: 1.00)
#   - Thực tế: person_17_bruno_mar
# Kết quả từ ./datasets/data\person_27_mck\6.jpg:
#   - Dự đoán: person_27_mck (Score: 1.00)
#   - Thực tế: person_27_mck
# Kết quả từ ./datasets/data\person_19_sam_smith\5.jpg:
#   - Dự đoán: person_19_sam_smith (Score: 1.00)
#   - Thực tế: person_19_sam_smith
# Kết quả từ ./datasets/data\person_43_dang\5.jpg:
#   - Dự đoán: person_43_dang (Score: 1.00)
#   - Thực tế: person_43_dang
# Kết quả từ ./datasets/data\person_14_tom_hardy\7.jpg:
#   - Dự đoán: person_14_tom_hardy (Score: 1.00)
#   - Thực tế: person_14_tom_hardy
# Kết quả từ ./datasets/data\person_12_hiddleston\7.jpg:
#   - Dự đoán: person_12_hiddleston (Score: 1.00)
#   - Thực tế: person_12_hiddleston
# Kết quả từ ./datasets/data\person_7_phuc\14.jpg:
#   - Dự đoán: person_7_Phuc (Score: 1.00)
#   - Thực tế: person_7_phuc
# Kết quả từ ./datasets/data\person_16_chris\2.jpg:
#   - Dự đoán: person_16_chris (Score: 1.00)
#   - Thực tế: person_16_chris
# Kết quả từ ./datasets/data\person_38_manbo\15.jpg:
#   - Dự đoán: person_38_manbo (Score: 1.00)
#   - Thực tế: person_38_manbo
# Kết quả từ ./datasets/data\person_36_brad\2.jpg:
#   - Dự đoán: person_36_brad (Score: 1.00)
#   - Thực tế: person_36_brad
# Kết quả từ ./datasets/data\person_31_anh_tu\14.jpg:
#   - Dự đoán: person_31_anh_tu (Score: 1.00)
#   - Thực tế: person_31_anh_tu
# Kết quả từ ./datasets/data\person_26_suboi\12.jpg:
#   - Dự đoán: person_26_suboi (Score: 1.00)
#   - Thực tế: person_26_suboi
# Kết quả từ ./datasets/data\person_7_phuc\24.jpg:
#   - Dự đoán: person_7_Phuc (Score: 1.00)
#   - Thực tế: person_7_phuc
# Kết quả từ ./datasets/data\person_35_will__smith\6.jpg:
#   - Dự đoán: person_35_will__smith (Score: 1.00)
#   - Thực tế: person_35_will__smith
# Kết quả từ ./datasets/data\person_22_atus\7.jpg:
#   - Dự đoán: person_22_atus (Score: 1.00)
#   - Thực tế: person_22_atus
# Độ chính xác của mô hình: 92.32%
# Tổng số ảnh: 833
# Số nhận diện đúng: 769
# Số nhận diện sai: 64
# 92.31692677070828

# %%
def show_random_results(dataset_dir, num_images=5):
    """
    Hiển thị kết quả nhận diện ngẫu nhiên từ dataset.
    
    Args:
        dataset_dir (str): Đường dẫn tới thư mục dataset.
        num_images (int): Số ảnh ngẫu nhiên để hiển thị.
    """
    all_images = []
    for person_name in os.listdir(dataset_dir):
        person_dir = os.path.join(dataset_dir, person_name)
        if not os.path.isdir(person_dir):
            continue

        for img_name in os.listdir(person_dir):
            img_path = os.path.join(person_dir, img_name)
            all_images.append((img_path, person_name))

    # Shuffle và lấy num_images ảnh
    random.shuffle(all_images)
    sample_images = all_images[:num_images]

    # Hiển thị từng ảnh
    for img_path, true_name in sample_images:
        show_image_with_results(img_path, true_name)

# %%
show_random_results(dataset_dir, num_images=5)
